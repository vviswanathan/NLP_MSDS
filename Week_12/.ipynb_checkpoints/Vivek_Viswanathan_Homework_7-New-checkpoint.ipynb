# %% [markdown]
# # Introduction
#
# In this homework, using the reviews downloaded as part of Homework 5, we will
# - Select a clustering method and run it over the collection of reviews
#     - Show at least 2 different ways of clustering the reviews.
#         - Changing k in k-Means clustering (OR)
#         - Change where you "cut" Agnes or Diana
# - Write a short phrase to characterize of what each cluster is generally centered on semantically
# - Explain which of hte 2 clustering results from Question 1 is preferable and why

# %% [markdown]
# #### Preparation Steps
# - Import the necessary packages
# - Import the reviews from Homework 5
# -

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from sklearn.cluster import MiniBatchKMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
data = pd.read_excel('Film_User_Reviews.xlsx')
data['Rating'] = data['Rating'].replace(r'\n','', regex=True).str.split('/').str[0].astype(int)
review = data['Review']

# %%
data
# Out:
#      Unnamed: 0    Film Title       Review User  \
# 0             0  Palm Springs        fadlanamin
# 1             1  Palm Springs          kjproulx
# 2             2  Palm Springs     cartsghammond
# 3             3  Palm Springs         cardsrock
# 4             4  Palm Springs        Loptimus06
# ..          ...           ...               ...
# 120          20    Desperados       omood-00755
# 121          21    Desperados       Worldpeece1
# 122          22    Desperados    boriquachula16
# 123          23    Desperados  Elizabethchivers
# 124          24    Desperados            yvccfj
#
#                                                  Title  \
# 0                                 Weird but Good Weird
# 1     It's Very Hard to Dislike a Movie like Palm S...
# 2                                             Pure fun
# 3                                      Simply terrific
# 4                          A New Take On Groundhog Day
# ..                                                 ...
# 120                                  Great comedy film
# 121                             Predictable and boring
# 122                 Couldn't skip through fast enough.
# 123                               Very fun chick flick
# 124                                     Dead end movie
#
#                                                 Review  Rating
# 0    I was expecting a conventional rom-com where t...       8
# 1    Films that revolve around characters repeating...       9
# 2    Palm Springs is just such a good time of a mov...       9
# 3    I'm impressed that people are still able to fi...       8
# 4    Palm Springs is "One of those infinite time-lo...       8
# ..                                                 ...     ...
# 120  It was a good comedy film. Was it a masterliec...       9
# 121  The main character was just annoying. Found my...       2
# 122  The ONLY good thing about this film is Lamorne...       1
# 123  I was surprised to see so many bad reviews. Th...       8
# 124  Decent movie but was disappointed in the story...       4
#
# [125 rows x 6 columns]

# %%
review
# Out:
# 0      I was expecting a conventional rom-com where t...
# 1      Films that revolve around characters repeating...
# 2      Palm Springs is just such a good time of a mov...
# 3      I'm impressed that people are still able to fi...
# 4      Palm Springs is "One of those infinite time-lo...
#                              ...
# 120    It was a good comedy film. Was it a masterliec...
# 121    The main character was just annoying. Found my...
# 122    The ONLY good thing about this film is Lamorne...
# 123    I was surprised to see so many bad reviews. Th...
# 124    Decent movie but was disappointed in the story...
# Name: Review, Length: 125, dtype: object

# %%
tfidf = TfidfVectorizer(
    min_df = 5,
    max_df = 0.95,
    max_features = 8000,
    stop_words = 'english'
)
tfidf.fit(data.Review)
text = tfidf.transform(data.Review)

# %%
def find_optimal_clusters(data, max_k):
    iters = range(2, max_k+1, 2)
    
    sse = []
    for k in iters:
        sse.append(MiniBatchKMeans(n_clusters=k, init_size=1024, batch_size=2048, random_state=20).fit(data).inertia_)
        print('Fit {} clusters'.format(k))
        
    f, ax = plt.subplots(1, 1)
    ax.plot(iters, sse, marker='o')
    ax.set_xlabel('Cluster Centers')
    ax.set_xticks(iters)
    ax.set_xticklabels(iters)
    ax.set_ylabel('SSE')
    ax.set_title('SSE by Cluster Center Plot')
    
find_optimal_clusters(text, 20)
# Out:
# Fit 2 clusters
# Fit 4 clusters
# Fit 6 clusters
# Fit 8 clusters
# Fit 10 clusters
# Fit 12 clusters
# Fit 14 clusters
# Fit 16 clusters
# Fit 18 clusters
# Fit 20 clusters

# %%
clusters = MiniBatchKMeans(n_clusters=10, init_size=1024, batch_size=2048, random_state=20).fit_predict(text)

# %%
def plot_tsne_pca(data, labels):
    max_label = max(labels)
    max_items = np.random.choice(range(data.shape[0]), size=125, replace=False)
    
    pca = PCA(n_components=10).fit_transform(data[max_items,:].todense())
    tsne = TSNE().fit_transform(PCA(n_components=10).fit_transform(data[max_items,:].todense()))
    
    
    idx = np.random.choice(range(pca.shape[0]), size=125, replace=False)
    label_subset = labels[max_items]
    label_subset = [cm.hsv(i/max_label) for i in label_subset[idx]]
    
    f, ax = plt.subplots(1, 2, figsize=(14, 6))
    
    ax[0].scatter(pca[idx, 0], pca[idx, 1], c=label_subset)
    ax[0].set_title('PCA Cluster Plot')
    
    ax[1].scatter(tsne[idx, 0], tsne[idx, 1], c=label_subset)
    ax[1].set_title('TSNE Cluster Plot')
    
plot_tsne_pca(text, clusters)

# %%
def get_top_keywords(data, clusters, labels, n_terms):
    df = pd.DataFrame(data.todense()).groupby(clusters).mean()
    
    for i,r in df.iterrows():
        print('\nCluster {}'.format(i))
        print(','.join([labels[t] for t in np.argsort(r)[-n_terms:]]))
            
get_top_keywords(text, clusters, tfidf.get_feature_names(), 10)
# Out:
# Cluster 0
# enjoyable,hilarious,movie,stuck,groundhog,time,watch,loop,day,romantic
#
# Cluster 1
# thing,message,saw,way,character,going,movie,good,just,like
#
# Cluster 2
# entitled,character,going,watch,main,pretty,characters,watching,just,movie
#
# Cluster 3
# ending,film,minutes,10,murder,movie,acting,good,mystery,story
#
# Cluster 4
# good,really,love,don,loved,contest,ferrell,song,film,eurovision
#
# Cluster 5
# better,love,moments,wasn,enjoyed,good,expected,comedy,people,low
#
# Cluster 6
# twists,rian,murder,film,mystery,daniel,cast,craig,knives,johnson
#
# Cluster 7
# movie,just,time,know,honestly,country,don,school,multiple,enjoy
#
# Cluster 8
# cristin,concept,time,film,andy,milioti,samberg,springs,palm,day
#
# Cluster 9
# movie,comedy,cute,romance,writing,screen,couple,original,heart,funny

# %%
clusters = MiniBatchKMeans(n_clusters=5, init_size=1024, batch_size=2048, random_state=20).fit_predict(text)

# %%
def plot_tsne_pca(data, labels):
    max_label = max(labels)
    max_items = np.random.choice(range(data.shape[0]), size=125, replace=False)
    
    pca = PCA(n_components=5).fit_transform(data[max_items,:].todense())
    tsne = TSNE().fit_transform(PCA(n_components=5).fit_transform(data[max_items,:].todense()))
    
    
    idx = np.random.choice(range(pca.shape[0]), size=125, replace=False)
    label_subset = labels[max_items]
    label_subset = [cm.hsv(i/max_label) for i in label_subset[idx]]
    
    f, ax = plt.subplots(1, 2, figsize=(14, 6))
    
    ax[0].scatter(pca[idx, 0], pca[idx, 1], c=label_subset)
    ax[0].set_title('PCA Cluster Plot')
    
    ax[1].scatter(tsne[idx, 0], tsne[idx, 1], c=label_subset)
    ax[1].set_title('TSNE Cluster Plot')
    
plot_tsne_pca(text, clusters)

# %%
def get_top_keywords(data, clusters, labels, n_terms):
    df = pd.DataFrame(data.todense()).groupby(clusters).mean()
    
    for i,r in df.iterrows():
        print('\nCluster {}'.format(i))
        print(','.join([labels[t] for t in np.argsort(r)[-n_terms:]]))
            
get_top_keywords(text, clusters, tfidf.get_feature_names(), 10)
# Out:
# Cluster 0
# low,fun,cute,movie,want,good,ok,enjoyed,pretty,film
#
# Cluster 1
# time,know,country,honestly,think,movie,school,multiple,don,enjoy
#
# Cluster 2
# main,bad,parents,good,going,funny,character,just,like,movie
#
# Cluster 3
# love,ferrell,mystery,time,good,story,song,movie,eurovision,film
#
# Cluster 4
# watch,classic,loop,samberg,palm,springs,time,groundhog,movie,day

# %% [markdown]
# ### Reference:
#
# - https://www.kaggle.com/jbencina/clustering-documents-with-tfidf-and-kmeans
