# %% [markdown]
# # Introduction
#
# In this exercise, we will
# - Extract User Reviews from IMDB for movies from the same genre
#     - Use a crawler to collect the review links (at least 100 reviews)
#     - Each link is a webpage that has only 1 user review
#     - Choose reviews from the same genre
#     - Collect reviews of several movies in the chosen genre and includes a mix of positive and negative reviews
# - Extract the Noun Phrase chunks from the reviews:
#     - Grab the main review text from each link
#     - Run the review through a tokenizer and try to NP chunk it with a shallow parser
#     - If there are unknown word, expand the working lexicon and run the NP chunker again
# - Output all the chunks in a single list for each review. Also, submit a brief summary of what we did.

# %% [markdown]
# #### Preparation Steps
# - Import the necessary packages
# - Use selenium to navigate through the webpages programatically
# - Extract reviews using beautifulsoup.

# %%
#!pip install selenium
#!pip install vaderSentiment
#!pip install textblob

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from textblob import TextBlob
import time

# %% [markdown]
# #### Setup driver and open the webpage
#
# - Setup the webdriver to Firefox.
#     - For this step to work, we have to add the directory path of the geckodriver.exe to the Windows PATH variable
# - Open the webpage for the selected genre (Romance)

# %%
driver = webdriver.Firefox()

genre="comedy"
genre=genre.lower()
url="https://www.imdb.com/search/title/?title_type=feature&genres="+genre+"&explore=genres"

print("URL for Genre:: ", url)
#Go to Google
driver.get("https://www.imdb.com/search/title/?title_type=feature&genres="+genre+"&explore=genres")
# Out:
# URL for Genre::  https://www.imdb.com/search/title/?title_type=feature&genres=comedy&explore=genres

# %% [markdown]
# #### Loop through the top 5 movies and get review text
#
# ##### I observed that:
#     - the full XPATH for the links on the page were incremented at a particular position
#     - The full XPATH for the user reviews were always the same within the movie page
#
# ##### To navigate the pages:
#     - Used the properties of selenium driver (find_element_by_xpath) to naviagte through the pages
#     - Once I reached the User review page, I set the current url to a variable
#     - Used Beautiful Soup to open the User Review page
#     - Extracted the Review User, Title of the Review, and the review text
#     - The values were stored in a dataframe
#     - The results were also written to and Excel file as a precaution just in case IMDB website is not available

# %%
#driver = webdriver.Chrome(executable_path=r"C:\Vivek\Software\chromedriver.exe")
table_review = pd.DataFrame(columns=['Film Title', 'Review User', 'Title', 'Review'])

for i in range(1,6):
    #driver.find_element_by_tag_name('body').send_keys(Keys.CONTROL + 't')
    
    # Open the main page for the Genre
    driver.get("https://www.imdb.com/search/title/?title_type=feature&genres="+genre+"&explore=genres")
    
    # Open the 1st 5 pages by iterating to set the XPATH parameter, click on the link
    xpth = "/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div/div["+str(i)+"]/div[3]/h3/a"
    driver.find_element_by_xpath(xpth).click()
    #print(xpth)
    
    # Find the User Reviews link and click by using the standard XPATH
    driver.find_element_by_xpath("/html/body/div[3]/div/div[2]/div/div[1]/div/div/div[1]/div[1]/div[1]/a[3]").click()
    
    #Scrap IMBD review
    ans = driver.current_url
    #print('URL:: ',ans)
    page = requests.get(ans)
    soup = BeautifulSoup(page.content, "html.parser")
    all = soup.find(id="main")
    
    #Get the title of the movie
    parent = all.find(class_ ="parent")
    name = parent.find(itemprop = "name")
    url = name.find(itemprop = 'url')
    #print('URL2:: ',url)
    film_title = url.get_text()
    
    #Get the User Name related to the review
    review_user_rev = all.select(".display-name-link")
    review_user = [t.get_text().replace("\n", "") for t in review_user_rev]
    
    #Get the title of the review
    title_rev = all.select(".title")
    title = [t.get_text().replace("\n", "") for t in title_rev]
    
    #Get the review
    review_rev = all.select(".content .text")
    review = [r.get_text() for r in review_rev]
    
    #Get the review
    rating_rev = all.select(".imdb-user-review .ipl-ratings-bar .rating-other-user-rating")
    rating = [r.get_text() for r in rating_rev]
    
    # Convert into a temp dataframe
    table_review_iter = pd.DataFrame({
        "Film Title": film_title,
        "Review User": review_user,
        "Title" : title,
        "Review" : review,
        "Rating" : rating
    })
    
    # Append to the main Dataframe
    table_review = table_review.append(table_review_iter)

# %%
table_review.shape
# Out:
# (125, 5)

# %%
table_review
# Out:
#       Film Title       Review User  \
# 0   Palm Springs        fadlanamin
# 1   Palm Springs          kjproulx
# 2   Palm Springs     cartsghammond
# 3   Palm Springs         cardsrock
# 4   Palm Springs        Loptimus06
# ..           ...               ...
# 20    Desperados       omood-00755
# 21    Desperados       Worldpeece1
# 22    Desperados    boriquachula16
# 23    Desperados  Elizabethchivers
# 24    Desperados            yvccfj
#
#                                                 Title  \
# 0                                Weird but Good Weird
# 1    It's Very Hard to Dislike a Movie like Palm S...
# 2                                            Pure fun
# 3                                     Simply terrific
# 4                         A New Take On Groundhog Day
# ..                                                ...
# 20                                  Great comedy film
# 21                             Predictable and boring
# 22                 Couldn't skip through fast enough.
# 23                               Very fun chick flick
# 24                                     Dead end movie
#
#                                                Review              Rating
# 0   I was expecting a conventional rom-com where t...  \n\n\n\n\n\n8/10\n
# 1   Films that revolve around characters repeating...  \n\n\n\n\n\n9/10\n
# 2   Palm Springs is just such a good time of a mov...  \n\n\n\n\n\n9/10\n
# 3   I'm impressed that people are still able to fi...  \n\n\n\n\n\n8/10\n
# 4   Palm Springs is "One of those infinite time-lo...  \n\n\n\n\n\n8/10\n
# ..                                                ...                 ...
# 20  It was a good comedy film. Was it a masterliec...  \n\n\n\n\n\n9/10\n
# 21  The main character was just annoying. Found my...  \n\n\n\n\n\n2/10\n
# 22  The ONLY good thing about this film is Lamorne...  \n\n\n\n\n\n1/10\n
# 23  I was surprised to see so many bad reviews. Th...  \n\n\n\n\n\n8/10\n
# 24  Decent movie but was disappointed in the story...  \n\n\n\n\n\n4/10\n
#
# [125 rows x 5 columns]

# %%
# Write results to an Excel file
table_review.to_excel('Film_User_Reviews.xlsx')

# %% [markdown]
# #### Noun phrase chunking
#
# Chunking is a process of extracting phrases from unstructured text. We have to first perform POS tagging before chunking the sentences. It is important when we want to extract information from the text. It is also known as Named Entity Extraction.
#
# To create NP chunk, we first define the chunk grammar (pattern) using POS tags. We will start with a simple grammar pattern before expanding on our pattern.
#
# At first, we will define the rule such that when the chunk finds determiner (DT) followed by any number of adjectives (JJ) and then a noun (NN) then the Noun Phrase(NP) chunk should be formed.

# %%
import nltk

# %%
def ie_preprocess(document):
    sentences = nltk.sent_tokenize(document)
    sentences = [nltk.word_tokenize(sent) for sent in sentences]
    sentences = [nltk.pos_tag(sent) for sent in sentences]
    return(sentences)

# %%
for ind_review in table_review.Review:
    sentences_pos = ie_preprocess(ind_review)
    
    grammar = ('''
    NP: {<DT>?<JJ>*<NN>} # NP
    ''')
    cp = nltk.RegexpParser(grammar)
    
    for sent in sentences_pos:
        tree = cp.parse(sent)
        print(tree)
# Out:
# (S
#   I/PRP
#   honestly/RB
#   ca/MD
#   n't/RB
#   believe/VB
#   this/DT
#   is/VBZ
#   (NP an/DT actual/JJ movie/NN)
#   and/CC
#   (NP number/NN)
#   1/CD
#   on/IN
#   Netflix/NNP
#   in/IN
#   my/PRP$
#   (NP country/NN)
#   ./.)
# (S
#   This/DT
#   was/VBD
#   probably/RB
#   the/DT
#   worst/JJS
#   (NP movie/NN)
#   I/PRP
#   've/VBP
#   ever/RB
#   seen/VBN
#   ./.)
# (S
#   The/DT
#   dialogues/NNS
#   between/IN
#   the/DT
#   main/JJ
#   characters/NNS
#   are/VBP
#   unbelievably/RB
#   cringy/JJ
#   and/CC
#   (NP the/DT plot/NN)
#   literally/RB
#   does/VBZ
#   n't/RB
#   make/VB
#   (NP any/DT sense/NN)
#   ./.)
# (S
#   Do/VBP
#   n't/RB
#   watch/VB
#   (NP this/DT movie/NN)
#   unless/IN
#   you/PRP
#   wan/VBP
#   (NP na/JJ waste/NN)
#   2/CD
#   hours/NNS
#   of/IN
#   your/PRP$
#   (NP life/NN)
#   just/RB
#   to/TO
#   give/VB
#   (NP this/DT movie/NN)
#   a/DT
#   (/(
#   probably/RB
#   )/)
#   1/CD
#   (NP star/NN)
#   (NP rating/NN)
#   too/RB
#   ./.)
# (S
#   Girl/NNP
#   's/POS
#   (NP boyfriend/NN)
#   wears/VBZ
#   cargo/VBP
#   short/JJ
#   pants/NNS
#   on/IN
#   her/PRP$
#   (NP birthday/NN)
#   ./.)
# (S
#   If/IN
#   that/DT
#   is/VBZ
#   not/RB
#   (NP a/DT red/JJ flag/NN)
#   ,/,
#   I/PRP
#   do/VBP
#   not/RB
#   know/VB
#   what/WP
#   it/PRP
#   is/VBZ
#   ./.)
# (S
#   (NP A/DT kidnapped/JJ woman/NN)
#   is/VBZ
#   smiling/VBG
#   less/JJR
#   than/IN
#   24/CD
#   hours/NNS
#   after/IN
#   being/VBG
#   fed/VBN
#   and/CC
#   taking/VBG
#   (NP shopping/NN)
#   at/IN
#   (NP a/DT high/JJ end/NN)
#   (NP botique/NN)
#   by/IN
#   her/PRP$
#   (NP captor/NN)
#   ./.)
# (S
#   3/CD
#   days/NNS
#   into/IN
#   her/PRP$
#   (NP captivity/NN)
#   (NP spent/NN)
#   jetsetting/VBG
#   to/TO
#   VIP/NNP
#   clubs/NNS
#   and/CC
#   on/IN
#   private/JJ
#   yachts/NNS
#   she/PRP
#   blows/VBZ
#   him/PRP
#   and/CC
#   falls/VBZ
#   in/IN
#   (NP love/NN)
#   ./.)
# (S
#   (NP A/DT true/JJ romance/NN)
#   (NP tale/NN)
#   for/IN
#   the/DT
#   ages/NNS
#   ./.)
# (S (NP The/DT cringe/NN) levels/NNS runeth/VBP over/IN ./.)
# (S
#   The/DT
#   English/NNP
#   is/VBZ
#   almost/RB
#   as/RB
#   bad/JJ
#   as/IN
#   (NP the/DT plot/NN)
#   ./.)
# (S
#   If/IN
#   you/PRP
#   want/VBP
#   to/TO
#   watch/VB
#   (NP this/DT movie/NN)
#   do/VBP
#   so/RB
#   as/IN
#   (NP a/DT drinking/NN)
#   (NP game/NN)
#   ./.)
# (S Did/NNP you/PRP cringe/VB ?/.)
# (S Then/RB take/VB (NP a/DT shot/NN) my/PRP$ (NP dude/NN) ./.)
# (S You/PRP will/MD be/VB wasted/VBN by/IN (NP the/DT end/NN) ./.)
# (S
#   I/PRP
#   honestly/RB
#   do/VBP
#   n't/RB
#   know/VB
#   who/WP
#   thought/VBD
#   that/IN
#   (NP this/DT movie/NN)
#   would/MD
#   be/VB
#   (NP a/DT good/JJ idea/NN)
#   ./.)
# (S
#   It/PRP
#   is/VBZ
#   (NP a/DT complete/JJ train/NN)
#   (NP wreck/NN)
#   for/IN
#   (NP multiple/JJ reasons.One/NN)
#   of/IN
#   the/DT
#   biggest/JJS
#   issues/NNS
#   is/VBZ
#   (NP the/DT plot/NN)
#   is/VBZ
#   just/RB
#   nonsense/JJ
#   ./.)
# (S
#   It/PRP
#   is/VBZ
#   inappropriate/JJ
#   to/TO
#   have/VB
#   (NP a/DT man/NN)
#   deiced/VBD
#   that/IN
#   he/PRP
#   will/MD
#   hold/VB
#   (NP a/DT woman/NN)
#   (NP captive/NN)
#   and/CC
#   she/PRP
#   will/MD
#   love/VB
#   him/PRP
#   ./.)
# (S
#   That/DT
#   is/VBZ
#   just/RB
#   not/RB
#   ok/JJ
#   and/CC
#   i/JJ
#   do/VBP
#   n't/RB
#   know/VB
#   why/WRB
#   they/PRP
#   made/VBD
#   (NP a/DT movie/NN)
#   romanticising/VBG
#   (NP this/DT idea/NN)
#   ./.)
# (S (NP The/DT male/JJ character/NN) is/VBZ (NP a/DT creep/NN) ./.)
# (S
#   He/PRP
#   assaults/VBZ
#   (NP the/DT female/JJ character/NN)
#   multiple/JJ
#   times/NNS
#   and/CC
#   it/PRP
#   is/VBZ
#   not/RB
#   shown/VBN
#   as/IN
#   (NP a/DT bad/JJ thing/NN)
#   ./.)
# (S
#   It/PRP
#   's/VBZ
#   just/RB
#   like/IN
#   he/PRP
#   is/VBZ
#   (NP a/DT man/NN)
#   and/CC
#   he/PRP
#   has/VBZ
#   (NP power/NN)
#   so/IN
#   he/PRP
#   can/MD
#   do/VB
#   what/WP
#   he/PRP
#   likes/VBZ
#   ./.)
# (S It/PRP is/VBZ really/RB really/RB bad/JJ ./.)
# (S
#   Beyond/IN
#   that/DT
#   they/PRP
#   just/RB
#   do/VBP
#   variations/NNS
#   of/IN
#   (NP the/DT same/JJ scene/NN)
#   6/CD
#   different/JJ
#   times/NNS
#   ./.)
# (S
#   (NP This/DT movie/NN)
#   is/VBZ
#   just/RB
#   (NP the/DT same/JJ scene/NN)
#   over/IN
#   and/CC
#   over/RB
#   again/RB
#   broken/VBN
#   up/RP
#   with/IN
#   random/JJ
#   montages/NNS
#   with/IN
#   (NP a/DT song/NN)
#   played/VBN
#   over/IN
#   it.The/JJ
#   actions/NNS
#   of/IN
#   the/DT
#   characters/NNS
#   are/VBP
#   nonsensical/JJ
#   too/RB
#   ./.)
# (S
#   She/PRP
#   has/VBZ
#   been/VBN
#   kidnapped/VBN
#   in/IN
#   (NP a/DT foreign/JJ country/NN)
#   and/CC
#   then/RB
#   (NP the/DT next/JJ day/NN)
#   there/EX
#   is/VBZ
#   (NP a/DT shopping/NN)
#   (NP montage/NN)
#   where/WRB
#   she/PRP
#   is/VBZ
#   just/RB
#   like/IN
#   ``/``
#   woo/JJ
#   lets/NNS
#   go/VBP
#   buy/VB
#   some/DT
#   new/JJ
#   clothes/NNS
#   ''/''
#   ./.)
# (S
#   Like/IN
#   that/DT
#   just/RB
#   would/MD
#   n't/RB
#   happen/VB
#   ,/,
#   you/PRP
#   would/MD
#   be/VB
#   terrified/VBN
#   and/CC
#   she/PRP
#   just/RB
#   acts/NNS
#   like/IN
#   (NP fine/NN)
#   with/IN
#   it/PRP
#   ./.)
# (S
#   I/PRP
#   feel/VBP
#   like/IN
#   they/PRP
#   try/VBP
#   to/TO
#   get/VB
#   (NP the/DT audience/NN)
#   on/IN
#   (NP side/NN)
#   by/IN
#   making/VBG
#   her/PRP$
#   (NP current/JJ boyfriend/NN)
#   (NP a/DT horrible/JJ person/NN)
#   ./.)
# (S
#   I/PRP
#   think/VBP
#   they/PRP
#   think/VBP
#   (NP the/DT audience/NN)
#   will/MD
#   be/VB
#   like/IN
#   ``/``
#   oh/IN
#   that/DT
#   's/VBZ
#   good/JJ
#   she/PRP
#   got/VBD
#   away/RB
#   from/IN
#   him/PRP
#   ''/''
#   ./.)
# (S
#   Yeah/UH
#   she/PRP
#   did/VBD
#   get/VB
#   away/RB
#   from/IN
#   her/PRP$
#   (NP bad/JJ boyfriend/NN)
#   .../:
#   by/IN
#   being/VBG
#   kidnapped/VBN
#   by/IN
#   (NP an/DT Italian/JJ mobster/NN)
#   who/WP
#   is/VBZ
#   holding/VBG
#   her/PRP$
#   (NP captive/NN)
#   ?/.
#   ?/.
#   ?/.)
# (S
#   ?/.
#   (NP The/DT second/JJ issue/NN)
#   is/VBZ
#   the/DT
#   leads/NNS
#   ca/MD
#   n't/RB
#   act/VB
#   and/CC
#   (NP a/DT lot/NN)
#   of/IN
#   (NP the/DT movie/NN)
#   is/VBZ
#   just/RB
#   them/PRP
#   interacting/VBG
#   so/RB
#   its/PRP$
#   like/IN
#   watching/VBG
#   (NP an/DT amateur/NN)
#   dramatics/NNS
#   troupe/VBP
#   (NP half/NN)
#   of/IN
#   (NP the/DT time/NN)
#   ./.)
# (S
#   Now/RB
#   i/VBZ
#   ca/MD
#   n't/RB
#   work/VB
#   this/DT
#   out/RP
#   but/CC
#   (NP this/DT woman/NN)
#   who/WP
#   is/VBZ
#   kidnapped/VBN
#   never/RB
#   seems/VBZ
#   scared/VBN
#   like/IN
#   at/IN
#   all/DT
#   ./.)
# (S
#   I/PRP
#   ca/MD
#   n't/RB
#   deiced/VB
#   if/IN
#   this/DT
#   was/VBD
#   (NP the/DT direction/NN)
#   she/PRP
#   was/VBD
#   given/VBN
#   or/CC
#   she/PRP
#   just/RB
#   ca/MD
#   n't/RB
#   act/VB
#   or/CC
#   (NP the/DT script/NN)
#   said/VBD
#   she/PRP
#   is/VBZ
#   n't/RB
#   scared/VBN
#   ./.)
# (S
#   She/PRP
#   literally/RB
#   wakes/VBZ
#   up/RP
#   after/IN
#   being/VBG
#   kidnapped/VBN
#   and/CC
#   tried/VBN
#   to/TO
#   open/VB
#   (NP the/DT door/NN)
#   to/TO
#   get/VB
#   out/RP
#   ,/,
#   ca/MD
#   n't/RB
#   because/VB
#   its/PRP$
#   locked/JJ
#   and/CC
#   is/VBZ
#   just/RB
#   like/IN
#   ``/``
#   Yeah/NNP
#   fair/JJ
#   enough/RB
#   ''/''
#   and/CC
#   just/RB
#   sits/NNS
#   down/RP
#   like/IN
#   this/DT
#   happens/VBZ
#   (NP every/DT day.On/NN)
#   (NP top/NN)
#   of/IN
#   that/IN
#   the/DT
#   scenes/NNS
#   with/IN
#   (NP the/DT male/JJ lead/NN)
#   pushing/VBG
#   her/PRP$
#   against/IN
#   walls/NNS
#   and/CC
#   (NP stuff/NN)
#   she/PRP
#   pulls/VBZ
#   like/IN
#   ``/``
#   Posing/NNP
#   ,/,
#   modelling/VBG
#   ''/''
#   faces/VBZ
#   and/CC
#   is/VBZ
#   not/RB
#   like/IN
#   ``/``
#   Jesus/NNP
#   Christ/NNP
#   (NP the/DT man/NN)
#   is/VBZ
#   assaulting/VBG
#   me/PRP
#   (NP help/NN)
#   ''/''
#   ./.)
# (S
#   Once/RB
#   again/RB
#   was/VBD
#   this/DT
#   (NP the/DT direction/NN)
#   or/CC
#   was/VBD
#   it/PRP
#   the/DT
#   acting/VBG
#   who/WP
#   's/VBZ
#   knows/NNS
#   ?/.
#   It/PRP
#   also/RB
#   relies/VBZ
#   heavily/RB
#   on/IN
#   ``/``
#   Pop/NNP
#   ''/''
#   songs/NNS
#   that/WDT
#   are/VBP
#   really/RB
#   loud/JJ
#   and/CC
#   unnecessary/JJ
#   ./.)
# (S
#   They/PRP
#   constantly/RB
#   play/VBP
#   one/CD
#   after/IN
#   the/DT
#   other/JJ
#   and/CC
#   then/RB
#   when/WRB
#   reading/VBG
#   i/RB
#   found/VBN
#   out/RP
#   (NP the/DT male/JJ lead/NN)
#   (NP sung/NN)
#   like/IN
#   (NP a/DT big/JJ chunk/NN)
#   of/IN
#   them/PRP
#   so/RB
#   (NP i/JJ guess/NN)
#   (NP production/NN)
#   was/VBD
#   just/RB
#   like/IN
#   ``/``
#   well/RB
#   he/PRP
#   will/MD
#   give/VB
#   us/PRP
#   them/PRP
#   cheep/VBP
#   (NP let/NN)
#   's/POS
#   throw/VB
#   them/PRP
#   all/DT
#   in/IN
#   ''/''
#   (NP .I/NN)
#   could/MD
#   go/VB
#   one/CD
#   about/IN
#   all/DT
#   its/PRP$
#   problems/NNS
#   but/CC
#   it/PRP
#   all/DT
#   circles/VBZ
#   back/RB
#   to/TO
#   (NP the/DT directing/NN)
#   ,/,
#   acting/VBG
#   and/CC
#   (NP the/DT script/NN)
#   ./.)
# (S
#   It/PRP
#   was/VBD
#   just/RB
#   (NP a/DT perfect/JJ storm.Believe/NN)
#   it/PRP
#   or/CC
#   not/RB
#   it/PRP
#   is/VBZ
#   watchable/JJ
#   but/CC
#   in/IN
#   (NP a/DT way/NN)
#   that/IN
#   you/PRP
#   want/VBP
#   to/TO
#   watch/VB
#   it/PRP
#   to/TO
#   see/VB
#   (NP the/DT disaster/NN)
#   ./.)
# (S
#   It/PRP
#   is/VBZ
#   the/DT
#   no1/JJ
#   viewed/VBN
#   (NP film/NN)
#   on/IN
#   (NP a/DT large/JJ amount/NN)
#   of/IN
#   different/JJ
#   countries/NNS
#   Netflix/NNP
#   's/POS
#   at/IN
#   (NP the/DT moment/NN)
#   and/CC
#   (NP i/NN)
#   believe/VBP
#   this/DT
#   to/TO
#   be/VB
#   (NP the/DT reason.So/NN)
#   its/PRP$
#   really/RB
#   up/IN
#   to/TO
#   you/PRP
#   if/IN
#   you/PRP
#   want/VBP
#   to/TO
#   watch/VB
#   it/PRP
#   ./.)
# (S
#   It/PRP
#   is/VBZ
#   very/RB
#   boring/JJ
#   but/CC
#   also/RB
#   (NP a/DT train/NN)
#   (NP wreck/NN)
#   ./.)
# (S I/PRP do/VBP not/RB even/RB know/VB where/WRB to/TO start/VB ./.)
# (S
#   (NP Look/NN)
#   ,/,
#   this/DT
#   is/VBZ
#   (NP nothing/NN)
#   but/CC
#   straight/VBD
#   up/RP
#   (NP porn/NN)
#   ./.)
# (S
#   (NP The/DT plot/NN)
#   is/VBZ
#   ridiculous/JJ
#   ,/,
#   (NP the/DT chemistry/NN)
#   between/IN
#   the/DT
#   two/CD
#   leads/NNS
#   is/VBZ
#   nonexistent/JJ
#   ,/,
#   and/CC
#   (NP the/DT acting/NN)
#   is/VBZ
#   even/RB
#   worse/JJR
#   ./.)
# (S
#   Trust/NNP
#   me/PRP
#   when/WRB
#   I/PRP
#   say/VBP
#   ,/,
#   you/PRP
#   will/MD
#   watch/VB
#   this/DT
#   in/IN
#   fast/RB
#   (NP forward/NN)
#   ./.)
# (S It/PRP is/VBZ that/IN horrible/JJ !/.)
# (S
#   (NP This/DT movie/NN)
#   is/VBZ
#   legit/JJ
#   (NP the/DT third/JJ worst/JJ movie/NN)
#   I/PRP
#   've/VBP
#   ever/RB
#   seen/VBN
#   ./.)
# (S
#   Incoherent/NNP
#   (NP plot/NN)
#   ,/,
#   stupid/JJ
#   characters/NNS
#   ,/,
#   completely/RB
#   illogical/JJ
#   in/IN
#   (NP every/DT sense/NN)
#   of/IN
#   (NP the/DT word/NN)
#   ./.)
# (S
#   My/PRP$
#   (NP advice/NN)
#   would/MD
#   be/VB
#   to/TO
#   avoid/VB
#   (NP this/DT hot/JJ mess/NN)
#   at/IN
#   all/DT
#   costs/NNS
#   ./.)
# (S
#   I/PRP
#   do/VBP
#   n't/RB
#   remember/VB
#   if/IN
#   I/PRP
#   have/VBP
#   reviewed/VBN
#   (NP another/DT movie/NN)
#   so/RB
#   far/RB
#   ,/,
#   but/CC
#   seeing/VBG
#   so/RB
#   many/JJ
#   10/10/CD
#   reviews/NNS
#   determined/VBD
#   me/PRP
#   to/TO
#   log/VB
#   in/IN
#   to/TO
#   write/VB
#   this/DT
#   ,/,
#   to/TO
#   ballance/VB
#   things/NNS
#   up/RP
#   (NP a/DT bit.The/NN)
#   (NP movie/NN)
#   is/VBZ
#   pretty/RB
#   bad/JJ
#   ./.)
# (S
#   (NP The/DT plot/NN)
#   (/(
#   if/IN
#   you/PRP
#   can/MD
#   call/VB
#   it/PRP
#   that/IN
#   )/)
#   is/VBZ
#   mostly/RB
#   absurd/JJ
#   and/CC
#   the/DT
#   events/NNS
#   are/VBP
#   (NP cliche/NN)
#   and/CC
#   totally/RB
#   predictable/JJ
#   (/(
#   try/VB
#   to/TO
#   remember/VB
#   what/WP
#   (NP somebody/NN)
#   did/VBD
#   or/CC
#   said/VBD
#   in/IN
#   all/PDT
#   the/DT
#   bad/JJ
#   movies/NNS
#   that/IN
#   you/PRP
#   ever/RB
#   saw/VBD
#   :/:
#   yes/UH
#   ,/,
#   it/PRP
#   's/VBZ
#   exactly/RB
#   what/WP
#   's/VBZ
#   going/VBG
#   to/TO
#   happen/VB
#   )/)
#   ,/,
#   the/DT
#   events/NNS
#   do/VBP
#   n't/RB
#   make/VB
#   (NP a/DT lot/NN)
#   of/IN
#   (NP sense/NN)
#   ,/,
#   (NP the/DT dialogue/NN)
#   is/VBZ
#   (NP cringe/NN)
#   ,/,
#   the/DT
#   characters/NNS
#   are/VBP
#   very/RB
#   cartoonish/JJ
#   and/CC
#   unbelievable/JJ
#   ./.)
# (S
#   What/WP
#   they/PRP
#   say/VBP
#   do/VBP
#   n't/RB
#   make/VB
#   (NP a/DT lot/NN)
#   of/IN
#   (NP sense/NN)
#   ,/,
#   and/CC
#   also/RB
#   (NP nobody/NN)
#   reacts/VBZ
#   to/TO
#   events/NNS
#   in/IN
#   (NP the/DT way/NN)
#   (NP a/DT normal/JJ person/NN)
#   would/MD
#   do/VB
#   ./.)
# (S
#   These/DT
#   are/VBP
#   (NP comic/JJ book/NN)
#   characters/NNS
#   ,/,
#   not/RB
#   people/NNS
#   ./.)
# (S
#   When/WRB
#   they/PRP
#   try/VBP
#   to/TO
#   suggest/VB
#   some/DT
#   of/IN
#   these/DT
#   people/NNS
#   are/VBP
#   (NP crime/NN)
#   lords/NNS
#   it/PRP
#   's/VBZ
#   hilarious/JJ
#   ,/,
#   you/PRP
#   ca/MD
#   n't/RB
#   help/VB
#   but/CC
#   chuckle/VB
#   ./.)
# (S
#   Real/JJ
#   mobsters/NNS
#   would/MD
#   have/VB
#   these/DT
#   guys/NNS
#   for/IN
#   (NP breakfast/NN)
#   ./.)
# (S
#   Ironically/RB
#   ,/,
#   the/DT
#   fly/JJ
#   girls/NNS
#   in/IN
#   (NP the/DT movie/NN)
#   are/VBP
#   actually/RB
#   more/RBR
#   believable/JJ
#   ,/,
#   because/IN
#   (NP the/DT way/NN)
#   they/PRP
#   live/VBP
#   it/PRP
#   is/VBZ
#   more/RBR
#   close/JJ
#   to/TO
#   some/DT
#   girls/NNS
#   I/PRP
#   know.I/VBP
#   never/RB
#   saw/VBD
#   any/DT
#   of/IN
#   the/DT
#   ``/``
#   Shades/NNP
#   of/IN
#   Gray/NNP
#   ''/''
#   movies/NNS
#   ,/,
#   but/CC
#   for/IN
#   (NP a/DT good/JJ part/NN)
#   it/PRP
#   felt/VBD
#   like/IN
#   (NP a/DT relative/NN)
#   of/IN
#   those/DT
#   movies/NNS
#   ./.)
# (S
#   (NP The/DT sex/NN)
#   scenes/NNS
#   are/VBP
#   pretty/RB
#   convincing/JJ
#   ,/,
#   I/PRP
#   'm/VBP
#   still/RB
#   unsure/JJ
#   if/IN
#   (NP the/DT oral/JJ sex/NN)
#   was/VBD
#   actually/RB
#   simulated/VBN
#   or/CC
#   not.The/RB
#   good/JJ
#   things/NNS
#   I/PRP
#   can/MD
#   say/VB
#   about/IN
#   this/DT
#   are/VBP
#   (/(
#   and/CC
#   each/DT
#   gets/VBZ
#   (NP a/DT star/NN)
#   from/IN
#   me/PRP
#   )/)
#   :/:
#   (NP the/DT photography/NN)
#   is/VBZ
#   pretty/RB
#   good/JJ
#   ,/,
#   at/IN
#   least/JJS
#   (NP the/DT cinematographer/NN)
#   knew/VBD
#   what/WP
#   he/PRP
#   was/VBD
#   doingthe/JJ
#   actors/NNS
#   are/VBP
#   generally/RB
#   pretty/RB
#   easy/JJ
#   on/IN
#   (NP the/DT eye/NN)
#   ,/,
#   the/DT
#   costumes/NNS
#   are/VBP
#   also/RB
#   solid/JJ
#   ,/,
#   there/EX
#   are/VBP
#   nice/JJ
#   and/CC
#   diverse/JJ
#   locations/NNS
#   ,/,
#   (NP hence/NN)
#   there/EX
#   is/VBZ
#   always/RB
#   (NP something/NN)
#   appealing/VBG
#   to/TO
#   look/VB
#   at/IN
#   on/IN
#   (NP the/DT screenthe/NN)
#   (NP sex/NN)
#   scenes/NNS
#   are/VBP
#   pretty/RB
#   good/JJ
#   if/IN
#   you/PRP
#   're/VBP
#   into/IN
#   (NP that/DT kind/NN)
#   of/IN
#   (NP thing/NN)
#   (/(
#   I/PRP
#   am/VBP
#   )/)
#   Should/MD
#   you/PRP
#   see/VB
#   it/PRP
#   ?/.)
# (S
#   Well/RB
#   I/PRP
#   do/VBP
#   n't/RB
#   know/VB
#   ,/,
#   even/RB
#   with/IN
#   (NP the/DT low/JJ score/NN)
#   that/IN
#   I/PRP
#   gave/VBD
#   it/PRP
#   ,/,
#   I/PRP
#   feel/VBP
#   like/IN
#   people/NNS
#   should/MD
#   make/VB
#   up/RP
#   their/PRP$
#   (NP own/JJ mind/NN)
#   and/CC
#   not/RB
#   take/VB
#   (NP someone/NN)
#   's/POS
#   (NP else/JJ opinion/NN)
#   on/IN
#   it/PRP
#   ./.)
# (S
#   Besides/IN
#   ,/,
#   I/PRP
#   think/VBP
#   people/NNS
#   should/MD
#   watch/VB
#   bad/JJ
#   movies/NNS
#   from/IN
#   (NP time/NN)
#   to/TO
#   (NP time/NN)
#   ,/,
#   to/TO
#   be/VB
#   able/JJ
#   to/TO
#   understand/VB
#   better/JJR
#   why/WRB
#   other/JJ
#   movies/NNS
#   are/VBP
#   good/JJ
#   ,/,
#   and/CC
#   to/TO
#   be/VB
#   more/RBR
#   appreciative/JJ
#   of/IN
#   those/DT
#   ,/,
#   as/IN
#   (NP a/DT consequence.So/NN)
#   (NP yeah/NN)
#   ,/,
#   go/VBP
#   (NP watch/NN)
#   it/PRP
#   ,/,
#   but/CC
#   keep/VB
#   your/PRP$
#   expectations/NNS
#   ridiculously/RB
#   low/JJ
#   ./.)
# (S
#   I/PRP
#   have/VBP
#   read/VBN
#   a/DT
#   few/JJ
#   stories/NNS
#   on/IN
#   (NP the/DT app/NN)
#   and/CC
#   (NP this/DT movie/NN)
#   is/VBZ
#   definitely/RB
#   (NP a/DT good/JJ reason/NN)
#   why/WRB
#   some/DT
#   books/NNS
#   should/MD
#   never/RB
#   make/VB
#   it/PRP
#   on/IN
#   (NP the/DT screen/NN)
#   ./.)
# (S It/PRP was/VBD fun/JJ but/CC ridiculous/JJ and/CC pathetic/JJ ./.)
# (S
#   Never/RB
#   seen/VBN
#   (NP such/JJ horrible/JJ movie/NN)
#   in/IN
#   my/PRP$
#   (NP entire/JJ life/NN)
#   ./.)
# (S
#   (NP The/DT concept/NN)
#   ,/,
#   acting/VBG
#   ,/,
#   scenes/NNS
#   ,/,
#   basically/RB
#   (NP everything/NN)
#   is/VBZ
#   wrong/JJ
#   in/IN
#   (NP this/DT movie/NN)
#   ./.)
# (S
#   Such/JJ
#   stupid/JJ
#   ,/,
#   worthless/JJ
#   ,/,
#   (NP toxic/JJ story/NN)
#   (NP line/NN)
#   ./.)
# (S
#   (NP Glorification/NN)
#   of/IN
#   relationships/NNS
#   where/WRB
#   (NP the/DT sole/JJ role/NN)
#   of/IN
#   (NP a/DT woman/NN)
#   is/VBZ
#   to/TO
#   be/VB
#   (NP a/DT slave/NN)
#   and/CC
#   fulfill/VB
#   the/DT
#   desires/NNS
#   of/IN
#   (NP a/DT harsh/NN)
#   ,/,
#   egotistic/JJ
#   ,/,
#   (NP rich/JJ male/NN)
#   (NP character/NN)
#   ./.)
# (S
#   365/CD
#   days/NNS
#   is/VBZ
#   about/IN
#   a/DT
#   successful/JJ
#   but/CC
#   (NP unhappy/JJ young/JJ woman/NN)
#   whose/WP$
#   (NP path/NN)
#   crosses/VBZ
#   with/IN
#   that/DT
#   of/IN
#   a/DT
#   young/JJ
#   ,/,
#   (NP handsome/JJ mafia/NN)
#   (NP boss/NN)
#   ./.)
# (S
#   He/PRP
#   kidnaps/VBZ
#   her/PRP$
#   and/CC
#   gives/VBZ
#   her/PRP$
#   (NP a/DT deadline/NN)
#   of/IN
#   one/CD
#   (NP year/NN)
#   to/TO
#   fall/VB
#   in/IN
#   (NP love/NN)
#   with/IN
#   him/PRP
#   ./.)
# (S
#   Despite/IN
#   (NP the/DT rough/JJ introduction/NN)
#   ,/,
#   she/PRP
#   eventually/RB
#   gives/VBZ
#   in/IN
#   to/TO
#   his/PRP$
#   charms/NNS
#   and/CC
#   falls/NNS
#   in/IN
#   (NP love/NN)
#   with/IN
#   him/PRP
#   ./.)
# (S
#   (NP The/DT central/JJ core/NN)
#   of/IN
#   (NP the/DT movie/NN)
#   is/VBZ
#   (NP domination/NN)
#   ,/,
#   or/CC
#   how/WRB
#   (NP the/DT male/JJ protagonist/NN)
#   uses/VBZ
#   his/PRP$
#   (NP raw/JJ masculinity/NN)
#   to/TO
#   completely/RB
#   overwhelm/VB
#   (NP the/DT girl/NN)
#   until/IN
#   she/PRP
#   eventually/RB
#   gives/VBZ
#   in/IN
#   to/TO
#   her/PRP$
#   (NP lust/NN)
#   ,/,
#   so/RB
#   ,/,
#   (NP this/DT movie/NN)
#   is/VBZ
#   a/DT
#   very/RB
#   (NP obvious/JJ copycat/NN)
#   of/IN
#   50/CD
#   Shades/NNS
#   of/IN
#   Grey.Now/NNP
#   ,/,
#   (NP this/DT movie/NN)
#   is/VBZ
#   n't/RB
#   exactly/RB
#   bad/JJ
#   ./.)
# (S
#   It/PRP
#   's/VBZ
#   not/RB
#   good/JJ
#   either/CC
#   ,/,
#   (NP mind/NN)
#   you/PRP
#   ,/,
#   but/CC
#   once/RB
#   you/PRP
#   understand/VBP
#   why/WRB
#   it/PRP
#   was/VBD
#   made/VBN
#   in/IN
#   (NP the/DT first/JJ place/NN)
#   ,/,
#   you/PRP
#   can/MD
#   at/IN
#   least/JJS
#   understand/VB
#   its/PRP$
#   (NP motivation/NN)
#   ./.)
# (S
#   There/EX
#   are/VBP
#   two/CD
#   ways/NNS
#   of/IN
#   looking/VBG
#   at/IN
#   (NP this/DT film:1/NN)
#   ./.)
# (S
#   You/PRP
#   try/VBP
#   to/TO
#   look/VB
#   at/IN
#   (NP this/DT movie/NN)
#   at/IN
#   (NP a/DT normal/JJ light/NN)
#   ,/,
#   and/CC
#   you/PRP
#   immediately/RB
#   notice/VBP
#   one/CD
#   (NP thing/NN)
#   :/:
#   it/PRP
#   draws/VBZ
#   (NP a/DT lot/NN)
#   of/IN
#   (NP inspiration/NN)
#   from/IN
#   50/CD
#   Shades/NNS
#   of/IN
#   Grey/NNP
#   ,/,
#   but/CC
#   it/PRP
#   adds/VBZ
#   a/DT
#   completely/RB
#   ludicrous/JJ
#   kidnapping/VBG
#   (NP scenario/NN)
#   ./.)
# (S
#   It/PRP
#   's/VBZ
#   like/IN
#   if/IN
#   50/CD
#   Shades/NNS
#   collided/VBD
#   at/IN
#   very/RB
#   high/JJ
#   speeds/NNS
#   with/IN
#   Beauty/NNP
#   and/CC
#   the/DT
#   Beast/NNP
#   ,/,
#   then/RB
#   (NP someone/NN)
#   filmed/VBD
#   (NP the/DT tragic/NN)
#   ,/,
#   (NP messy/JJ aftermath/NN)
#   and/CC
#   sold/VBD
#   it/PRP
#   as/IN
#   (NP a/DT movie/NN)
#   ./.)
# (S
#   (NP The/DT first/JJ act/NN)
#   seems/VBZ
#   (NP pretty/JJ straightforward/NN)
#   :/:
#   (NP the/DT young/JJ girl/NN)
#   is/VBZ
#   deeply/RB
#   frustrated/JJ
#   with/IN
#   her/PRP$
#   (NP love/NN)
#   (NP life/NN)
#   and/CC
#   is/VBZ
#   set/VBN
#   to/TO
#   meet/VB
#   (NP the/DT handsome/NN)
#   ,/,
#   (NP assertive/JJ gangster/NN)
#   ./.)
# (S
#   But/CC
#   how/WRB
#   (NP the/DT meeting/NN)
#   goes/VBZ
#   is/VBZ
#   where/WRB
#   (NP the/DT craziness/NN)
#   starts/VBZ
#   :/:
#   he/PRP
#   intentionally/RB
#   snatches/VBZ
#   her/PRP
#   off/RP
#   (NP the/DT street/NN)
#   and/CC
#   holds/VBZ
#   her/PRP$
#   (NP captive/NN)
#   ./.)
# (S
#   Then/RB
#   tells/VBZ
#   her/PRP$
#   he/PRP
#   will/MD
#   only/RB
#   let/VB
#   her/PRP
#   go/VB
#   if/IN
#   she/PRP
#   manages/VBZ
#   to/TO
#   not/RB
#   fall/VB
#   in/IN
#   (NP love/NN)
#   with/IN
#   him/PRP
#   in/IN
#   one/CD
#   (NP year/NN)
#   ./.)
# (S
#   This/DT
#   already/RB
#   feels/VBZ
#   like/IN
#   (NP a/DT plot/NN)
#   picked/VBD
#   straight/RB
#   from/IN
#   a/DT
#   Law/NNP
#   and/CC
#   Order/NNP
#   :/:
#   SVU/NNP
#   (NP episode/NN)
#   ./.)
# (S
#   (NP The/DT explanation/NN)
#   he/PRP
#   gives/VBZ
#   for/IN
#   why/WRB
#   he/PRP
#   went/VBD
#   after/IN
#   her/PRP
#   in/IN
#   (NP the/DT first/JJ place/NN)
#   just/RB
#   adds/VBZ
#   (NP another/DT thick/JJ layer/NN)
#   of/IN
#   (NP insanity/NN)
#   to/TO
#   the/DT
#   bananas/NNS
#   cake/VBP
#   ./.)
# (S
#   The/DT
#   events/NNS
#   that/WDT
#   follow/VBP
#   are/VBP
#   so/RB
#   astoundingly/RB
#   bizarre/JJ
#   that/IN
#   they/PRP
#   boggle/VBP
#   (NP the/DT mind/NN)
#   ./.)
# (S
#   It/PRP
#   does/VBZ
#   n't/RB
#   take/VB
#   too/RB
#   long/RB
#   for/IN
#   her/PRP$
#   to/TO
#   accept/VB
#   her/PRP$
#   (NP predicament/NN)
#   ,/,
#   and/CC
#   after/IN
#   what/WP
#   appears/VBZ
#   to/TO
#   be/VB
#   no/RB
#   more/JJR
#   than/IN
#   (NP a/DT day/NN)
#   ,/,
#   she/PRP
#   is/VBZ
#   already/RB
#   playing/VBG
#   flirty/JJ
#   games/NNS
#   and/CC
#   teasing/VBG
#   him/PRP
#   ./.)
# (S
#   Once/RB
#   she/PRP
#   gets/VBZ
#   her/PRP$
#   (NP cell/NN)
#   (NP phone/NN)
#   and/CC
#   her/PRP$
#   (NP laptop/JJ back/NN)
#   ,/,
#   she/PRP
#   never/RB
#   bothers/NNS
#   to/TO
#   ,/,
#   say/VB
#   ,/,
#   call/VB
#   (NP the/DT police/NN)
#   ,/,
#   or/CC
#   tell/VB
#   her/PRP$
#   (NP family/NN)
#   what/WP
#   's/VBZ
#   going/VBG
#   on/IN
#   ./.)
# (S
#   For/IN
#   (NP half/NN)
#   of/IN
#   (NP the/DT movie/NN)
#   ,/,
#   she/PRP
#   acts/VBZ
#   more/RBR
#   like/IN
#   (NP a/DT girl/NN)
#   just/RB
#   teasing/VBG
#   and/CC
#   trying/VBG
#   make/VB
#   her/PRP$
#   (NP crush/NN)
#   (NP jealous/NN)
#   ,/,
#   than/IN
#   like/IN
#   (NP a/DT woman/NN)
#   who/WP
#   has/VBZ
#   just/RB
#   being/VBG
#   abducted/VBN
#   for/IN
#   sexual/JJ
#   purposes/NNS
#   by/IN
#   (NP a/DT deranged/JJ murderer/NN)
#   ./.)
# (S
#   In/IN
#   (NP any/DT other/JJ context/NN)
#   ,/,
#   seeing/VBG
#   her/PRP$
#   giving/VBG
#   in/IN
#   ,/,
#   sleeping/VBG
#   with/IN
#   him/PRP
#   and/CC
#   start/VB
#   (NP a/DT relationship/NN)
#   with/IN
#   her/PRP$
#   (NP kidnapper/NN)
#   would/MD
#   be/VB
#   (NP a/DT horrific/JJ story/NN)
#   of/IN
#   (NP a/DT poor/JJ woman/NN)
#   being/VBG
#   forced/VBN
#   against/IN
#   her/PRP$
#   will/MD
#   and/CC
#   ,/,
#   after/IN
#   getting/VBG
#   completely/RB
#   broken/VBN
#   inside/RB
#   ,/,
#   accepting/VBG
#   her/PRP$
#   (NP fate/NN)
#   ./.)
# (S
#   Seeing/VBG
#   her/PRP$
#   (NP mistake/NN)
#   her/PRP$
#   inevitable/JJ
#   Stockholm/NNP
#   Syndrome/NNP
#   for/IN
#   truly/RB
#   falling/VBG
#   in/IN
#   (NP love/NN)
#   is/VBZ
#   not/RB
#   only/RB
#   tragic/JJ
#   ,/,
#   it/PRP
#   almost/RB
#   insults/VBZ
#   (NP the/DT intelligence/NN)
#   of/IN
#   (NP the/DT viewer/NN)
#   ./.)
# (S
#   The/DT
#   ending/VBG
#   does/VBZ
#   n't/RB
#   help/VB
#   either/RB
#   ,/,
#   because/IN
#   it/PRP
#   tries/VBZ
#   to/TO
#   be/VB
#   somber/JJ
#   and/CC
#   serious/JJ
#   ,/,
#   but/CC
#   by/IN
#   (NP the/DT time/NN)
#   (NP the/DT film/NN)
#   ends/VBZ
#   ,/,
#   those/DT
#   two/CD
#   words/NNS
#   have/VBP
#   already/RB
#   flown/VBN
#   through/IN
#   (NP the/DT window/NN)
#   long/RB
#   ago/RB
#   ./.)
# (S
#   (NP This/DT movie/NN)
#   seems/VBZ
#   even/RB
#   more/RBR
#   (NP baffling/NN)
#   and/CC
#   out/IN
#   of/IN
#   (NP place/NN)
#   in/IN
#   our/PRP$
#   current/JJ
#   times/NNS
#   ,/,
#   (NP the/DT era/NN)
#   of/IN
#   (NP the/DT fight/NN)
#   for/IN
#   (NP gender/NN)
#   (NP equality/NN)
#   ,/,
#   (NP the/DT struggle/NN)
#   for/IN
#   greater/JJR
#   (NP respect/NN)
#   for/IN
#   women/NNS
#   and/CC
#   the/DT
#   MeToo/NNP
#   (NP movement.I/NN)
#   know/VBP
#   you/PRP
#   are/VBP
#   thinking/VBG
#   this/DT
#   is/VBZ
#   incomprehensible/JJ
#   and/CC
#   bizarre/JJ
#   ./.)
# (S
#   I/PRP
#   sure/VBP
#   thought/VBN
#   that/IN
#   (NP way/NN)
#   myself/PRP
#   for/IN
#   (NP the/DT first/JJ half/NN)
#   ./.)
# (S
#   But/CC
#   then/RB
#   you/PRP
#   realize/VBP
#   you/PRP
#   are/VBP
#   simply/RB
#   looking/VBG
#   at/IN
#   it/PRP
#   wrong/JJ
#   ./.)
# (S
#   This/DT
#   is/VBZ
#   still/RB
#   no/DT
#   Citizen/NNP
#   Kane/NNP
#   ,/,
#   (NP mind/NN)
#   you/PRP
#   ,/,
#   but/CC
#   it/PRP
#   has/VBZ
#   a/DT
#   very/RB
#   (NP simple/JJ reason/NN)
#   to/TO
#   exist.2/VB
#   ./.)
# (S (NP This/DT movie/NN) is/VBZ (NP a/DT complete/JJ fantasy/NN) ./.)
# (S
#   (NP The/DT female/JJ lead/NN)
#   is/VBZ
#   in/IN
#   an/DT
#   extremely/RB
#   (NP relatable/JJ situation/NN)
#   :/:
#   she/PRP
#   has/VBZ
#   a/DT
#   vaguely/RB
#   defined/VBN
#   but/CC
#   supposedly/RB
#   (NP successful/JJ job/NN)
#   ,/,
#   but/CC
#   her/PRP$
#   (NP love/NN)
#   (NP life/NN)
#   is/VBZ
#   (NP a/DT mess/NN)
#   ./.)
# (S
#   Her/PRP$
#   (NP deadbeat/NN)
#   (NP boyfriend/NN)
#   is/VBZ
#   (NP an/DT amalgamation/NN)
#   of/IN
#   many/JJ
#   things/NNS
#   that/WDT
#   are/VBP
#   collectively/RB
#   considered/VBN
#   very/RB
#   bad/JJ
#   traits/NNS
#   for/IN
#   (NP a/DT male/JJ partner/NN)
#   :/:
#   (NP lazy/NN)
#   ,/,
#   makes/VBZ
#   tasteless/JJ
#   jokes/NNS
#   about/IN
#   her/PRP$
#   in/IN
#   (NP front/NN)
#   of/IN
#   their/PRP$
#   friends/NNS
#   ,/,
#   does/VBZ
#   n't/RB
#   pay/VB
#   (NP attention/NN)
#   to/TO
#   her/PRP$
#   feelings/NNS
#   and/CC
#   needs/NNS
#   and/CC
#   ,/,
#   (/(
#   shocking/VBG
#   )/)
#   ,/,
#   leaves/VBZ
#   her/PRP$
#   (NP behind/NN)
#   on/IN
#   her/PRP$
#   (NP birthday/NN)
#   ,/,
#   to/TO
#   go/VB
#   see/VB
#   (NP a/DT place/NN)
#   they/PRP
#   had/VBD
#   previously/RB
#   agreed/VBN
#   to/TO
#   go/VB
#   to/TO
#   together/RB
#   ./.)
# (S
#   He/PRP
#   also/RB
#   seems/VBZ
#   very/RB
#   indifferent/JJ
#   to/TO
#   her/PRP$
#   sexual/JJ
#   desires/NNS
#   ,/,
#   and/CC
#   this/DT
#   is/VBZ
#   (NP the/DT crucial/JJ part/NN)
#   I/PRP
#   'll/MD
#   get/VB
#   to/TO
#   shortly/RB
#   ./.)
# (S
#   So/RB
#   far/RB
#   ,/,
#   very/RB
#   (NP generic/JJ romantic/JJ movie/NN)
#   (NP stuff/NN)
#   ./.)
# (S
#   (NP The/DT next/JJ step/NN)
#   we/PRP
#   (NP the/DT audience/NN)
#   expect/VBP
#   is/VBZ
#   for/IN
#   (NP a/DT knight/NN)
#   in/IN
#   (NP shiny/JJ armor/NN)
#   to/TO
#   appear/VB
#   and/CC
#   save/VB
#   her/PRP
#   from/IN
#   (NP the/DT dead/JJ relationship/NN)
#   ,/,
#   but/CC
#   this/DT
#   is/VBZ
#   where/WRB
#   (NP the/DT normal/JJ movie/NN)
#   (NP stuff/NN)
#   ends/VBZ
#   :/:
#   her/PRP$
#   savior/JJ
#   just/RB
#   outright/MD
#   kidnaps/NNS
#   and/CC
#   threatens/VBZ
#   her/PRP
#   ./.)
# (S
#   He/PRP
#   takes/VBZ
#   her/PRP
#   to/TO
#   his/PRP$
#   (NP house/NN)
#   and/CC
#   does/VBZ
#   n't/RB
#   allow/VB
#   her/PRP
#   to/TO
#   leave/VB
#   ./.)
# (S
#   (NP This/DT dangerous/JJ criminal/NN)
#   turns/VBZ
#   out/RP
#   to/TO
#   be/VB
#   an/DT
#   extremely/RB
#   (NP dominating/JJ man/NN)
#   ./.)
# (S
#   He/PRP
#   grabs/VBD
#   her/PRP
#   violently/RB
#   ,/,
#   thrashes/VBZ
#   her/PRP$
#   (NP around/NN)
#   and/CC
#   menacingly/RB
#   states/NNS
#   that/IN
#   she/PRP
#   will/MD
#   cave/VB
#   in/IN
#   to/TO
#   him/PRP
#   ./.)
# (S He/PRP also/RB turns/VBZ out/RP to/TO be/VB very/RB rich/JJ ./.)
# (S He/PRP lives/VBZ in/IN (NP a/DT gigantic/JJ castle/NN) ./.)
# (S
#   He/PRP
#   takes/VBZ
#   her/PRP
#   to/TO
#   shop/VB
#   for/IN
#   expensive/JJ
#   clothes/NNS
#   in/IN
#   luxurious/JJ
#   stores/NNS
#   ,/,
#   gives/VBZ
#   her/PRP$
#   refined/JJ
#   dinners/NNS
#   and/CC
#   procures/VBZ
#   any/DT
#   dish/JJ
#   she/PRP
#   desires/VBZ
#   ./.)
# (S
#   He/PRP
#   is/VBZ
#   also/RB
#   tall/JJ
#   ,/,
#   muscular/JJ
#   ,/,
#   with/IN
#   (NP a/DT gruff/JJ beard/NN)
#   and/CC
#   (NP a/DT generous/JJ amount/NN)
#   of/IN
#   (NP chest/NN)
#   (NP hair/NN)
#   ./.)
# (S
#   Even/RB
#   when/WRB
#   she/PRP
#   tries/VBZ
#   to/TO
#   tease/VB
#   him/PRP
#   and/CC
#   gain/VB
#   (NP the/DT upper/JJ hand/NN)
#   ,/,
#   he/PRP
#   turns/VBZ
#   the/DT
#   tables/NNS
#   and/CC
#   subdues/VBZ
#   her/PRP
#   ./.)
# (S
#   He/PRP
#   is/VBZ
#   ,/,
#   by/IN
#   and/CC
#   large/JJ
#   ,/,
#   (NP the/DT textbook/NN)
#   (NP definition/NN)
#   of/IN
#   (NP an/DT alpha/JJ male/NN)
#   ./.)
# (S
#   When/WRB
#   she/PRP
#   tries/VBZ
#   to/TO
#   make/VB
#   him/PRP
#   feel/VB
#   jealous/JJ
#   by/IN
#   dancing/VBG
#   with/IN
#   (NP another/DT man/NN)
#   in/IN
#   (NP a/DT nightclub/NN)
#   ,/,
#   our/PRP$
#   (NP hero/NN)
#   responds/NNS
#   by/IN
#   shooting/VBG
#   (NP the/DT offender/NN)
#   in/IN
#   the/DT
#   hands/NNS
#   ,/,
#   and/CC
#   frowning/VBG
#   at/IN
#   her/PRP$
#   until/IN
#   she/PRP
#   apologizes/VBZ
#   ./.)
# (S
#   And/CC
#   when/WRB
#   they/PRP
#   finally/RB
#   make/VBP
#   (NP love/NN)
#   ,/,
#   it/PRP
#   is/VBZ
#   implied/VBN
#   that/IN
#   it/PRP
#   was/VBD
#   (NP everything/NN)
#   she/PRP
#   ever/RB
#   hoped/VBD
#   for/IN
#   -/:
#   he/PRP
#   makes/VBZ
#   her/PRP
#   feel/VB
#   like/IN
#   a/DT
#   Woman/NNP
#   ,/,
#   (NP dammit/NN)
#   ./.)
# (S
#   This/DT
#   is/VBZ
#   (NP the/DT moment/NN)
#   when/WRB
#   (NP something/NN)
#   clicks/NNS
#   in/IN
#   your/PRP$
#   (NP mind/NN)
#   ./.)
# (S
#   (NP This/DT movie/NN)
#   takes/VBZ
#   (NP a/DT lot/NN)
#   of/IN
#   influences/NNS
#   from/IN
#   50/CD
#   Shades/NNS
#   ,/,
#   but/CC
#   they/PRP
#   did/VBD
#   n't/RB
#   come/VBN
#   from/IN
#   nowhere/RB
#   ./.)
# (S Let/VB 's/PRP get/VB (NP a/DT little/JJ dirty/NN) here/RB ./.)
# (S
#   How/WRB
#   many/JJ
#   of/IN
#   us/PRP
#   here/RB
#   have/VBP
#   played/VBN
#   ,/,
#   or/CC
#   heard/VB
#   about/IN
#   (NP someone/NN)
#   who/WP
#   plays/VBZ
#   ,/,
#   fetishes/NNS
#   and/CC
#   fantasies/NNS
#   with/IN
#   their/PRP$
#   SOs/NNP
#   ,/,
#   and/CC
#   how/WRB
#   many/JJ
#   of/IN
#   those/DT
#   fantasies/NNS
#   usually/RB
#   include/VBP
#   popular/JJ
#   ,/,
#   silly/RB
#   scenarios/NNS
#   like/IN
#   (NP the/DT boyfriend/husband/NN)
#   (NP roleplaying/NN)
#   as/IN
#   (NP a/DT police/NN)
#   (NP officer/NN)
#   ,/,
#   catching/VBG
#   (NP the/DT bandit/NN)
#   played/VBN
#   by/IN
#   (NP the/DT wife/girlfriend/NN)
#   ,/,
#   and/CC
#   taking/VBG
#   her/PRP$
#   into/IN
#   (NP custody/NN)
#   for/IN
#   ``/``
#   (NP interrogation/NN)
#   and/CC
#   (NP full/JJ body/NN)
#   (NP search/NN)
#   ''/''
#   ?/.)
# (S Then/RB it/PRP hits/VBZ you/PRP ./.)
# (S
#   (NP This/DT movie/NN)
#   does/VBZ
#   n't/RB
#   make/VB
#   (NP logical/JJ sense/NN)
#   because/IN
#   it/PRP
#   does/VBZ
#   n't/RB
#   have/VB
#   to/TO
#   ./.)
# (S
#   It/PRP
#   's/VBZ
#   just/RB
#   two/CD
#   hours/NNS
#   of/IN
#   (NP a/DT bland/NN)
#   ,/,
#   (NP female/JJ lead/NN)
#   who/WP
#   's/VBZ
#   (NP a/DT stand/NN)
#   in/IN
#   for/IN
#   (NP the/DT woman/NN)
#   watching/VBG
#   (NP the/DT movie/NN)
#   ,/,
#   and/CC
#   living/VBG
#   the/DT
#   fantastic/JJ
#   ,/,
#   (NP outlandish/JJ fantasy/NN)
#   that/IN
#   I/PRP
#   suppose/VBP
#   many/JJ
#   girls/NNS
#   and/CC
#   women/NNS
#   out/RP
#   there/RB
#   enjoy/VB
#   thinking/VBG
#   about/IN
#   :/:
#   being/VBG
#   seduced/VBN
#   and/CC
#   dominated/VBN
#   by/IN
#   an/DT
#   otherwordly/RB
#   (NP alpha/JJ male/NN)
#   who/WP
#   then/RB
#   vigorously/RB
#   sates/VBZ
#   their/PRP$
#   sexual/JJ
#   desires/NNS
#   ./.)
# (S
#   (NP This/DT movie/NN)
#   just/RB
#   uses/VBZ
#   a/DT
#   ``/``
#   girl/JJ
#   gets/VBZ
#   kidnapped/VBN
#   ''/''
#   (NP scenario/NN)
#   ,/,
#   50/CD
#   Shades/NNP
#   simply/RB
#   went/VBD
#   the/DT
#   more/RBR
#   (NP niche/JJ route/NN)
#   with/IN
#   BDSM/NNP
#   ./.)
# (S
#   (NP Simple/NN)
#   ,/,
#   nonsensical/JJ
#   plots/NNS
#   that/WDT
#   serve/VBP
#   purely/RB
#   to/TO
#   let/VB
#   the/DT
#   female/JJ
#   viewers/NNS
#   vicariously/RB
#   live/VBP
#   (NP a/DT sexual/JJ fantasy.I/NN)
#   'm/VBP
#   going/VBG
#   to/TO
#   say/VB
#   it/PRP
#   out/RP
#   loud/JJ
#   :/:
#   this/DT
#   is/VBZ
#   (NP a/DT porn/JJ movie/NN)
#   ./.)
# (S It/PRP 's/VBZ (NP a/DT porno/NN) made/VBN for/IN women/NNS ./.)
# (S
#   And/CC
#   there/EX
#   is/VBZ
#   absolutely/RB
#   (NP nothing/NN)
#   wrong/JJ
#   with/IN
#   this/DT
#   ./.)
# (S
#   This/DT
#   is/VBZ
#   (NP nothing/NN)
#   more/JJR
#   than/IN
#   (NP a/DT pure/NN)
#   ,/,
#   (NP sexual/JJ guilty/JJ pleasure/NN)
#   that/WDT
#   obviously/RB
#   would/MD
#   never/RB
#   work/VB
#   in/IN
#   (NP the/DT real/JJ world/NN)
#   ./.)
# (S
#   Nothing/VBG
#   different/JJ
#   from/IN
#   a/DT
#   ``/``
#   traditional/JJ
#   ''/''
#   (NP porn/JJ movie/NN)
#   ./.)
# (S
#   (NP The/DT only/JJ real/JJ difference/NN)
#   is/VBZ
#   the/DT
#   public/JJ
#   it/PRP
#   is/VBZ
#   aimed/VBN
#   at/IN
#   ./.)
# (S
#   (NP A/DT normal/JJ porn/JJ movie/NN)
#   for/IN
#   men/NNS
#   is/VBZ
#   going/VBG
#   to/TO
#   cater/VB
#   to/TO
#   men/NNS
#   's/POS
#   fantasies/NNS
#   :/:
#   ludicrous/JJ
#   setups/NNS
#   ,/,
#   gorgeous/JJ
#   women/NNS
#   gladly/RB
#   doing/VBG
#   (NP everything/NN)
#   (NP the/DT man/NN)
#   demands/VBZ
#   ,/,
#   explicit/JJ
#   images/NNS
#   of/IN
#   (NP intercourse/NN)
#   ./.)
# (S
#   (NP This/DT porn/JJ movie/NN)
#   (/(
#   and/CC
#   50/CD
#   Shades/NNS
#   as/RB
#   well/RB
#   )/)
#   caters/NNS
#   to/TO
#   fantasies/NNS
#   that/WDT
#   are/VBP
#   more/JJR
#   common/JJ
#   for/IN
#   many/JJ
#   women/NNS
#   :/:
#   a/DT
#   strong/JJ
#   ,/,
#   dominating/VBG
#   (NP male/JJ figure/NN)
#   that/WDT
#   takes/VBZ
#   them/PRP
#   on/IN
#   expensive/JJ
#   trips/NNS
#   to/TO
#   majestic/JJ
#   locations/NNS
#   and/CC
#   is/VBZ
#   completely/RB
#   focused/VBN
#   on/IN
#   pleasuring/VBG
#   (NP the/DT woman/NN)
#   ,/,
#   not/RB
#   himself/PRP
#   ./.)
# (S
#   (NP The/DT only/JJ thing/NN)
#   (NP this/DT movie/NN)
#   really/RB
#   does/VBZ
#   wrong/JJ
#   at/IN
#   (NP this/DT point/NN)
#   is/VBZ
#   being/VBG
#   marketed/VBN
#   as/IN
#   a/DT
#   normal/JJ
#   ,/,
#   (NP traditional/JJ movie/NN)
#   when/WRB
#   it/PRP
#   so/RB
#   clearly/RB
#   is/VBZ
#   not/RB
#   ./.)
# (S
#   If/IN
#   you/PRP
#   are/VBP
#   (NP a/DT woman/NN)
#   ,/,
#   you/PRP
#   are/VBP
#   probably/RB
#   going/VBG
#   to/TO
#   enjoy/VB
#   living/VBG
#   (NP this/DT fantasy/NN)
#   ,/,
#   and/CC
#   there/EX
#   is/VBZ
#   (NP no/DT shame/NN)
#   in/IN
#   that/DT
#   ./.)
# (S
#   It/PRP
#   just/RB
#   makes/VBZ
#   me/PRP
#   realize/VB
#   how/WRB
#   grossly/RB
#   biased/VBD
#   (NP the/DT movie/NN)
#   (NP industry/NN)
#   is/VBZ
#   when/WRB
#   it/PRP
#   comes/VBZ
#   to/TO
#   porn/VB
#   :/:
#   we/PRP
#   are/VBP
#   okay/JJ
#   with/IN
#   all/PDT
#   the/DT
#   millions/NNS
#   of/IN
#   (NP silly/JJ porno/NN)
#   flicks/NNS
#   and/CC
#   videos/NNS
#   aimed/VBN
#   at/IN
#   men/NNS
#   ,/,
#   but/CC
#   when/WRB
#   we/PRP
#   see/VBP
#   (NP a/DT silly/JJ sexual/JJ fetish/JJ movie/NN)
#   aimed/VBN
#   at/IN
#   women/NNS
#   ,/,
#   the/DT
#   moviegoing/VBG
#   public/JJ
#   collectively/RB
#   pops/VBP
#   their/PRP$
#   monocles/NNS
#   in/IN
#   (NP outrage.I/NN)
#   watched/VBD
#   (NP this/DT movie/NN)
#   with/IN
#   my/PRP$
#   (NP wife/NN)
#   and/CC
#   while/IN
#   we/PRP
#   were/VBD
#   trying/VBG
#   to/TO
#   take/VB
#   it/PRP
#   seriously/RB
#   ,/,
#   we/PRP
#   both/DT
#   complained/VBD
#   how/WRB
#   bizarre/JJ
#   (NP the/DT plot/NN)
#   is/VBZ
#   ./.)
# (S
#   But/CC
#   once/RB
#   we/PRP
#   understand/VBP
#   what/WP
#   is/VBZ
#   actually/RB
#   at/IN
#   (NP play/NN)
#   here/RB
#   ,/,
#   we/PRP
#   see/VBP
#   it/PRP
#   in/IN
#   (NP a/DT whole/JJ different/JJ light/NN)
#   ./.)
# (S
#   This/DT
#   is/VBZ
#   (NP a/DT porn/JJ movie/NN)
#   ,/,
#   and/CC
#   do/VBP
#   n't/RB
#   let/VB
#   (NP the/DT lack/NN)
#   of/IN
#   (NP explicit/JJ imagery/NN)
#   (NP fool/NN)
#   you/PRP
#   (/(
#   there/EX
#   is/VBZ
#   lots/NNS
#   of/IN
#   (NP nudity/NN)
#   however/RB
#   ,/,
#   so/IN
#   beware/JJ
#   )/)
#   ./.)
# (S
#   If/IN
#   you/PRP
#   are/VBP
#   still/RB
#   not/RB
#   convinced/VBN
#   and/CC
#   will/MD
#   still/RB
#   watch/VB
#   it/PRP
#   thinking/VBG
#   it/PRP
#   is/VBZ
#   a/DT
#   ``/``
#   traditional/JJ
#   ''/''
#   (NP movie/NN)
#   ,/,
#   do/VBP
#   n't/RB
#   bother/VB
#   ,/,
#   and/CC
#   save/VB
#   (NP the/DT disappointment/NN)
#   ./.)
# (S
#   If/IN
#   ,/,
#   however/RB
#   ,/,
#   you/PRP
#   understand/VBP
#   and/CC
#   accept/VBP
#   it/PRP
#   for/IN
#   what/WP
#   it/PRP
#   is/VBZ
#   ,/,
#   then/RB
#   go/VB
#   ahead/RB
#   at/IN
#   (NP enjoy/NN)
#   it/PRP
#   ./.)
# (S (NP The/DT plot/NN) was/VBD (NP trash/NN) ./.)
# (S
#   Even/RB
#   fifty/JJ
#   shades/NNS
#   (NP series/NN)
#   had/VBD
#   better/JJR
#   plots/NNS
#   than/IN
#   this/DT
#   ./.)
# (S
#   Things/NNS
#   happen/VBP
#   out/IN
#   of/IN
#   nowhere/RB
#   ,/,
#   I/PRP
#   was/VBD
#   confused/VBN
#   (NP the/DT whole/JJ time/NN)
#   watching/VBG
#   (NP this/DT movie/NN)
#   ./.)
# (S
#   Could/MD
#   n't/RB
#   even/RB
#   get/VB
#   myself/PRP
#   to/TO
#   finish/VB
#   (NP watching/NN)
#   till/IN
#   (NP the/DT end/NN))
# (S
#   Wow/NNP
#   ,/,
#   how/WRB
#   (NP corny/NN)
#   can/MD
#   (NP a/DT movie/NN)
#   (NP get/NN)
#   and/CC
#   what/WDT
#   were/VBD
#   they/PRP
#   thinking/VBG
#   ,/,
#   it/PRP
#   's/VBZ
#   so/RB
#   corny/JJ
#   it/PRP
#   can/MD
#   be/VB
#   rated/VBN
#   as/IN
#   (NP a/DT comedy/NN)
#   (NP movie/NN)
#   ./.)
# (S
#   They/PRP
#   collected/VBD
#   (NP every/DT cliche/NN)
#   from/IN
#   (NP the/DT book/NN)
#   of/IN
#   (NP cringe/NN)
#   and/CC
#   (NP romance/NN)
#   and/CC
#   shoved/VBD
#   them/PRP
#   in/IN
#   (NP a/DT movie/NN)
#   ./.)
# (S
#   I/PRP
#   ca/MD
#   n't/RB
#   even/RB
#   humor/VB
#   (NP the/DT movie/NN)
#   by/IN
#   listing/VBG
#   the/DT
#   things/NNS
#   that/WDT
#   are/VBP
#   bad/JJ
#   with/IN
#   it/PRP
#   ,/,
#   does/VBZ
#   n't/RB
#   even/RB
#   deserve/VB
#   (NP the/DT time/NN)
#   or/CC
#   (NP effort/NN)
#   ,/,
#   the/DT
#   two/CD
#   hours/NNS
#   I/PRP
#   wasted/VBD
#   watching/VBG
#   it/PRP
#   were/VBD
#   more/JJR
#   than/IN
#   enough/RB
#   ./.)
# (S
#   Probably/RB
#   one/CD
#   of/IN
#   the/DT
#   worst/JJS
#   movies/NNS
#   of/IN
#   (NP the/DT century/NN)
#   so/RB
#   far/RB)
# (S
#   Seriously/RB
#   I/PRP
#   am/VBP
#   not/RB
#   politically/RB
#   correct/JJ
#   woke/VBD
#   or/CC
#   outraged/VBD
#   person.But/IN
#   (NP the/DT idea/NN)
#   that/IN
#   (NP a/DT scumbag/NN)
#   (NP mafia/NN)
#   (NP guy/NN)
#   ,/,
#   is/VBZ
#   going/VBG
#   to/TO
#   sexually/RB
#   assault/VB
#   his/PRP$
#   (NP way/NN)
#   into/IN
#   (NP a/DT woman/NN)
#   's/POS
#   (NP heart/NN)
#   is/VBZ
#   just/RB
#   absurd/JJ
#   ./.)
# (S
#   (NP The/DT sopranos/NN)
#   was/VBD
#   good/JJ
#   ,/,
#   but/CC
#   Christopher/NNP
#   Moltisante/NNP
#   's/POS
#   ``/``
#   Cleaver/NNP
#   ''/''
#   (NP script/NN)
#   within/IN
#   it/PRP
#   was/VBD
#   there/EX
#   to/TO
#   be/VB
#   mocked/VBN
#   and/CC
#   it/PRP
#   appears/VBZ
#   that/IN
#   that/IN
#   the/DT
#   makers/NNS
#   of/IN
#   (NP this/DT film/NN)
#   are/VBP
#   so/RB
#   stupid/JJ
#   as/IN
#   to/TO
#   not/RB
#   realize/VB
#   this/DT
#   ./.)
# (S
#   Exactly/RB
#   what/WP
#   attributes/VBZ
#   does/VBZ
#   (NP this/DT mafia/NN)
#   (NP leader/NN)
#   have/VB
#   ?/.)
# (S
#   He/PRP
#   has/VBZ
#   (NP brutishness/NN)
#   ,/,
#   but/CC
#   he/PRP
#   has/VBZ
#   (NP no/DT cunning/NN)
#   ,/,
#   (NP no/DT leadership/NN)
#   skills/NNS
#   ,/,
#   and/CC
#   is/VBZ
#   not/RB
#   credible/JJ
#   as/IN
#   (NP someone/NN)
#   who/WP
#   would/MD
#   rise/VB
#   through/IN
#   the/DT
#   ranks/NNS
#   in/IN
#   (NP anything/NN)
#   ,/,
#   including/VBG
#   organized/VBN
#   (NP crime/NN)
#   ./.)
# (S
#   He/PRP
#   is/VBZ
#   about/RB
#   as/RB
#   sexy/JJ
#   as/IN
#   (NP a/DT toad.The/NN)
#   (NP acting/NN)
#   ,/,
#   (NP dialogue/NN)
#   ,/,
#   (NP plot/NN)
#   and/CC
#   (NP cinematography/NN)
#   are/VBP
#   just/RB
#   amazingly/RB
#   bad/JJ
#   and/CC
#   cringe-worthy/JJ
#   ./.)
# (S
#   The/DT
#   makers/NNS
#   of/IN
#   (NP this/DT spent/NN)
#   more/JJR
#   (NP time/NN)
#   shilling/VBG
#   (NP the/DT review/NN)
#   (NP section/NN)
#   here/RB
#   than/IN
#   they/PRP
#   did/VBD
#   writing/VBG
#   (NP this/DT junk/NN)
#   ./.)
# (S
#   Such/JJ
#   (NP a/DT rip/NN)
#   off/IN
#   from/IN
#   fifty/JJ
#   shades/NNS
#   of/IN
#   (NP grey/NN)
#   ./.)
# (S
#   (NP The/DT plot/NN)
#   and/CC
#   (NP character/NN)
#   (NP development/NN)
#   is/VBZ
#   all/DT
#   over/IN
#   (NP the/DT place/NN)
#   ./.)
# (S
#   Some/DT
#   things/NNS
#   did/VBD
#   n't/RB
#   make/VB
#   (NP any/DT sense/NN)
#   at/IN
#   all/DT
#   ./.)
# (S The/DT ending/VBG was/VBD horrible/JJ ./.)
# (S Where/WRB 's/POS my/PRP$ 2/CD hours/NNS gone/VBN ?/.)
# (S
#   (NP This/DT movie/NN)
#   made/VBD
#   me/PRP
#   laugh/IN
#   so/RB
#   hard/JJ
#   I/PRP
#   almost/RB
#   peed/VBD
#   myself/PRP
#   ./.)
# (S
#   Pretty/RB
#   sure/JJ
#   it/PRP
#   's/VBZ
#   not/RB
#   supposed/VBN
#   to/TO
#   be/VB
#   (NP a/DT comedy/NN)
#   (NP tho/NN)
#   .../:)
# (S
#   I/PRP
#   've/VBP
#   never/RB
#   seen/VBN
#   (NP a/DT movie/NN)
#   that/IN
#   bad/JJ
#   ./.)
# (S Could/MD n't/RB even/RB finish/VB it/PRP ./.)
# (S This/DT is/VBZ such/JJ (NP a/DT horrible/JJ movie/NN) ./.)
# (S
#   I/PRP
#   do/VBP
#   not/RB
#   understand/VB
#   how/WRB
#   it/PRP
#   's/VBZ
#   at/IN
#   (NP the/DT top/NN)
#   on/IN
#   my/PRP$
#   (NP list/NN)
#   on/IN
#   Netflix/NNP
#   ?/.)
# (S Crazy/NNP ./.)
# (S
#   I/PRP
#   just/RB
#   created/VBD
#   (NP an/DT account/NN)
#   just/RB
#   to/TO
#   review/VB
#   how/WRB
#   horrible/JJ
#   (NP this/DT movie/NN)
#   is/VBZ
#   ./.)
# (S
#   I/PRP
#   agree/VBP
#   with/IN
#   all/PDT
#   the/DT
#   bad/JJ
#   ratings/NNS
#   that/IN
#   other/JJ
#   users/NNS
#   have/VBP
#   posted/VBN
#   ./.)
# (S
#   I/PRP
#   'm/VBP
#   not/RB
#   sure/JJ
#   if/IN
#   this/DT
#   is/VBZ
#   what/WP
#   they/PRP
#   think/VBP
#   women/NNS
#   want/VBP
#   and/CC
#   I/PRP
#   guess/VBP
#   you/PRP
#   would/MD
#   consider/VB
#   this/DT
#   to/TO
#   be/VB
#   like/IN
#   (NP every/DT woman/NN)
#   's/POS
#   (NP wet/JJ dream/NN)
#   ?/.)
# (S
#   But/CC
#   there/EX
#   's/VBZ
#   (NP no/DT plot/NN)
#   ,/,
#   (NP the/DT dialogue/NN)
#   is/VBZ
#   terrible/JJ
#   ,/,
#   and/CC
#   sure/JJ
#   women/NNS
#   like/IN
#   being/VBG
#   dominated/VBN
#   from/IN
#   (NP time/NN)
#   to/TO
#   (NP time/NN)
#   but/CC
#   not/RB
#   to/TO
#   (NP that/DT extreme/NN)
#   and/CC
#   (NP the/DT guy/NN)
#   is/VBZ
#   n't/RB
#   even/RB
#   sweet/VB
#   or/CC
#   gentle/VB
#   as/IN
#   he/PRP
#   claims/VBZ
#   ./.)
# (S
#   He/PRP
#   is/VBZ
#   only/RB
#   sweet/JJ
#   or/CC
#   gentle/JJ
#   after/IN
#   he/PRP
#   gets/VBZ
#   his/PRP$
#   and/CC
#   i/VB
#   feel/VBP
#   like/IN
#   that/DT
#   's/VBZ
#   (NP kind/NN)
#   of/IN
#   backwards/NNS
#   ./.)
# (S
#   I/PRP
#   felt/VBP
#   like/IN
#   I/PRP
#   was/VBD
#   just/RB
#   watching/VBG
#   porn/JJ
#   and/CC
#   that/DT
#   's/VBZ
#   it/PRP
#   ./.)
# (S
#   I/PRP
#   did/VBD
#   enjoy/VB
#   (NP the/DT main/JJ actress/NN)
#   ,/,
#   I/PRP
#   think/VBP
#   she/PRP
#   is/VBZ
#   just/RB
#   stunning/JJ
#   but/CC
#   I/PRP
#   found/VBD
#   it/PRP
#   funny/VBZ
#   how/WRB
#   they/PRP
#   kept/VBD
#   putting/VBG
#   her/PRP$
#   in/IN
#   (NP the/DT same/JJ low/JJ cut/NN)
#   (NP black/JJ dress/NN)
#   with/IN
#   (NP the/DT same/JJ hair/NN)
#   ./.)
# (S
#   */JJ
#   Spoiler/NNP
#   (NP */NN)
#   When/WRB
#   it/PRP
#   came/VBD
#   to/TO
#   (NP the/DT ball/NN)
#   (NP scene/NN)
#   ,/,
#   I/PRP
#   expected/VBD
#   a/DT
#   even/RB
#   more/RBR
#   (NP beautiful/JJ transformation/NN)
#   with/IN
#   (NP a/DT flashy/JJ dress/NN)
#   and/CC
#   (NP hair/NN)
#   done/VBN
#   but/CC
#   nope/JJ
#   ../NNP
#   just/RB
#   stuck/VBD
#   to/TO
#   (NP the/DT same/JJ style/NN)
#   she/PRP
#   's/VBZ
#   been/VBN
#   wearing/VBG
#   ./.)
# (S
#   Another/DT
#   */NNP
#   Spoiler/NNP
#   (NP */NN)
#   when/WRB
#   she/PRP
#   falls/VBZ
#   in/IN
#   (NP love/NN)
#   (NP ../NN)
#   what/WP
#   is/VBZ
#   she/PRP
#   falling/VBG
#   in/IN
#   (NP love/NN)
#   with/IN
#   ?/.)
# (S
#   He/PRP
#   has/VBZ
#   n't/RB
#   done/VBN
#   (NP anything/NN)
#   redeeming/VBG
#   nor/CC
#   has/VBZ
#   (NP a/DT redeeming/JJ quality/NN)
#   ./.)
# (S
#   Do/VBP
#   n't/RB
#   confuse/VB
#   lust/JJ
#   and/CC
#   (NP good/JJ sex/NN)
#   with/IN
#   (NP love/NN)
#   ./.)
# (S
#   (NP This/DT movie/NN)
#   is/VBZ
#   just/RB
#   unbelievable/JJ
#   stupid/JJ
#   ,/,
#   2/CD
#   (NP hrs/NN)
#   of/IN
#   it/PRP)
# (S Such/JJ (NP a/DT waste/NN) of/IN (NP time/NN) ./.)
# (S
#   How/WRB
#   did/VBD
#   Netflix/NNP
#   even/RB
#   pick/VBP
#   (NP this/DT movie/NN)
#   up/RP)
# (S
#   I/PRP
#   do/VBP
#   n't/RB
#   know/VB
#   how/WRB
#   (NP a/DT person/NN)
#   can/MD
#   make/VB
#   (NP this/DT cheap/JJ movie/NN)
#   ?/.)
# (S it/PRP 's/VBZ embarrassing/VBG)
# (S
#   (NP An/DT Italian/Polish/JJ version/NN)
#   of/IN
#   50/CD
#   Shades/NNS
#   on/IN
#   (NP crack/NN)
#   .../:
#   who/WP
#   falls/VBZ
#   in/IN
#   (NP love/NN)
#   with/IN
#   their/PRP$
#   (NP captor/NN)
#   and/CC
#   gets/VBZ
#   married/VBN
#   in/IN
#   2/CD
#   months/NNS
#   and/CC
#   pregnant/VB
#   ?/.
#   ?/.)
# (S
#   The/DT
#   best/JJS
#   (NP view/NN)
#   is/VBZ
#   (NP the/DT scenery/NN)
#   in/IN
#   (NP the/DT background/NN)
#   ./.)
# (S Not/RB including/VBG some/DT guys/NNS ass/VBP closeups/NNS ./.)
# (S
#   (NP The/DT script/NN)
#   is/VBZ
#   laughable/JJ
#   and/CC
#   (NP the/DT acting/NN)
#   (/(
#   often/RB
#   (NP voice-over/NN)
#   )/)
#   ,/,
#   too/RB
#   ./.)
# (S The/DT 3D/CD (NP sex/NN) is/VBZ well/RB marketed/VBN ./.)
# (S
#   And/CC
#   yes/UH
#   ,/,
#   during/IN
#   certain/JJ
#   scenes/NNS
#   people/NNS
#   got/VBD
#   up/RB
#   and/CC
#   left/VBD
#   ./.)
# (S Yet/RB ./.)
# (S
#   (NP The/DT film/NN)
#   does/VBZ
#   n't/RB
#   argue/VB
#   to/TO
#   be/VB
#   (NP anything/NN)
#   beyond/IN
#   (NP a/DT meandering/NN)
#   (NP stroll/NN)
#   into/IN
#   the/DT
#   gallows/NNS
#   (NP melancholy/NN)
#   ./.)
# (S And/CC it/PRP does/VBZ this/DT very/RB very/RB well/RB ./.)
# (S
#   (NP The/DT film/NN)
#   features/VBZ
#   (NP no/DT highbrow/NN)
#   intellectual/JJ
#   conversations/NNS
#   but/CC
#   instead/RB
#   ,/,
#   favors/VBZ
#   the/DT
#   same/JJ
#   lines/NNS
#   you/PRP
#   've/VBP
#   probably/RB
#   slung/VBN
#   at/IN
#   your/PRP$
#   lovers/NNS
#   ./.)
# (S Again/RB and/CC again/RB and/CC again/RB ./.)
# (S
#   Just/RB
#   like/IN
#   (NP the/DT sex/NN)
#   you/PRP
#   've/VBP
#   had/VBN
#   with/IN
#   your/PRP$
#   lovers/NNS
#   again/RB
#   and/CC
#   again/RB
#   and/CC
#   again/RB
#   ./.)
# (S
#   You/PRP
#   know/VBP
#   their/PRP$
#   bodies/NNS
#   and/CC
#   you/PRP
#   know/VBP
#   how/WRB
#   to/TO
#   please/VB
#   them/PRP
#   and/CC
#   above/IN
#   all/DT
#   ,/,
#   you/PRP
#   know/VBP
#   how/WRB
#   to/TO
#   hurt/VB
#   them/PRP
#   ./.)
# (S Sorrow/NNP ./.)
# (S
#   There/EX
#   's/VBZ
#   (NP a/DT resplendent/JJ simplicity/NN)
#   here/RB
#   that/IN
#   hypnotizes/VBZ
#   (NP the/DT viewer.You/NN)
#   hear/VBP
#   (NP music/NN)
#   (NP banging/NN)
#   inside/IN
#   (NP the/DT club/NN)
#   ,/,
#   yet/CC
#   the/DT
#   lovers/NNS
#   are/VBP
#   outside/JJ
#   in/IN
#   (NP halflight/NN)
#   ./.)
# (S Having/VBG (NP sex/NN) ,/, obviously/RB ./.)
# (S
#   This/DT
#   is/VBZ
#   (NP a/DT good/JJ image/NN)
#   of/IN
#   what/WP
#   (NP this/DT film/NN)
#   surprisingly/RB
#   achieves/VBZ
#   best/JJS
#   :/:
#   (NP intimacy/NN)
#   ./.)
# (S
#   And/CC
#   it/PRP
#   fights/VBZ
#   for/IN
#   that/DT
#   with/IN
#   it/PRP
#   's/VBZ
#   (NP magnificent/JJ camera-work/NN)
#   and/CC
#   editing.But/VB
#   what/WP
#   would/MD
#   (NP this/DT review/NN)
#   be/VB
#   if/IN
#   it/PRP
#   did/VBD
#   n't/RB
#   talk/VB
#   about/IN
#   the/DT
#   3D/CD
#   (NP sex/NN)
#   ?/.)
# (S Love/NNP and/CC (NP cinema/NN) are/VBP inseparable/JJ ./.)
# (S
#   Love/NNP
#   stories/NNS
#   are/VBP
#   why/WRB
#   you/PRP
#   stick/VBP
#   glued/VBN
#   to/TO
#   (NP a/DT chair/NN)
#   for/IN
#   (NP a/DT couple/NN)
#   of/IN
#   hours/NNS
#   ./.)
# (S
#   Raw/NNP
#   (NP sex/NN)
#   is/VBZ
#   (NP part/NN)
#   of/IN
#   (NP love/NN)
#   ,/,
#   yet/RB
#   ,/,
#   films/NNS
#   used/VBD
#   to/TO
#   cut/VB
#   to/TO
#   birds/NNS
#   necking/VBG
#   after/IN
#   (NP a/DT kiss/NN)
#   ./.)
# (S Then/RB it/PRP became/VBD steamy/JJ windows/NNS ./.)
# (S
#   Signs/NNS
#   ,/,
#   metaphors/NNS
#   ,/,
#   analogies/NNS
#   ,/,
#   (NP semiotic/JJ nausea/NN)
#   ./.)
# (S
#   And/CC
#   here/RB
#   ,/,
#   Noé/NNP
#   takes/VBZ
#   that/IN
#   away/RB
#   which/WDT
#   makes/VBZ
#   (NP the/DT film/NN)
#   even/RB
#   coarser/RBR
#   ,/,
#   and/CC
#   ultimately/RB
#   more/RBR
#   brutal.I/JJ
#   wanted/VBD
#   to/TO
#   write/VB
#   (NP this/DT review/NN)
#   because/IN
#   (NP the/DT whole/JJ marketing/NN)
#   (/(
#   ``/``
#   finally/RB
#   (NP a/DT love/NN)
#   (NP story/NN)
#   restricted/VBN
#   for/IN
#   (NP -16/NN)
#   )/)
#   and/CC
#   (NP shock/NN)
#   (NP value/NN)
#   (/(
#   (NP an/DT eye-rolling/NN)
#   (NP warning/NN)
#   in/IN
#   (NP the/DT opening/NN)
#   credits/NNS
#   )/)
#   have/VBP
#   cheapened/VBN
#   what/WP
#   (NP this/DT film/NN)
#   has/VBZ
#   achieved/VBN
#   and/CC
#   I/PRP
#   encourage/VBP
#   viewers/NNS
#   to/TO
#   look/VB
#   beyond/IN
#   ./.)
# (S
#   I/PRP
#   know/VBP
#   I/PRP
#   only/RB
#   rated/VBD
#   it/PRP
#   a/DT
#   seven/CD
#   out/IN
#   of/IN
#   ten/NNS
#   but/CC
#   that/DT
#   's/VBZ
#   because/IN
#   I/PRP
#   admit/VBP
#   (NP this/DT film/NN)
#   's/POS
#   faults/NNS
#   ./.)
# (S
#   It/PRP
#   certainly/RB
#   is/VBZ
#   n't/RB
#   near/JJ
#   perfect/JJ
#   but/CC
#   I/PRP
#   felt/VBD
#   very/RB
#   moved/VBN
#   by/IN
#   the/DT
#   characters/NNS
#   and/CC
#   their/PRP$
#   (NP story/NN)
#   ./.)
# (S
#   Lots/NNS
#   of/IN
#   people/NNS
#   may/MD
#   not/RB
#   be/VB
#   able/JJ
#   to/TO
#   relate/VB
#   to/TO
#   (NP this/DT film/NN)
#   however/RB
#   those/DT
#   of/IN
#   us/PRP
#   that/WDT
#   do/VBP
#   can/MD
#   say/VB
#   that/IN
#   (NP everything/NN)
#   about/IN
#   (NP this/DT depiction/NN)
#   of/IN
#   (NP love/NN)
#   has/VBZ
#   been/VBN
#   experienced/VBN
#   and/CC
#   is/VBZ
#   real/JJ
#   ./.)
# (S
#   As/IN
#   (NP a/DT grown/JJ single/JJ adult/NN)
#   (NP living/NN)
#   in/IN
#   (NP today/NN)
#   's/POS
#   (NP dating/JJ world/NN)
#   I/PRP
#   can/MD
#   attest/VB
#   that/IN
#   (NP the/DT relationship/NN)
#   between/IN
#   Murphy/NNP
#   and/CC
#   Electra/NNP
#   exists/NNS
#   ./.)
# (S
#   Their/PRP$
#   (NP obsession/NN)
#   with/IN
#   each/DT
#   other/JJ
#   and/CC
#   with/IN
#   (NP sex/NN)
#   that/WDT
#   led/VBD
#   them/PRP
#   into/IN
#   a/DT
#   deep/JJ
#   and/CC
#   possibly/RB
#   (NP unreal/JJ infatuation/NN)
#   was/VBD
#   honest/JJ
#   and/CC
#   thought/VBD
#   (NP provoking/NN)
#   ./.)
# (S
#   Love/NNP
#   sometimes/RB
#   does/VBZ
#   n't/RB
#   make/VB
#   (NP sense/NN)
#   and/CC
#   ca/MD
#   n't/RB
#   be/VB
#   described/VBN
#   or/CC
#   made/VBN
#   logical/JJ
#   ./.)
# (S
#   Their/PRP$
#   (NP connection/NN)
#   was/VBD
#   what/WP
#   drove/VB
#   them/PRP
#   into/IN
#   (NP darkness/NN)
#   ,/,
#   (NP madness/NN)
#   and/CC
#   (NP despair/NN)
#   ./.)
# (S
#   Love/NNP
#   is/VBZ
#   completely/RB
#   all/DT
#   consuming/VBG
#   on/IN
#   (NP any/DT level/NN)
#   it/PRP
#   's/VBZ
#   represented/VBN
#   on/IN
#   ./.)
# (S
#   So/RB
#   many/JJ
#   times/NNS
#   have/VBP
#   I/PRP
#   given/VBN
#   myself/PRP
#   up/RP
#   for/IN
#   (NP something/NN)
#   that/IN
#   (NP a/DT year/NN)
#   later/RB
#   I/PRP
#   looked/VBD
#   back/RB
#   on/IN
#   and/CC
#   could/MD
#   n't/RB
#   reconcile/VB
#   my/PRP$
#   (NP behavior/NN)
#   ,/,
#   and/CC
#   so/RB
#   many/JJ
#   times/NNS
#   have/VBP
#   I/PRP
#   given/VBN
#   myself/PRP
#   up/IN
#   to/TO
#   (NP something/NN)
#   to/TO
#   only/RB
#   sabotage/VB
#   it/PRP
#   before/IN
#   it/PRP
#   completely/RB
#   devoured/VBD
#   me/PRP
#   ./.)
# (S
#   I/PRP
#   do/VBP
#   n't/RB
#   know/VB
#   if/IN
#   I/PRP
#   have/VBP
#   been/VBN
#   in/IN
#   (NP love/NN)
#   ,/,
#   but/CC
#   I/PRP
#   have/VBP
#   felt/VBN
#   what/WP
#   these/DT
#   characters/NNS
#   are/VBP
#   going/VBG
#   through/IN
#   and/CC
#   I/PRP
#   would/MD
#   n't/RB
#   know/VB
#   what/WP
#   else/RB
#   to/TO
#   call/VB
#   it/PRP
#   ./.)
# (S
#   In/IN
#   (NP the/DT vein/NN)
#   of/IN
#   Harmony/NNP
#   Korine/NNP
#   and/CC
#   Lars/NNP
#   von/NNP
#   Trier/NNP
#   I/PRP
#   think/VBP
#   Gasper/NNP
#   Noe/NNP
#   is/VBZ
#   (NP a/DT genius/NN)
#   ./.)
# (S
#   Yes/UH
#   (NP this/DT movie/NN)
#   is/VBZ
#   uncomfortable/JJ
#   ,/,
#   yes/VB
#   (NP the/DT acting/NN)
#   is/VBZ
#   n't/RB
#   great/JJ
#   and/CC
#   yes/VB
#   (NP the/DT story/NN)
#   is/VBZ
#   dry/JJ
#   ,/,
#   but/CC
#   it/PRP
#   's/VBZ
#   (NP a/DT genuine/JJ take/NN)
#   on/IN
#   what/WP
#   relationships/NNS
#   look/VBP
#   like/IN
#   for/IN
#   some/DT
#   people/NNS
#   in/IN
#   their/PRP$
#   (NP mid/NN)
#   twenties/NNS
#   to/TO
#   early/JJ
#   thirties/NNS
#   and/CC
#   I/PRP
#   loved/VBD
#   (NP every/DT second/NN)
#   of/IN
#   it/PRP
#   ./.)
# (S I/PRP have/VBP (NP nothing/NN) against/IN (NP sex/NN) ./.)
# (S
#   I/PRP
#   love/VBP
#   it/PRP
#   ,/,
#   I/PRP
#   love/VBP
#   watching/VBG
#   it/PRP
#   but/CC
#   this/DT
#   was/VBD
#   painful/JJ
#   ./.)
# (S
#   (NP The/DT sex/NN)
#   was/VBD
#   hot/JJ
#   but/CC
#   (NP the/DT story/NN)
# ...
# (S
#   (NP The/DT melancholy/NN)
#   that/WDT
#   Timothee/NNP
#   has/VBZ
#   added/VBN
#   to/TO
#   Laurie/NNP
#   's/POS
#   (NP character/NN)
#   gives/VBZ
#   it/PRP
#   (NP a/DT sincere/JJ darkness/NN)
#   that/WDT
#   makes/VBZ
#   (NP the/DT character/NN)
#   and/CC
#   his/PRP$
#   (NP behavior/NN)
#   more/RBR
#   believable/JJ
#   ./.)
# (S
#   (NP Florence/NN)
#   's/POS
#   (NP dual/JJ character/NN)
#   in/IN
#   (NP the/DT story/NN)
#   ,/,
#   both/CC
#   as/IN
#   (NP a/DT young/JJ girl/NN)
#   as/RB
#   well/RB
#   as/IN
#   (NP a/DT lady/NN)
#   are/VBP
#   portrayed/VBN
#   well/RB
#   ./.)
# (S
#   Laurie/NNP
#   and/CC
#   Amy/NNP
#   's/POS
#   (NP character/NN)
#   (NP bring/NN)
#   (NP coherency/NN)
#   and/CC
#   strengthen/VB
#   (NP the/DT story/NN)
#   ./.)
# (S
#   (NP The/DT lack/NN)
#   of/IN
#   (NP unnecessary/JJ dialogue/NN)
#   ,/,
#   especially/RB
#   in/IN
#   the/DT
#   romantic/JJ
#   scenes/NNS
#   have/VBP
#   been/VBN
#   a/DT
#   more/RBR
#   (NP befitting/JJ choice/NN)
#   ,/,
#   especially/RB
#   between/IN
#   Laurie/NNP
#   and/CC
#   Amy/NNP
#   where/WRB
#   we/PRP
#   see/VBP
#   (NP a/DT skip/NN)
#   in/IN
#   (NP the/DT dialogue/NN)
#   ,/,
#   replaced/VBN
#   by/IN
#   (NP silence/NN)
#   ./.)
# (S
#   Joe/NNP
#   's/POS
#   ``/``
#   I/PRP
#   tried/VBD
#   and/CC
#   I/PRP
#   failed/VBD
#   ''/''
#   gives/VBZ
#   (NP a/DT good/JJ explanation/NN)
#   ,/,
#   (NP a/DT good/JJ add-on/NN)
#   to/TO
#   her/PRP$
#   reasons/NNS
#   for/IN
#   her/PRP$
#   (NP decision/NN)
#   and/CC
#   (NP a/DT good/JJ complication/NN)
#   to/TO
#   her/PRP$
#   later/JJ
#   changing/VBG
#   her/PRP$
#   (NP mind/NN)
#   ./.)
# (S
#   Her/PRP$
#   (NP disappointment/NN)
#   upon/IN
#   hearing/VBG
#   (NP the/DT news/NN)
#   is/VBZ
#   fantastic/JJ
#   ./.)
# (S This/DT is/VBZ More/RBR believable/JJ and/CC tangible/JJ ./.)
# (S
#   I/PRP
#   'm/VBP
#   comparing/VBG
#   it/PRP
#   to/TO
#   (NP the/DT unnatural/JJ joy/NN)
#   of/IN
#   Joe/NNP
#   in/IN
#   The/DT
#   previous/JJ
#   Version/NNP
#   ./.)
# (S Comedy/NNP well/RB incorporated/VBD and/CC funny/JJ ./.)
# (S
#   (NP A/DT little/JJ slogan/NN)
#   in/IN
#   (NP the/DT end/NN)
#   about/IN
#   domestic/JJ
#   struggles/NNS
#   ./.)
# (S
#   (NP Good/JJ point/NN)
#   ,/,
#   but/CC
#   Decreases/VBZ
#   (NP the/DT naturalness/NN)
#   of/IN
#   (NP the/DT scene/NN)
#   ./.)
# (S
#   (NP The/DT movie/NN)
#   does/VBZ
#   address/VB
#   (NP the/DT fact/NN)
#   that/IN
#   the/DT
#   ending/VBG
#   was/VBD
#   not/RB
#   intended/VBN
#   by/IN
#   (NP the/DT writer/NN)
#   herself/PRP
#   in/IN
#   (NP an/DT audience-pleasing/JJ manner/NN)
#   ./.)
# (S Still/RB pleasant/JJ for/IN its/PRP$ (NP genre/NN) ./.)
# (S
#   And/CC
#   we/PRP
#   must/MD
#   not/RB
#   overlook/VB
#   (NP the/DT good/JJ music/NN)
#   composed/VBN
#   for/IN
#   (NP this/DT movie/NN)
#   that/WDT
#   suits/NNS
#   the/DT
#   scenes/NNS
#   well/RB
#   ./.)
# (S
#   The/DT
#   7th/CD
#   (NP film/NN)
#   (NP adaptation/NN)
#   of/IN
#   Louisa/NNP
#   May/NNP
#   Alcott/NNP
#   's/POS
#   (NP classic/JJ novel/NN)
#   of/IN
#   (NP the/DT same/JJ name/NN)
#   is/VBZ
#   (NP the/DT only/JJ version/NN)
#   that/IN
#   I/PRP
#   've/VBP
#   seen/VBN
#   so/RB
#   far/RB
#   and/CC
#   frankly/RB
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   need/VB
#   to/TO
#   check/VB
#   out/RP
#   the/DT
#   ones/NNS
#   that/WDT
#   surfaced/VBD
#   before/IN
#   anymore/RB
#   coz/JJ
#   Greta/NNP
#   Gerwig/NNP
#   's/POS
#   Little/JJ
#   Women/NNP
#   is/VBZ
#   (NP an/DT instant/JJ classic/NN)
#   that/WDT
#   impresses/VBZ
#   on/IN
#   all/DT
#   fronts/NNS
#   ,/,
#   and/CC
#   also/RB
#   establishes/VBZ
#   her/PRP
#   as/IN
#   (NP a/DT creative/JJ force/NN)
#   to/TO
#   be/VB
#   reckoned/VBN
#   with.Written/JJ
#   &/CC
#   directed/VBN
#   by/IN
#   Gerwig/NNP
#   in/IN
#   what/WP
#   's/VBZ
#   her/PRP$
#   (NP solo/JJ sophomore/NN)
#   (NP effort/NN)
#   ,/,
#   (NP the/DT film/NN)
#   is/VBZ
#   crafted/VBN
#   with/IN
#   so/RB
#   (NP much/JJ love/NN)
#   ,/,
#   (NP passion/NN)
#   ,/,
#   (NP honesty/NN)
#   ,/,
#   (NP authenticity/NN)
#   &/CC
#   (NP heartfelt/NN)
#   (NP warmth/NN)
#   that/IN
#   it/PRP
#   has/VBZ
#   the/DT
#   viewers/NNS
#   under/IN
#   its/PRP$
#   (NP spell/NN)
#   within/IN
#   minutes/NNS
#   ./.)
# (S
#   Gerwig/NNP
#   captures/VBZ
#   (NP the/DT joy/NN)
#   ,/,
#   (NP pain/NN)
#   ,/,
#   (NP tenderness/NN)
#   &/CC
#   everlasting/VBG
#   (NP love/NN)
#   between/IN
#   sisters/NNS
#   with/IN
#   (NP such/JJ effortless/JJ purity/NN)
#   that/IN
#   it/PRP
#   's/VBZ
#   just/RB
#   beautiful/JJ
#   to/TO
#   watch.Coming/VBG
#   off/RP
#   the/DT
#   critical/JJ
#   &/CC
#   (NP commercial/JJ success/NN)
#   of/IN
#   Lady/NNP
#   Bird/NNP
#   ,/,
#   Gerwig/NNP
#   proves/VBZ
#   that/IN
#   she/PRP
#   is/VBZ
#   (NP no/DT one/NN)
#   (NP hit/NN)
#   (NP wonder/NN)
#   ,/,
#   for/IN
#   Little/JJ
#   Women/NNP
#   is/VBZ
#   much/RB
#   better/RBR
#   &/CC
#   far/RB
#   more/JJR
#   (NP mature/JJ work/NN)
#   from/IN
#   her/PRP$
#   ./.)
# (S
#   (NP The/DT period/NN)
#   details/NNS
#   ,/,
#   (NP costume/JJ design/NN)
#   ,/,
#   (NP low-light/JJ photography/NN)
#   (NP stand/NN)
#   out/IN
#   with/IN
#   (NP ease/NN)
#   ,/,
#   while/IN
#   excellent/JJ
#   editing/VBG
#   makes/VBZ
#   (NP sure/NN)
#   there/EX
#   is/VBZ
#   n't/RB
#   (NP a/DT single/JJ wasted/JJ scene/NN)
#   in/IN
#   (NP the/DT final/JJ print.Gerwig/NN)
#   's/POS
#   (NP script/NN)
#   bestows/VBZ
#   (NP each/DT character/NN)
#   with/IN
#   (NP arcs/NN)
#   that/WDT
#   (NP exhibit/NN)
#   (NP depth/NN)
#   &/CC
#   (NP richness/NN)
#   ,/,
#   and/CC
#   then/RB
#   she/PRP
#   directs/VBZ
#   (NP the/DT terrific/JJ cast/NN)
#   of/IN
#   Saoirse/NNP
#   Ronan/NNP
#   ,/,
#   Florence/NNP
#   Pugh/NNP
#   ,/,
#   Emma/NNP
#   Watson/NNP
#   ,/,
#   Eliza/NNP
#   Scanlen/NNP
#   &/CC
#   others/NNS
#   to/TO
#   help/VB
#   them/PRP
#   bring/VB
#   their/PRP$
#   respective/JJ
#   roles/NNS
#   to/TO
#   (NP life/NN)
#   with/IN
#   (NP finesse/NN)
#   &/CC
#   (NP vibrancy/NN)
#   ./.)
# (S
#   Ronan/NNP
#   's/POS
#   (NP input/NN)
#   is/VBZ
#   amazing/JJ
#   ,/,
#   Pugh/NNP
#   is/VBZ
#   just/RB
#   as/RB
#   good/JJ
#   &/CC
#   (NP the/DT rest/NN)
#   (NP provide/NN)
#   (NP brilliant/JJ support/NN)
#   but/CC
#   it/PRP
#   's/VBZ
#   their/PRP$
#   (NP chemistry/NN)
#   with/IN
#   one/CD
#   another/DT
#   that/WDT
#   clicks/VBZ
#   (NP best.Overall/NN)
#   ,/,
#   Little/JJ
#   Women/NNP
#   presents/NNS
#   Greta/NNP
#   Gerwig/NNP
#   in/IN
#   (NP stellar/JJ form/NN)
#   ,/,
#   and/CC
#   is/VBZ
#   (NP another/DT quality/NN)
#   (NP addition/NN)
#   to/TO
#   her/PRP$
#   (NP filmography/NN)
#   ./.)
# (S
#   Exquisitely/RB
#   highlighting/VBG
#   the/DT
#   women/NNS
#   's/POS
#   (NP plight/NN)
#   ,/,
#   (NP prejudice/NN)
#   &/CC
#   (NP powerlessness/NN)
#   in/IN
#   those/DT
#   days/NNS
#   and/CC
#   to/TO
#   (NP an/DT extent/NN)
#   even/RB
#   (NP today/NN)
#   ,/,
#   Little/NNP
#   Women/NNP
#   is/VBZ
#   (NP a/DT joyful/JJ celebration/NN)
#   of/IN
#   (NP sisterhood/NN)
#   that/WDT
#   's/VBZ
#   highly/RB
#   faithful/JJ
#   to/TO
#   its/PRP$
#   (NP source/NN)
#   (NP material/NN)
#   and/CC
#   is/VBZ
#   winsome/JJ
#   &/CC
#   whimsical/JJ
#   in/IN
#   wonderful/JJ
#   ways/NNS
#   ./.)
# (S
#   One/CD
#   of/IN
#   the/DT
#   best/JJS
#   all-round/JJ
#   films/NNS
#   of/IN
#   2019/CD
#   ./.)
# (S
#   Greta/NNP
#   Gerwig/NNP
#   's/POS
#   post-'Lady/JJ
#   Bird/NNP
#   '/POS
#   (NP female/NN)
#   centred/VBD
#   'Little/JJ
#   Women/NNP
#   '/POS
#   ,/,
#   based/VBN
#   on/IN
#   the/DT
#   acclaimed/VBN
#   (NP novel/NN)
#   by/IN
#   Louisa/NNP
#   May/NNP
#   Alcott/NNP
#   ,/,
#   takes/VBZ
#   us/PRP
#   back/RB
#   to/TO
#   (NP the/DT late/JJ 19th/JJ century/NN)
#   in/IN
#   which/WDT
#   we/PRP
#   follow/VBP
#   the/DT
#   lives/NNS
#   of/IN
#   the/DT
#   March-family/NNP
#   ./.)
# (S
#   Numerous/JJ
#   adaptations/NNS
#   have/VBP
#   been/VBN
#   made/VBN
#   over/IN
#   the/DT
#   past/JJ
#   few/JJ
#   decades/NNS
#   ,/,
#   but/CC
#   Gerwig/NNP
#   elevates/VBZ
#   (NP the/DT material/NN)
#   ,/,
#   translating/VBG
#   it/PRP
#   in/IN
#   (NP a/DT way/NN)
#   to/TO
#   appeal/VB
#   to/TO
#   modern/JJ
#   audiences/NNS
#   ,/,
#   without/IN
#   ever/RB
#   losing/VBG
#   (NP the/DT essence/NN)
#   of/IN
#   (NP the/DT well/NN)
#   known/VBN
#   (NP story.When/NN)
#   we/PRP
#   first/RB
#   meet/VBD
#   the/DT
#   talented/VBN
#   Jo/NNP
#   (/(
#   Saoirse/NNP
#   Ronan/NNP
#   )/)
#   ,/,
#   she/PRP
#   's/VBZ
#   living/VBG
#   in/IN
#   New/NNP
#   York/NNP
#   ,/,
#   teaching/VBG
#   girls/NNS
#   (NP literature/NN)
#   and/CC
#   trying/VBG
#   to/TO
#   sell/VB
#   her/PRP$
#   own/JJ
#   stories/NNS
#   to/TO
#   (NP the/DT local/JJ newspaper/NN)
#   ./.)
# (S
#   While/IN
#   Jo/NNP
#   lives/VBZ
#   her/PRP$
#   best/JJS
#   (NP life/NN)
#   ,/,
#   her/PRP$
#   (NP hopeless/JJ romantic/JJ sister/NN)
#   Amy/NNP
#   (/(
#   Florence/NNP
#   Pugh/NNP
#   )/)
#   lives/VBZ
#   with/IN
#   her/PRP$
#   (NP old/JJ fashioned/JJ aunt/NN)
#   (/(
#   Meryl/NNP
#   Streep/NNP
#   )/)
#   in/IN
#   Paris/NNP
#   ,/,
#   attending/VBG
#   (NP painting/NN)
#   classes/NNS
#   while/IN
#   hoping/VBG
#   for/IN
#   (NP a/DT true/JJ love/NN)
#   to/TO
#   come/VB
#   (NP rescue/NN)
#   her/PRP
#   ./.)
# (S
#   (NP Other/JJ sister/NN)
#   Meg/NNP
#   (/(
#   Emma/NNP
#   Watson/NNP
#   )/)
#   is/VBZ
#   happily/RB
#   married/VBN
#   with/IN
#   kids/NNS
#   and/CC
#   the/DT
#   musically/RB
#   gifted/VBN
#   Beth/NNP
#   (/(
#   Eliza/NNP
#   Scanlen/NNP
#   )/)
#   has/VBZ
#   been/VBN
#   bedridden/VBN
#   with/IN
#   (NP a/DT severe/JJ illness/NN)
#   ./.)
# (S
#   When/WRB
#   Jo/NNP
#   gets/VBZ
#   (NP news/NN)
#   about/IN
#   Beth/NNP
#   's/POS
#   (NP state/NN)
#   quickly/RB
#   (NP deteriorating/NN)
#   ,/,
#   she/PRP
#   leaves/VBZ
#   (NP everything/NN)
#   (NP behind/NN)
#   and/CC
#   jumps/NNS
#   on/IN
#   (NP the/DT first/JJ train/NN)
#   (NP home/NN)
#   ./.)
# (S
#   While/IN
#   Jo/NNP
#   naps/NNS
#   ,/,
#   we/PRP
#   flash/VBP
#   back/RB
#   to/TO
#   easier/JJR
#   times/NNS
#   seven/CD
#   years/NNS
#   earlier/RB
#   ,/,
#   when/WRB
#   all/DT
#   sisters/NNS
#   still/RB
#   lived/VBD
#   merrily/RB
#   under/IN
#   one/CD
#   (NP roof.The/NN)
#   (NP first/JJ thing/NN)
#   you/PRP
#   'll/MD
#   notice/VB
#   is/VBZ
#   (NP the/DT scale/NN)
#   on/IN
#   which/WDT
#   all/DT
#   of/IN
#   this/DT
#   has/VBZ
#   been/VBN
#   made/VBN
#   ./.)
# (S
#   (NP Extraordinary/JJ production/NN)
#   (NP design/NN)
#   inside/IN
#   the/DT
#   old/JJ
#   mansions/NNS
#   surrounded/VBN
#   by/IN
#   the/DT
#   breathtaking/VBG
#   (NP scenery/NN)
#   of/IN
#   Massachusetts/NNP
#   ,/,
#   where/WRB
#   Little/JJ
#   Women/NNP
#   was/VBD
#   filmed/VBN
#   ./.)
# (S
#   Let/VB
#   Academy/NNP
#   Award/NNP
#   (NP winning/NN)
#   (/(
#   for/IN
#   his/PRP$
#   scores/NNS
#   of/IN
#   'The/NNP
#   Shape/NNP
#   of/IN
#   Water/NNP
#   '/POS
#   and/CC
#   'The/CD
#   Grand/NNP
#   Budapest/NNP
#   Hotel/NNP
#   '/POS
#   )/)
#   (NP composer/NN)
#   Alexandre/NNP
#   Desplat/NNP
#   set/VBD
#   (NP the/DT tone/NN)
#   for/IN
#   (NP each/DT scene/NN)
#   with/IN
#   his/PRP$
#   (NP classically/NN)
#   infused/VBD
#   orchestra/JJ
#   ,/,
#   and/CC
#   all/DT
#   you/PRP
#   need/VBP
#   is/VBZ
#   talent/JJ
#   on/IN
#   (NP screen/NN)
#   and/CC
#   on/IN
#   paper.Luckily/RB
#   Gerwig/NNP
#   knows/VBZ
#   how/WRB
#   to/TO
#   write/VB
#   (NP a/DT terrific/JJ screenplay/NN)
#   and/CC
#   (NP the/DT cast/NN)
#   has/VBZ
#   the/DT
#   most/RBS
#   (NP incredible/JJ chemistry/NN)
#   ./.)
# (S
#   (NP The/DT dialogue/NN)
#   is/VBZ
#   riddled/VBN
#   with/IN
#   timely/JJ
#   jokes/NNS
#   and/CC
#   hopelessly/RB
#   romantic/JJ
#   discussions/NNS
#   ,/,
#   (NP perfect/NN)
#   for/IN
#   (NP that/DT time/NN)
#   (NP period/NN)
#   ./.)
# (S
#   It/PRP
#   's/VBZ
#   (NP all/DT part/NN)
#   of/IN
#   a/DT
#   bigger/JJR
#   (NP picture/NN)
#   in/IN
#   which/WDT
#   (NP each/DT character/NN)
#   has/VBZ
#   their/PRP$
#   (NP own/JJ story/NN)
#   to/TO
#   tell/VB
#   ./.)
# (S
#   Saoirse/NNP
#   Ronan/NNP
#   's/POS
#   (/(
#   Lady/NNP
#   Bird/NNP
#   )/)
#   (NP radiant/NN)
#   (NP presence/NN)
#   is/VBZ
#   again/RB
#   noteworthy/JJ
#   ,/,
#   more/RBR
#   so/RB
#   ,/,
#   she/PRP
#   is/VBZ
#   quickly/RB
#   becoming/VBG
#   the/DT
#   best/JJS
#   (NP actress/NN)
#   in/IN
#   (NP the/DT business/NN)
#   ./.)
# (S
#   While/IN
#   rising/VBG
#   (NP star/NN)
#   Florence/NNP
#   Pugh/NNP
#   (/(
#   Midsommar/NNP
#   )/)
#   as/IN
#   the/DT
#   truly/RB
#   hilarious/JJ
#   and/CC
#   hopelessly/RB
#   obsessed/VBN
#   with/IN
#   (NP love/NN)
#   ,/,
#   (NP wealth/NN)
#   and/CC
#   looks/VBZ
#   Amy/NNP
#   ,/,
#   gives/VBZ
#   (NP another/DT career/NN)
#   defining/VBG
#   (NP performance/NN)
#   ,/,
#   to/TO
#   leave/VB
#   (NP a/DT mark/NN)
#   on/IN
#   (NP today/NN)
#   's/POS
#   moviegoers/NNS
#   '/POS
#   (NP memory/NN)
#   ./.)
# (S
#   It/PRP
#   's/VBZ
#   when/WRB
#   all/DT
#   four/CD
#   sisters/NNS
#   and/CC
#   their/PRP$
#   (NP mother/NN)
#   (/(
#   played/VBN
#   by/IN
#   (NP a/DT comforting/NN)
#   Laura/NNP
#   Dern/NNP
#   )/)
#   first/RB
#   appear/VBP
#   on/IN
#   (NP screen/NN)
#   ,/,
#   you/PRP
#   'll/MD
#   fall/VB
#   in/IN
#   (NP love/NN)
#   with/IN
#   (NP this/DT family/NN)
#   ./.)
# (S
#   There/EX
#   's/VBZ
#   (NP a/DT cosiness/NN)
#   and/CC
#   homely/RB
#   feeling/VBG
#   to/TO
#   their/PRP$
#   interactions/NNS
#   ,/,
#   that/WDT
#   will/MD
#   warm/VB
#   you/PRP
#   up/RP
#   from/IN
#   (NP the/DT inside/NN)
#   ./.)
# (S
#   Something/VBG
#   this/DT
#   innocent/JJ
#   and/CC
#   safe/JJ
#   has/VBZ
#   n't/RB
#   been/VBN
#   brought/VBN
#   to/TO
#   (NP the/DT big/JJ screen/NN)
#   in/IN
#   a/DT
#   very/RB
#   (NP long/JJ time/NN)
#   and/CC
#   Gerwig/NNP
#   knows/VBZ
#   just/RB
#   how/WRB
#   to/TO
#   control/VB
#   your/PRP$
#   (NP emotions.After/NN)
#   (NP a/DT lot/NN)
#   of/IN
#   going/VBG
#   back/RB
#   and/CC
#   (NP forth/NN)
#   in/IN
#   (NP time/NN)
#   -/:
#   which/WDT
#   is/VBZ
#   quite/RB
#   confusing/JJ
#   to/TO
#   begin/VB
#   with/IN
#   ,/,
#   but/CC
#   you/PRP
#   get/VBP
#   more/JJR
#   used/VBN
#   to/TO
#   it/PRP
#   further/RB
#   down/RP
#   (NP the/DT line/NN)
#   when/WRB
#   both/DT
#   timelines/NNS
#   move/VBP
#   forward/RB
#   to/TO
#   meet/VB
#   in/IN
#   the/DT
#   middle/JJ
#   -/:
#   (NP the/DT final/JJ third/NN)
#   of/IN
#   (NP the/DT film/NN)
#   builds/VBZ
#   up/RP
#   to/TO
#   (NP a/DT gut/NN)
#   wrenching/VBG
#   (NP conclusion/NN)
#   ./.)
# (S
#   For/IN
#   (NP some/DT reason/NN)
#   ,/,
#   (NP the/DT actual/JJ heartbreaking/NN)
#   (NP event/NN)
#   is/VBZ
#   n't/RB
#   so/RB
#   much/JJ
#   of/IN
#   (NP a/DT surprise/NN)
#   ,/,
#   it/PRP
#   's/VBZ
#   (NP the/DT aftermath/NN)
#   that/WDT
#   truly/VBZ
#   shatters/NNS
#   your/PRP$
#   (NP heart/NN)
#   into/IN
#   tiny/JJ
#   pieces/NNS
#   and/CC
#   leaves/VBZ
#   you/PRP
#   gasping/VBG
#   for/IN
#   (NP air/NN)
#   while/IN
#   tears/NNS
#   roll/VBP
#   down/RP
#   your/PRP$
#   (NP cheek/NN)
#   ./.)
# (S
#   Little/JJ
#   Women/NNP
#   is/VBZ
#   just/RB
#   as/RB
#   heartwarming/VBG
#   as/IN
#   it/PRP
#   is/VBZ
#   excruciatingly/RB
#   sad/JJ
#   ./.)
# (S
#   Greta/NNP
#   Gerwig/NNP
#   has/VBZ
#   made/VBN
#   a/DT
#   timeless/JJ
#   classic/JJ
#   that/WDT
#   exudes/VBZ
#   (NP love/NN)
#   ./.)
# (S
#   Watching/VBG
#   (NP this/DT film/NN)
#   will/MD
#   for/IN
#   sure/JJ
#   become/VB
#   a/DT
#   new/JJ
#   Christmas/NNP
#   (NP tradition/NN)
#   in/IN
#   many/JJ
#   households/NNS
#   ./.)
# (S
#   What/WP
#   a/DT
#   wonderful/JJ
#   gift.Originally/RB
#   published/VBN
#   on/IN
#   intoscreens/NNS)
# (S
#   ``/``
#   Little/JJ
#   Women/NNP
#   ''/''
#   is/VBZ
#   empowering/VBG
#   ,/,
#   refreshing/VBG
#   and/CC
#   an/DT
#   absolutely/RB
#   (NP lovely/JJ film/NN)
#   backed/VBN
#   by/IN
#   (NP an/DT incredible/JJ cast/NN)
#   ./.)
# (S ./.)
# (S
#   In/IN
#   (NP this/DT drama/NN)
#   ,/,
#   the/DT
#   March/NNP
#   sisters/NNS
#   are/VBP
#   four/CD
#   young/JJ
#   women/NNS
#   each/DT
#   determined/VBD
#   to/TO
#   live/VB
#   (NP life/NN)
#   on/IN
#   their/PRP$
#   own/JJ
#   terms/NNS
#   ./.)
# (S
#   Based/VBN
#   on/IN
#   (NP the/DT classic/JJ novel/NN)
#   of/IN
#   (NP the/DT same/JJ name/NN)
#   ./.)
# (S ./.)
# (S
#   I/PRP
#   had/VBD
#   neutral/JJ
#   feelings/NNS
#   about/IN
#   ``/``
#   Little/JJ
#   Women/NNP
#   ''/''
#   as/IN
#   I/PRP
#   walked/VBD
#   in/IN
#   to/TO
#   take/VB
#   my/PRP$
#   (NP seat/NN)
#   ,/,
#   but/CC
#   in/IN
#   (NP the/DT end/NN)
#   I/PRP
#   thoroughly/RB
#   enjoyed/VBD
#   (NP this/DT film/NN)
#   ./.)
# (S
#   (NP A/DT sweet/NN)
#   ,/,
#   sensitive/JJ
#   and/CC
#   (NP powerful/JJ film/NN)
#   that/WDT
#   will/MD
#   remain/VB
#   timeless/JJ
#   like/IN
#   its/PRP$
#   (NP source/NN)
#   (NP material/NN)
#   ./.)
# (S
#   (NP The/DT cast/NN)
#   of/IN
#   leads/NNS
#   is/VBZ
#   terrific/JJ
#   but/CC
#   Florence/NNP
#   Pugh/NNP
#   steals/VBZ
#   (NP the/DT show/NN)
#   ./.)
# (S
#   Pugh/NNP
#   will/MD
#   become/VB
#   one/CD
#   of/IN
#   the/DT
#   great/JJ
#   leading/JJ
#   ladies/NNS
#   in/IN
#   (NP the/DT biz/NN)
#   (/(
#   see/VB
#   also/RB
#   ``/``
#   Fighting/VBG
#   With/IN
#   My/NNP
#   Family/NNP
#   ''/''
#   ,/,
#   ``/``
#   Midsommar/NNP
#   ''/''
#   )/)
#   ./.)
# (S
#   ``/``
#   Little/JJ
#   Women/NNP
#   ''/''
#   is/VBZ
#   garnished/VBN
#   with/IN
#   (NP beauty/NN)
#   and/CC
#   (NP a/DT joy/NN)
#   to/TO
#   watch/VB
#   ./.)
# (S
#   You/PRP
#   will/MD
#   fall/VB
#   in/IN
#   (NP love/NN)
#   with/IN
#   (NP this/DT film/NN)
#   ./.)
# (S
#   (NP Tender/NN)
#   ,/,
#   (NP beautiful/JJ rhythm/NN)
#   ,/,
#   well-kept/JJ
#   characters/NNS
#   and/CC
#   (NP an/DT atmosphere/NN)
#   that/WDT
#   holds/VBZ
#   up/IN
#   to/TO
#   (NP the/DT end/NN)
#   ./.)
# (S
#   we/PRP
#   all/DT
#   know/VBP
#   (NP the/DT story/NN)
#   ,/,
#   making/VBG
#   (NP a/DT good/JJ movie/NN)
#   was/VBD
#   not/RB
#   easy/JJ
#   at/IN
#   all/DT
#   ./.)
# (S 7/10/CD)

# %% [markdown]
# In the above example, we notice that the proper nouns are ignored from the Noun Phrases. Phrases like Netflix, Jesus Christ  were not tagged in Noun Phrases. So, we expand our grammar to include NN.\* and JJ.\* to the NP Chunk.
#
# In order to improve the output, we display only the noun phrases and store teh noun phrases to an array.
#
# As we scroll down through the result, we will see that Proper Noun and Plural Nouns are tagged as Noun Phrases.

# %%
sentences_arr = []
sentences_np_arr = []
for ind_review in table_review.Review:
    sentences_pos = ie_preprocess(ind_review)
    
    grammar = '''
    NP: {<PRP.*>*<NN.*>}          # Include NNP, NNS, NNPS, etc.
    '''
    cp = nltk.RegexpParser(grammar)
    
    for sent in sentences_pos:
        tree = cp.parse(sent)
        sentences_arr.append(tree)
        print(tree) # Print the entire sentence 
        #tree.draw()
        for subtree in tree.subtrees():
            if subtree.label() == 'NP': 
                print(subtree) # Print the noun phrases within the sentence
                sentences_np_arr.append(subtree)
# Out:
# (S
#   I/PRP
#   honestly/RB
#   ca/MD
#   n't/RB
#   believe/VB
#   this/DT
#   is/VBZ
#   (NP an/DT actual/JJ movie/NN)
#   and/CC
#   (NP number/NN)
#   1/CD
#   on/IN
#   (NP Netflix/NNP)
#   in/IN
#   my/PRP$
#   (NP country/NN)
#   ./.)
# (NP an/DT actual/JJ movie/NN)
# (NP number/NN)
# (NP Netflix/NNP)
# (NP country/NN)
# (S
#   This/DT
#   was/VBD
#   probably/RB
#   (NP the/DT worst/JJS movie/NN)
#   I/PRP
#   've/VBP
#   ever/RB
#   seen/VBN
#   ./.)
# (NP the/DT worst/JJS movie/NN)
# (S
#   (NP The/DT dialogues/NNS)
#   between/IN
#   (NP the/DT main/JJ characters/NNS)
#   are/VBP
#   unbelievably/RB
#   cringy/JJ
#   and/CC
#   (NP the/DT plot/NN)
#   literally/RB
#   does/VBZ
#   n't/RB
#   make/VB
#   (NP any/DT sense/NN)
#   ./.)
# (NP The/DT dialogues/NNS)
# (NP the/DT main/JJ characters/NNS)
# (NP the/DT plot/NN)
# (NP any/DT sense/NN)
# (S
#   Do/VBP
#   n't/RB
#   watch/VB
#   (NP this/DT movie/NN)
#   unless/IN
#   you/PRP
#   wan/VBP
#   (NP na/JJ waste/NN)
#   2/CD
#   (NP hours/NNS)
#   of/IN
#   your/PRP$
#   (NP life/NN)
#   just/RB
#   to/TO
#   give/VB
#   (NP this/DT movie/NN)
#   a/DT
#   (/(
#   probably/RB
#   )/)
#   1/CD
#   (NP star/NN)
#   (NP rating/NN)
#   too/RB
#   ./.)
# (NP this/DT movie/NN)
# (NP na/JJ waste/NN)
# (NP hours/NNS)
# (NP life/NN)
# (NP this/DT movie/NN)
# (NP star/NN)
# (NP rating/NN)
# (S
#   (NP Girl/NNP)
#   's/POS
#   (NP boyfriend/NN)
#   wears/VBZ
#   cargo/VBP
#   (NP short/JJ pants/NNS)
#   on/IN
#   her/PRP$
#   (NP birthday/NN)
#   ./.)
# (NP Girl/NNP)
# (NP boyfriend/NN)
# (NP short/JJ pants/NNS)
# (NP birthday/NN)
# (S
#   If/IN
#   that/DT
#   is/VBZ
#   not/RB
#   (NP a/DT red/JJ flag/NN)
#   ,/,
#   I/PRP
#   do/VBP
#   not/RB
#   know/VB
#   what/WP
#   it/PRP
#   is/VBZ
#   ./.)
# (NP a/DT red/JJ flag/NN)
# (S
#   (NP A/DT kidnapped/JJ woman/NN)
#   is/VBZ
#   smiling/VBG
#   less/JJR
#   than/IN
#   24/CD
#   (NP hours/NNS)
#   after/IN
#   being/VBG
#   fed/VBN
#   and/CC
#   taking/VBG
#   (NP shopping/NN)
#   at/IN
#   (NP a/DT high/JJ end/NN)
#   (NP botique/NN)
#   by/IN
#   her/PRP$
#   (NP captor/NN)
#   ./.)
# (NP A/DT kidnapped/JJ woman/NN)
# (NP hours/NNS)
# (NP shopping/NN)
# (NP a/DT high/JJ end/NN)
# (NP botique/NN)
# (NP captor/NN)
# (S
#   3/CD
#   (NP days/NNS)
#   into/IN
#   her/PRP$
#   (NP captivity/NN)
#   (NP spent/NN)
#   jetsetting/VBG
#   to/TO
#   (NP VIP/NNP)
#   (NP clubs/NNS)
#   and/CC
#   on/IN
#   (NP private/JJ yachts/NNS)
#   she/PRP
#   blows/VBZ
#   him/PRP
#   and/CC
#   falls/VBZ
#   in/IN
#   (NP love/NN)
#   ./.)
# (NP days/NNS)
# (NP captivity/NN)
# (NP spent/NN)
# (NP VIP/NNP)
# (NP clubs/NNS)
# (NP private/JJ yachts/NNS)
# (NP love/NN)
# (S
#   (NP A/DT true/JJ romance/NN)
#   (NP tale/NN)
#   for/IN
#   (NP the/DT ages/NNS)
#   ./.)
# (NP A/DT true/JJ romance/NN)
# (NP tale/NN)
# (NP the/DT ages/NNS)
# (S (NP The/DT cringe/NN) (NP levels/NNS) runeth/VBP over/IN ./.)
# (NP The/DT cringe/NN)
# (NP levels/NNS)
# (S
#   (NP The/DT English/NNP)
#   is/VBZ
#   almost/RB
#   as/RB
#   bad/JJ
#   as/IN
#   (NP the/DT plot/NN)
#   ./.)
# (NP The/DT English/NNP)
# (NP the/DT plot/NN)
# (S
#   If/IN
#   you/PRP
#   want/VBP
#   to/TO
#   watch/VB
#   (NP this/DT movie/NN)
#   do/VBP
#   so/RB
#   as/IN
#   (NP a/DT drinking/NN)
#   (NP game/NN)
#   ./.)
# (NP this/DT movie/NN)
# (NP a/DT drinking/NN)
# (NP game/NN)
# (S (NP Did/NNP) you/PRP cringe/VB ?/.)
# (NP Did/NNP)
# (S Then/RB take/VB (NP a/DT shot/NN) my/PRP$ (NP dude/NN) ./.)
# (NP a/DT shot/NN)
# (NP dude/NN)
# (S You/PRP will/MD be/VB wasted/VBN by/IN (NP the/DT end/NN) ./.)
# (NP the/DT end/NN)
# (S
#   I/PRP
#   honestly/RB
#   do/VBP
#   n't/RB
#   know/VB
#   who/WP
#   thought/VBD
#   that/IN
#   (NP this/DT movie/NN)
#   would/MD
#   be/VB
#   (NP a/DT good/JJ idea/NN)
#   ./.)
# (NP this/DT movie/NN)
# (NP a/DT good/JJ idea/NN)
# (S
#   It/PRP
#   is/VBZ
#   (NP a/DT complete/JJ train/NN)
#   (NP wreck/NN)
#   for/IN
#   (NP multiple/JJ reasons.One/NN)
#   of/IN
#   (NP the/DT biggest/JJS issues/NNS)
#   is/VBZ
#   (NP the/DT plot/NN)
#   is/VBZ
#   just/RB
#   nonsense/JJ
#   ./.)
# (NP a/DT complete/JJ train/NN)
# (NP wreck/NN)
# (NP multiple/JJ reasons.One/NN)
# (NP the/DT biggest/JJS issues/NNS)
# (NP the/DT plot/NN)
# (S
#   It/PRP
#   is/VBZ
#   inappropriate/JJ
#   to/TO
#   have/VB
#   (NP a/DT man/NN)
#   deiced/VBD
#   that/IN
#   he/PRP
#   will/MD
#   hold/VB
#   (NP a/DT woman/NN)
#   (NP captive/NN)
#   and/CC
#   she/PRP
#   will/MD
#   love/VB
#   him/PRP
#   ./.)
# (NP a/DT man/NN)
# (NP a/DT woman/NN)
# (NP captive/NN)
# (S
#   That/DT
#   is/VBZ
#   just/RB
#   not/RB
#   ok/JJ
#   and/CC
#   i/JJ
#   do/VBP
#   n't/RB
#   know/VB
#   why/WRB
#   they/PRP
#   made/VBD
#   (NP a/DT movie/NN)
#   romanticising/VBG
#   (NP this/DT idea/NN)
#   ./.)
# (NP a/DT movie/NN)
# (NP this/DT idea/NN)
# (S (NP The/DT male/JJ character/NN) is/VBZ (NP a/DT creep/NN) ./.)
# (NP The/DT male/JJ character/NN)
# (NP a/DT creep/NN)
# (S
#   He/PRP
#   assaults/VBZ
#   (NP the/DT female/JJ character/NN)
#   (NP multiple/JJ times/NNS)
#   and/CC
#   it/PRP
#   is/VBZ
#   not/RB
#   shown/VBN
#   as/IN
#   (NP a/DT bad/JJ thing/NN)
#   ./.)
# (NP the/DT female/JJ character/NN)
# (NP multiple/JJ times/NNS)
# (NP a/DT bad/JJ thing/NN)
# (S
#   It/PRP
#   's/VBZ
#   just/RB
#   like/IN
#   he/PRP
#   is/VBZ
#   (NP a/DT man/NN)
#   and/CC
#   he/PRP
#   has/VBZ
#   (NP power/NN)
#   so/IN
#   he/PRP
#   can/MD
#   do/VB
#   what/WP
#   he/PRP
#   likes/VBZ
#   ./.)
# (NP a/DT man/NN)
# (NP power/NN)
# (S It/PRP is/VBZ really/RB really/RB bad/JJ ./.)
# (S
#   Beyond/IN
#   that/DT
#   they/PRP
#   just/RB
#   do/VBP
#   (NP variations/NNS)
#   of/IN
#   (NP the/DT same/JJ scene/NN)
#   6/CD
#   (NP different/JJ times/NNS)
#   ./.)
# (NP variations/NNS)
# (NP the/DT same/JJ scene/NN)
# (NP different/JJ times/NNS)
# (S
#   (NP This/DT movie/NN)
#   is/VBZ
#   just/RB
#   (NP the/DT same/JJ scene/NN)
#   over/IN
#   and/CC
#   over/RB
#   again/RB
#   broken/VBN
#   up/RP
#   with/IN
#   (NP random/JJ montages/NNS)
#   with/IN
#   (NP a/DT song/NN)
#   played/VBN
#   over/IN
#   (NP it.The/JJ actions/NNS)
#   of/IN
#   (NP the/DT characters/NNS)
#   are/VBP
#   nonsensical/JJ
#   too/RB
#   ./.)
# (NP This/DT movie/NN)
# (NP the/DT same/JJ scene/NN)
# (NP random/JJ montages/NNS)
# (NP a/DT song/NN)
# (NP it.The/JJ actions/NNS)
# (NP the/DT characters/NNS)
# (S
#   She/PRP
#   has/VBZ
#   been/VBN
#   kidnapped/VBN
#   in/IN
#   (NP a/DT foreign/JJ country/NN)
#   and/CC
#   then/RB
#   (NP the/DT next/JJ day/NN)
#   there/EX
#   is/VBZ
#   (NP a/DT shopping/NN)
#   (NP montage/NN)
#   where/WRB
#   she/PRP
#   is/VBZ
#   just/RB
#   like/IN
#   ``/``
#   (NP woo/JJ lets/NNS)
#   go/VBP
#   buy/VB
#   (NP some/DT new/JJ clothes/NNS)
#   ''/''
#   ./.)
# (NP a/DT foreign/JJ country/NN)
# (NP the/DT next/JJ day/NN)
# (NP a/DT shopping/NN)
# (NP montage/NN)
# (NP woo/JJ lets/NNS)
# (NP some/DT new/JJ clothes/NNS)
# (S
#   Like/IN
#   that/DT
#   just/RB
#   would/MD
#   n't/RB
#   happen/VB
#   ,/,
#   you/PRP
#   would/MD
#   be/VB
#   terrified/VBN
#   and/CC
#   she/PRP
#   just/RB
#   (NP acts/NNS)
#   like/IN
#   (NP fine/NN)
#   with/IN
#   it/PRP
#   ./.)
# (NP acts/NNS)
# (NP fine/NN)
# (S
#   I/PRP
#   feel/VBP
#   like/IN
#   they/PRP
#   try/VBP
#   to/TO
#   get/VB
#   (NP the/DT audience/NN)
#   on/IN
#   (NP side/NN)
#   by/IN
#   making/VBG
#   her/PRP$
#   (NP current/JJ boyfriend/NN)
#   (NP a/DT horrible/JJ person/NN)
#   ./.)
# (NP the/DT audience/NN)
# (NP side/NN)
# (NP current/JJ boyfriend/NN)
# (NP a/DT horrible/JJ person/NN)
# (S
#   I/PRP
#   think/VBP
#   they/PRP
#   think/VBP
#   (NP the/DT audience/NN)
#   will/MD
#   be/VB
#   like/IN
#   ``/``
#   oh/IN
#   that/DT
#   's/VBZ
#   good/JJ
#   she/PRP
#   got/VBD
#   away/RB
#   from/IN
#   him/PRP
#   ''/''
#   ./.)
# (NP the/DT audience/NN)
# (S
#   Yeah/UH
#   she/PRP
#   did/VBD
#   get/VB
#   away/RB
#   from/IN
#   her/PRP$
#   (NP bad/JJ boyfriend/NN)
#   .../:
#   by/IN
#   being/VBG
#   kidnapped/VBN
#   by/IN
#   (NP an/DT Italian/JJ mobster/NN)
#   who/WP
#   is/VBZ
#   holding/VBG
#   her/PRP$
#   (NP captive/NN)
#   ?/.
#   ?/.
#   ?/.)
# (NP bad/JJ boyfriend/NN)
# (NP an/DT Italian/JJ mobster/NN)
# (NP captive/NN)
# (S
#   ?/.
#   (NP The/DT second/JJ issue/NN)
#   is/VBZ
#   (NP the/DT leads/NNS)
#   ca/MD
#   n't/RB
#   act/VB
#   and/CC
#   (NP a/DT lot/NN)
#   of/IN
#   (NP the/DT movie/NN)
#   is/VBZ
#   just/RB
#   them/PRP
#   interacting/VBG
#   so/RB
#   its/PRP$
#   like/IN
#   watching/VBG
#   (NP an/DT amateur/NN)
#   (NP dramatics/NNS)
#   troupe/VBP
#   (NP half/NN)
#   of/IN
#   (NP the/DT time/NN)
#   ./.)
# (NP The/DT second/JJ issue/NN)
# (NP the/DT leads/NNS)
# (NP a/DT lot/NN)
# (NP the/DT movie/NN)
# (NP an/DT amateur/NN)
# (NP dramatics/NNS)
# (NP half/NN)
# (NP the/DT time/NN)
# (S
#   Now/RB
#   i/VBZ
#   ca/MD
#   n't/RB
#   work/VB
#   this/DT
#   out/RP
#   but/CC
#   (NP this/DT woman/NN)
#   who/WP
#   is/VBZ
#   kidnapped/VBN
#   never/RB
#   seems/VBZ
#   scared/VBN
#   like/IN
#   at/IN
#   all/DT
#   ./.)
# (NP this/DT woman/NN)
# (S
#   I/PRP
#   ca/MD
#   n't/RB
#   deiced/VB
#   if/IN
#   this/DT
#   was/VBD
#   (NP the/DT direction/NN)
#   she/PRP
#   was/VBD
#   given/VBN
#   or/CC
#   she/PRP
#   just/RB
#   ca/MD
#   n't/RB
#   act/VB
#   or/CC
#   (NP the/DT script/NN)
#   said/VBD
#   she/PRP
#   is/VBZ
#   n't/RB
#   scared/VBN
#   ./.)
# (NP the/DT direction/NN)
# (NP the/DT script/NN)
# (S
#   She/PRP
#   literally/RB
#   wakes/VBZ
#   up/RP
#   after/IN
#   being/VBG
#   kidnapped/VBN
#   and/CC
#   tried/VBN
#   to/TO
#   open/VB
#   (NP the/DT door/NN)
#   to/TO
#   get/VB
#   out/RP
#   ,/,
#   ca/MD
#   n't/RB
#   because/VB
#   its/PRP$
#   locked/JJ
#   and/CC
#   is/VBZ
#   just/RB
#   like/IN
#   ``/``
#   (NP Yeah/NNP)
#   fair/JJ
#   enough/RB
#   ''/''
#   and/CC
#   just/RB
#   (NP sits/NNS)
#   down/RP
#   like/IN
#   this/DT
#   happens/VBZ
#   (NP every/DT day.On/NN)
#   (NP top/NN)
#   of/IN
#   that/IN
#   (NP the/DT scenes/NNS)
#   with/IN
#   (NP the/DT male/JJ lead/NN)
#   pushing/VBG
#   her/PRP$
#   against/IN
#   (NP walls/NNS)
#   and/CC
#   (NP stuff/NN)
#   she/PRP
#   pulls/VBZ
#   like/IN
#   ``/``
#   (NP Posing/NNP)
#   ,/,
#   modelling/VBG
#   ''/''
#   faces/VBZ
#   and/CC
#   is/VBZ
#   not/RB
#   like/IN
#   ``/``
#   (NP Jesus/NNP)
#   (NP Christ/NNP)
#   (NP the/DT man/NN)
#   is/VBZ
#   assaulting/VBG
#   me/PRP
#   (NP help/NN)
#   ''/''
#   ./.)
# (NP the/DT door/NN)
# (NP Yeah/NNP)
# (NP sits/NNS)
# (NP every/DT day.On/NN)
# (NP top/NN)
# (NP the/DT scenes/NNS)
# (NP the/DT male/JJ lead/NN)
# (NP walls/NNS)
# (NP stuff/NN)
# (NP Posing/NNP)
# (NP Jesus/NNP)
# (NP Christ/NNP)
# (NP the/DT man/NN)
# (NP help/NN)
# (S
#   Once/RB
#   again/RB
#   was/VBD
#   this/DT
#   (NP the/DT direction/NN)
#   or/CC
#   was/VBD
#   it/PRP
#   the/DT
#   acting/VBG
#   who/WP
#   's/VBZ
#   (NP knows/NNS)
#   ?/.
#   It/PRP
#   also/RB
#   relies/VBZ
#   heavily/RB
#   on/IN
#   ``/``
#   (NP Pop/NNP)
#   ''/''
#   (NP songs/NNS)
#   that/WDT
#   are/VBP
#   really/RB
#   loud/JJ
#   and/CC
#   unnecessary/JJ
#   ./.)
# (NP the/DT direction/NN)
# (NP knows/NNS)
# (NP Pop/NNP)
# (NP songs/NNS)
# (S
#   They/PRP
#   constantly/RB
#   play/VBP
#   one/CD
#   after/IN
#   the/DT
#   other/JJ
#   and/CC
#   then/RB
#   when/WRB
#   reading/VBG
#   i/RB
#   found/VBN
#   out/RP
#   (NP the/DT male/JJ lead/NN)
#   (NP sung/NN)
#   like/IN
#   (NP a/DT big/JJ chunk/NN)
#   of/IN
#   them/PRP
#   so/RB
#   (NP i/JJ guess/NN)
#   (NP production/NN)
#   was/VBD
#   just/RB
#   like/IN
#   ``/``
#   well/RB
#   he/PRP
#   will/MD
#   give/VB
#   us/PRP
#   them/PRP
#   cheep/VBP
#   (NP let/NN)
#   's/POS
#   throw/VB
#   them/PRP
#   all/DT
#   in/IN
#   ''/''
#   (NP .I/NN)
#   could/MD
#   go/VB
#   one/CD
#   about/IN
#   all/DT
#   its/PRP$
#   (NP problems/NNS)
#   but/CC
#   it/PRP
#   all/DT
#   circles/VBZ
#   back/RB
#   to/TO
#   (NP the/DT directing/NN)
#   ,/,
#   acting/VBG
#   and/CC
#   (NP the/DT script/NN)
#   ./.)
# (NP the/DT male/JJ lead/NN)
# (NP sung/NN)
# (NP a/DT big/JJ chunk/NN)
# (NP i/JJ guess/NN)
# (NP production/NN)
# (NP let/NN)
# (NP .I/NN)
# (NP problems/NNS)
# (NP the/DT directing/NN)
# (NP the/DT script/NN)
# (S
#   It/PRP
#   was/VBD
#   just/RB
#   (NP a/DT perfect/JJ storm.Believe/NN)
#   it/PRP
#   or/CC
#   not/RB
#   it/PRP
#   is/VBZ
#   watchable/JJ
#   but/CC
#   in/IN
#   (NP a/DT way/NN)
#   that/IN
#   you/PRP
#   want/VBP
#   to/TO
#   watch/VB
#   it/PRP
#   to/TO
#   see/VB
#   (NP the/DT disaster/NN)
#   ./.)
# (NP a/DT perfect/JJ storm.Believe/NN)
# (NP a/DT way/NN)
# (NP the/DT disaster/NN)
# (S
#   It/PRP
#   is/VBZ
#   the/DT
#   no1/JJ
#   viewed/VBN
#   (NP film/NN)
#   on/IN
#   (NP a/DT large/JJ amount/NN)
#   of/IN
#   (NP different/JJ countries/NNS)
#   (NP Netflix/NNP)
#   's/POS
#   at/IN
#   (NP the/DT moment/NN)
#   and/CC
#   (NP i/NN)
#   believe/VBP
#   this/DT
#   to/TO
#   be/VB
#   (NP the/DT reason.So/NN)
#   its/PRP$
#   really/RB
#   up/IN
#   to/TO
#   you/PRP
#   if/IN
#   you/PRP
#   want/VBP
#   to/TO
#   watch/VB
#   it/PRP
#   ./.)
# (NP film/NN)
# (NP a/DT large/JJ amount/NN)
# (NP different/JJ countries/NNS)
# (NP Netflix/NNP)
# (NP the/DT moment/NN)
# (NP i/NN)
# (NP the/DT reason.So/NN)
# (S
#   It/PRP
#   is/VBZ
#   very/RB
#   boring/JJ
#   but/CC
#   also/RB
#   (NP a/DT train/NN)
#   (NP wreck/NN)
#   ./.)
# (NP a/DT train/NN)
# (NP wreck/NN)
# (S I/PRP do/VBP not/RB even/RB know/VB where/WRB to/TO start/VB ./.)
# (S
#   (NP Look/NN)
#   ,/,
#   this/DT
#   is/VBZ
#   (NP nothing/NN)
#   but/CC
#   straight/VBD
#   up/RP
#   (NP porn/NN)
#   ./.)
# (NP Look/NN)
# (NP nothing/NN)
# (NP porn/NN)
# (S
#   (NP The/DT plot/NN)
#   is/VBZ
#   ridiculous/JJ
#   ,/,
#   (NP the/DT chemistry/NN)
#   between/IN
#   the/DT
#   two/CD
#   (NP leads/NNS)
#   is/VBZ
#   nonexistent/JJ
#   ,/,
#   and/CC
#   (NP the/DT acting/NN)
#   is/VBZ
#   even/RB
#   worse/JJR
#   ./.)
# (NP The/DT plot/NN)
# (NP the/DT chemistry/NN)
# (NP leads/NNS)
# (NP the/DT acting/NN)
# (S
#   (NP Trust/NNP)
#   me/PRP
#   when/WRB
#   I/PRP
#   say/VBP
#   ,/,
#   you/PRP
#   will/MD
#   watch/VB
#   this/DT
#   in/IN
#   fast/RB
#   (NP forward/NN)
#   ./.)
# (NP Trust/NNP)
# (NP forward/NN)
# (S It/PRP is/VBZ that/IN horrible/JJ !/.)
# (S
#   (NP This/DT movie/NN)
#   is/VBZ
#   legit/JJ
#   (NP the/DT third/JJ worst/JJ movie/NN)
#   I/PRP
#   've/VBP
#   ever/RB
#   seen/VBN
#   ./.)
# (NP This/DT movie/NN)
# (NP the/DT third/JJ worst/JJ movie/NN)
# (S
#   (NP Incoherent/NNP)
#   (NP plot/NN)
#   ,/,
#   (NP stupid/JJ characters/NNS)
#   ,/,
#   completely/RB
#   illogical/JJ
#   in/IN
#   (NP every/DT sense/NN)
#   of/IN
#   (NP the/DT word/NN)
#   ./.)
# (NP Incoherent/NNP)
# (NP plot/NN)
# (NP stupid/JJ characters/NNS)
# (NP every/DT sense/NN)
# (NP the/DT word/NN)
# (S
#   My/PRP$
#   (NP advice/NN)
#   would/MD
#   be/VB
#   to/TO
#   avoid/VB
#   (NP this/DT hot/JJ mess/NN)
#   at/IN
#   (NP all/DT costs/NNS)
#   ./.)
# (NP advice/NN)
# (NP this/DT hot/JJ mess/NN)
# (NP all/DT costs/NNS)
# (S
#   I/PRP
#   do/VBP
#   n't/RB
#   remember/VB
#   if/IN
#   I/PRP
#   have/VBP
#   reviewed/VBN
#   (NP another/DT movie/NN)
#   so/RB
#   far/RB
#   ,/,
#   but/CC
#   seeing/VBG
#   so/RB
#   many/JJ
#   10/10/CD
#   (NP reviews/NNS)
#   determined/VBD
#   me/PRP
#   to/TO
#   log/VB
#   in/IN
#   to/TO
#   write/VB
#   this/DT
#   ,/,
#   to/TO
#   ballance/VB
#   (NP things/NNS)
#   up/RP
#   (NP a/DT bit.The/NN)
#   (NP movie/NN)
#   is/VBZ
#   pretty/RB
#   bad/JJ
#   ./.)
# (NP another/DT movie/NN)
# (NP reviews/NNS)
# (NP things/NNS)
# (NP a/DT bit.The/NN)
# (NP movie/NN)
# (S
#   (NP The/DT plot/NN)
#   (/(
#   if/IN
#   you/PRP
#   can/MD
#   call/VB
#   it/PRP
#   that/IN
#   )/)
#   is/VBZ
#   mostly/RB
#   absurd/JJ
#   and/CC
#   (NP the/DT events/NNS)
#   are/VBP
#   (NP cliche/NN)
#   and/CC
#   totally/RB
#   predictable/JJ
#   (/(
#   try/VB
#   to/TO
#   remember/VB
#   what/WP
#   (NP somebody/NN)
#   did/VBD
#   or/CC
#   said/VBD
#   in/IN
#   all/PDT
#   (NP the/DT bad/JJ movies/NNS)
#   that/IN
#   you/PRP
#   ever/RB
#   saw/VBD
#   :/:
#   yes/UH
#   ,/,
#   it/PRP
#   's/VBZ
#   exactly/RB
#   what/WP
#   's/VBZ
#   going/VBG
#   to/TO
#   happen/VB
#   )/)
#   ,/,
#   (NP the/DT events/NNS)
#   do/VBP
#   n't/RB
#   make/VB
#   (NP a/DT lot/NN)
#   of/IN
#   (NP sense/NN)
#   ,/,
#   (NP the/DT dialogue/NN)
#   is/VBZ
#   (NP cringe/NN)
#   ,/,
#   (NP the/DT characters/NNS)
#   are/VBP
#   very/RB
#   cartoonish/JJ
#   and/CC
#   unbelievable/JJ
#   ./.)
# (NP The/DT plot/NN)
# (NP the/DT events/NNS)
# (NP cliche/NN)
# (NP somebody/NN)
# (NP the/DT bad/JJ movies/NNS)
# (NP the/DT events/NNS)
# (NP a/DT lot/NN)
# (NP sense/NN)
# (NP the/DT dialogue/NN)
# (NP cringe/NN)
# (NP the/DT characters/NNS)
# (S
#   What/WP
#   they/PRP
#   say/VBP
#   do/VBP
#   n't/RB
#   make/VB
#   (NP a/DT lot/NN)
#   of/IN
#   (NP sense/NN)
#   ,/,
#   and/CC
#   also/RB
#   (NP nobody/NN)
#   reacts/VBZ
#   to/TO
#   (NP events/NNS)
#   in/IN
#   (NP the/DT way/NN)
#   (NP a/DT normal/JJ person/NN)
#   would/MD
#   do/VB
#   ./.)
# (NP a/DT lot/NN)
# (NP sense/NN)
# (NP nobody/NN)
# (NP events/NNS)
# (NP the/DT way/NN)
# (NP a/DT normal/JJ person/NN)
# (S
#   These/DT
#   are/VBP
#   (NP comic/JJ book/NN)
#   (NP characters/NNS)
#   ,/,
#   not/RB
#   (NP people/NNS)
#   ./.)
# (NP comic/JJ book/NN)
# (NP characters/NNS)
# (NP people/NNS)
# (S
#   When/WRB
#   they/PRP
#   try/VBP
#   to/TO
#   suggest/VB
#   some/DT
#   of/IN
#   (NP these/DT people/NNS)
#   are/VBP
#   (NP crime/NN)
#   (NP lords/NNS)
#   it/PRP
#   's/VBZ
#   hilarious/JJ
#   ,/,
#   you/PRP
#   ca/MD
#   n't/RB
#   help/VB
#   but/CC
#   chuckle/VB
#   ./.)
# (NP these/DT people/NNS)
# (NP crime/NN)
# (NP lords/NNS)
# (S
#   (NP Real/JJ mobsters/NNS)
#   would/MD
#   have/VB
#   (NP these/DT guys/NNS)
#   for/IN
#   (NP breakfast/NN)
#   ./.)
# (NP Real/JJ mobsters/NNS)
# (NP these/DT guys/NNS)
# (NP breakfast/NN)
# (S
#   Ironically/RB
#   ,/,
#   (NP the/DT fly/JJ girls/NNS)
#   in/IN
#   (NP the/DT movie/NN)
#   are/VBP
#   actually/RB
#   more/RBR
#   believable/JJ
#   ,/,
#   because/IN
#   (NP the/DT way/NN)
#   they/PRP
#   live/VBP
#   it/PRP
#   is/VBZ
#   more/RBR
#   close/JJ
#   to/TO
#   (NP some/DT girls/NNS)
#   I/PRP
#   know.I/VBP
#   never/RB
#   saw/VBD
#   any/DT
#   of/IN
#   the/DT
#   ``/``
#   (NP Shades/NNP)
#   of/IN
#   (NP Gray/NNP)
#   ''/''
#   (NP movies/NNS)
#   ,/,
#   but/CC
#   for/IN
#   (NP a/DT good/JJ part/NN)
#   it/PRP
#   felt/VBD
#   like/IN
#   (NP a/DT relative/NN)
#   of/IN
#   (NP those/DT movies/NNS)
#   ./.)
# (NP the/DT fly/JJ girls/NNS)
# (NP the/DT movie/NN)
# (NP the/DT way/NN)
# (NP some/DT girls/NNS)
# (NP Shades/NNP)
# (NP Gray/NNP)
# (NP movies/NNS)
# (NP a/DT good/JJ part/NN)
# (NP a/DT relative/NN)
# (NP those/DT movies/NNS)
# (S
#   (NP The/DT sex/NN)
#   (NP scenes/NNS)
#   are/VBP
#   pretty/RB
#   convincing/JJ
#   ,/,
#   I/PRP
#   'm/VBP
#   still/RB
#   unsure/JJ
#   if/IN
#   (NP the/DT oral/JJ sex/NN)
#   was/VBD
#   actually/RB
#   simulated/VBN
#   or/CC
#   not.The/RB
#   (NP good/JJ things/NNS)
#   I/PRP
#   can/MD
#   say/VB
#   about/IN
#   this/DT
#   are/VBP
#   (/(
#   and/CC
#   each/DT
#   gets/VBZ
#   (NP a/DT star/NN)
#   from/IN
#   me/PRP
#   )/)
#   :/:
#   (NP the/DT photography/NN)
#   is/VBZ
#   pretty/RB
#   good/JJ
#   ,/,
#   at/IN
#   least/JJS
#   (NP the/DT cinematographer/NN)
#   knew/VBD
#   what/WP
#   he/PRP
#   was/VBD
#   (NP doingthe/JJ actors/NNS)
#   are/VBP
#   generally/RB
#   pretty/RB
#   easy/JJ
#   on/IN
#   (NP the/DT eye/NN)
#   ,/,
#   (NP the/DT costumes/NNS)
#   are/VBP
#   also/RB
#   solid/JJ
#   ,/,
#   there/EX
#   are/VBP
#   nice/JJ
#   and/CC
#   (NP diverse/JJ locations/NNS)
#   ,/,
#   (NP hence/NN)
#   there/EX
#   is/VBZ
#   always/RB
#   (NP something/NN)
#   appealing/VBG
#   to/TO
#   look/VB
#   at/IN
#   on/IN
#   (NP the/DT screenthe/NN)
#   (NP sex/NN)
#   (NP scenes/NNS)
#   are/VBP
#   pretty/RB
#   good/JJ
#   if/IN
#   you/PRP
#   're/VBP
#   into/IN
#   (NP that/DT kind/NN)
#   of/IN
#   (NP thing/NN)
#   (/(
#   I/PRP
#   am/VBP
#   )/)
#   Should/MD
#   you/PRP
#   see/VB
#   it/PRP
#   ?/.)
# (NP The/DT sex/NN)
# (NP scenes/NNS)
# (NP the/DT oral/JJ sex/NN)
# (NP good/JJ things/NNS)
# (NP a/DT star/NN)
# (NP the/DT photography/NN)
# (NP the/DT cinematographer/NN)
# (NP doingthe/JJ actors/NNS)
# (NP the/DT eye/NN)
# (NP the/DT costumes/NNS)
# (NP diverse/JJ locations/NNS)
# (NP hence/NN)
# (NP something/NN)
# (NP the/DT screenthe/NN)
# (NP sex/NN)
# (NP scenes/NNS)
# (NP that/DT kind/NN)
# (NP thing/NN)
# (S
#   Well/RB
#   I/PRP
#   do/VBP
#   n't/RB
#   know/VB
#   ,/,
#   even/RB
#   with/IN
#   (NP the/DT low/JJ score/NN)
#   that/IN
#   I/PRP
#   gave/VBD
#   it/PRP
#   ,/,
#   I/PRP
#   feel/VBP
#   like/IN
#   (NP people/NNS)
#   should/MD
#   make/VB
#   up/RP
#   their/PRP$
#   (NP own/JJ mind/NN)
#   and/CC
#   not/RB
#   take/VB
#   (NP someone/NN)
#   's/POS
#   (NP else/JJ opinion/NN)
#   on/IN
#   it/PRP
#   ./.)
# (NP the/DT low/JJ score/NN)
# (NP people/NNS)
# (NP own/JJ mind/NN)
# (NP someone/NN)
# (NP else/JJ opinion/NN)
# (S
#   Besides/IN
#   ,/,
#   I/PRP
#   think/VBP
#   (NP people/NNS)
#   should/MD
#   watch/VB
#   (NP bad/JJ movies/NNS)
#   from/IN
#   (NP time/NN)
#   to/TO
#   (NP time/NN)
#   ,/,
#   to/TO
#   be/VB
#   able/JJ
#   to/TO
#   understand/VB
#   better/JJR
#   why/WRB
#   (NP other/JJ movies/NNS)
#   are/VBP
#   good/JJ
#   ,/,
#   and/CC
#   to/TO
#   be/VB
#   more/RBR
#   appreciative/JJ
#   of/IN
#   those/DT
#   ,/,
#   as/IN
#   (NP a/DT consequence.So/NN)
#   (NP yeah/NN)
#   ,/,
#   go/VBP
#   (NP watch/NN)
#   it/PRP
#   ,/,
#   but/CC
#   keep/VB
#   your/PRP$
#   (NP expectations/NNS)
#   ridiculously/RB
#   low/JJ
#   ./.)
# (NP people/NNS)
# (NP bad/JJ movies/NNS)
# (NP time/NN)
# (NP time/NN)
# (NP other/JJ movies/NNS)
# (NP a/DT consequence.So/NN)
# (NP yeah/NN)
# (NP watch/NN)
# (NP expectations/NNS)
# (S
#   I/PRP
#   have/VBP
#   read/VBN
#   (NP a/DT few/JJ stories/NNS)
#   on/IN
#   (NP the/DT app/NN)
#   and/CC
#   (NP this/DT movie/NN)
#   is/VBZ
#   definitely/RB
#   (NP a/DT good/JJ reason/NN)
#   why/WRB
#   (NP some/DT books/NNS)
#   should/MD
#   never/RB
#   make/VB
#   it/PRP
#   on/IN
#   (NP the/DT screen/NN)
#   ./.)
# (NP a/DT few/JJ stories/NNS)
# (NP the/DT app/NN)
# (NP this/DT movie/NN)
# (NP a/DT good/JJ reason/NN)
# (NP some/DT books/NNS)
# (NP the/DT screen/NN)
# (S It/PRP was/VBD fun/JJ but/CC ridiculous/JJ and/CC pathetic/JJ ./.)
# (S
#   Never/RB
#   seen/VBN
#   (NP such/JJ horrible/JJ movie/NN)
#   in/IN
#   my/PRP$
#   (NP entire/JJ life/NN)
#   ./.)
# (NP such/JJ horrible/JJ movie/NN)
# (NP entire/JJ life/NN)
# (S
#   (NP The/DT concept/NN)
#   ,/,
#   acting/VBG
#   ,/,
#   (NP scenes/NNS)
#   ,/,
#   basically/RB
#   (NP everything/NN)
#   is/VBZ
#   wrong/JJ
#   in/IN
#   (NP this/DT movie/NN)
#   ./.)
# (NP The/DT concept/NN)
# (NP scenes/NNS)
# (NP everything/NN)
# (NP this/DT movie/NN)
# (S
#   Such/JJ
#   stupid/JJ
#   ,/,
#   worthless/JJ
#   ,/,
#   (NP toxic/JJ story/NN)
#   (NP line/NN)
#   ./.)
# (NP toxic/JJ story/NN)
# (NP line/NN)
# (S
#   (NP Glorification/NN)
#   of/IN
#   (NP relationships/NNS)
#   where/WRB
#   (NP the/DT sole/JJ role/NN)
#   of/IN
#   (NP a/DT woman/NN)
#   is/VBZ
#   to/TO
#   be/VB
#   (NP a/DT slave/NN)
#   and/CC
#   fulfill/VB
#   (NP the/DT desires/NNS)
#   of/IN
#   (NP a/DT harsh/NN)
#   ,/,
#   egotistic/JJ
#   ,/,
#   (NP rich/JJ male/NN)
#   (NP character/NN)
#   ./.)
# (NP Glorification/NN)
# (NP relationships/NNS)
# (NP the/DT sole/JJ role/NN)
# (NP a/DT woman/NN)
# (NP a/DT slave/NN)
# (NP the/DT desires/NNS)
# (NP a/DT harsh/NN)
# (NP rich/JJ male/NN)
# (NP character/NN)
# (S
#   365/CD
#   (NP days/NNS)
#   is/VBZ
#   about/IN
#   a/DT
#   successful/JJ
#   but/CC
#   (NP unhappy/JJ young/JJ woman/NN)
#   whose/WP$
#   (NP path/NN)
#   crosses/VBZ
#   with/IN
#   that/DT
#   of/IN
#   a/DT
#   young/JJ
#   ,/,
#   (NP handsome/JJ mafia/NN)
#   (NP boss/NN)
#   ./.)
# (NP days/NNS)
# (NP unhappy/JJ young/JJ woman/NN)
# (NP path/NN)
# (NP handsome/JJ mafia/NN)
# (NP boss/NN)
# (S
#   He/PRP
#   kidnaps/VBZ
#   her/PRP$
#   and/CC
#   gives/VBZ
#   her/PRP$
#   (NP a/DT deadline/NN)
#   of/IN
#   one/CD
#   (NP year/NN)
#   to/TO
#   fall/VB
#   in/IN
#   (NP love/NN)
#   with/IN
#   him/PRP
#   ./.)
# (NP a/DT deadline/NN)
# (NP year/NN)
# (NP love/NN)
# (S
#   Despite/IN
#   (NP the/DT rough/JJ introduction/NN)
#   ,/,
#   she/PRP
#   eventually/RB
#   gives/VBZ
#   in/IN
#   to/TO
#   his/PRP$
#   (NP charms/NNS)
#   and/CC
#   (NP falls/NNS)
#   in/IN
#   (NP love/NN)
#   with/IN
#   him/PRP
#   ./.)
# (NP the/DT rough/JJ introduction/NN)
# (NP charms/NNS)
# (NP falls/NNS)
# (NP love/NN)
# (S
#   (NP The/DT central/JJ core/NN)
#   of/IN
#   (NP the/DT movie/NN)
#   is/VBZ
#   (NP domination/NN)
#   ,/,
#   or/CC
#   how/WRB
#   (NP the/DT male/JJ protagonist/NN)
#   uses/VBZ
#   his/PRP$
#   (NP raw/JJ masculinity/NN)
#   to/TO
#   completely/RB
#   overwhelm/VB
#   (NP the/DT girl/NN)
#   until/IN
#   she/PRP
#   eventually/RB
#   gives/VBZ
#   in/IN
#   to/TO
#   her/PRP$
#   (NP lust/NN)
#   ,/,
#   so/RB
#   ,/,
#   (NP this/DT movie/NN)
#   is/VBZ
#   a/DT
#   very/RB
#   (NP obvious/JJ copycat/NN)
#   of/IN
#   50/CD
#   (NP Shades/NNS)
#   of/IN
#   (NP Grey.Now/NNP)
#   ,/,
#   (NP this/DT movie/NN)
#   is/VBZ
#   n't/RB
#   exactly/RB
#   bad/JJ
#   ./.)
# (NP The/DT central/JJ core/NN)
# (NP the/DT movie/NN)
# (NP domination/NN)
# (NP the/DT male/JJ protagonist/NN)
# (NP raw/JJ masculinity/NN)
# (NP the/DT girl/NN)
# (NP lust/NN)
# (NP this/DT movie/NN)
# (NP obvious/JJ copycat/NN)
# (NP Shades/NNS)
# (NP Grey.Now/NNP)
# (NP this/DT movie/NN)
# (S
#   It/PRP
#   's/VBZ
#   not/RB
#   good/JJ
#   either/CC
#   ,/,
#   (NP mind/NN)
#   you/PRP
#   ,/,
#   but/CC
#   once/RB
#   you/PRP
#   understand/VBP
#   why/WRB
#   it/PRP
#   was/VBD
#   made/VBN
#   in/IN
#   (NP the/DT first/JJ place/NN)
#   ,/,
#   you/PRP
#   can/MD
#   at/IN
#   least/JJS
#   understand/VB
#   its/PRP$
#   (NP motivation/NN)
#   ./.)
# (NP mind/NN)
# (NP the/DT first/JJ place/NN)
# (NP motivation/NN)
# (S
#   There/EX
#   are/VBP
#   two/CD
#   (NP ways/NNS)
#   of/IN
#   looking/VBG
#   at/IN
#   (NP this/DT film:1/NN)
#   ./.)
# (NP ways/NNS)
# (NP this/DT film:1/NN)
# (S
#   You/PRP
#   try/VBP
#   to/TO
#   look/VB
#   at/IN
#   (NP this/DT movie/NN)
#   at/IN
#   (NP a/DT normal/JJ light/NN)
#   ,/,
#   and/CC
#   you/PRP
#   immediately/RB
#   notice/VBP
#   one/CD
#   (NP thing/NN)
#   :/:
#   it/PRP
#   draws/VBZ
#   (NP a/DT lot/NN)
#   of/IN
#   (NP inspiration/NN)
#   from/IN
#   50/CD
#   (NP Shades/NNS)
#   of/IN
#   (NP Grey/NNP)
#   ,/,
#   but/CC
#   it/PRP
#   adds/VBZ
#   a/DT
#   completely/RB
#   ludicrous/JJ
#   kidnapping/VBG
#   (NP scenario/NN)
#   ./.)
# (NP this/DT movie/NN)
# (NP a/DT normal/JJ light/NN)
# (NP thing/NN)
# (NP a/DT lot/NN)
# (NP inspiration/NN)
# (NP Shades/NNS)
# (NP Grey/NNP)
# (NP scenario/NN)
# (S
#   It/PRP
#   's/VBZ
#   like/IN
#   if/IN
#   50/CD
#   (NP Shades/NNS)
#   collided/VBD
#   at/IN
#   very/RB
#   (NP high/JJ speeds/NNS)
#   with/IN
#   (NP Beauty/NNP)
#   and/CC
#   (NP the/DT Beast/NNP)
#   ,/,
#   then/RB
#   (NP someone/NN)
#   filmed/VBD
#   (NP the/DT tragic/NN)
#   ,/,
#   (NP messy/JJ aftermath/NN)
#   and/CC
#   sold/VBD
#   it/PRP
#   as/IN
#   (NP a/DT movie/NN)
#   ./.)
# (NP Shades/NNS)
# (NP high/JJ speeds/NNS)
# (NP Beauty/NNP)
# (NP the/DT Beast/NNP)
# (NP someone/NN)
# (NP the/DT tragic/NN)
# (NP messy/JJ aftermath/NN)
# (NP a/DT movie/NN)
# (S
#   (NP The/DT first/JJ act/NN)
#   seems/VBZ
#   (NP pretty/JJ straightforward/NN)
#   :/:
#   (NP the/DT young/JJ girl/NN)
#   is/VBZ
#   deeply/RB
#   frustrated/JJ
#   with/IN
#   her/PRP$
#   (NP love/NN)
#   (NP life/NN)
#   and/CC
#   is/VBZ
#   set/VBN
#   to/TO
#   meet/VB
#   (NP the/DT handsome/NN)
#   ,/,
#   (NP assertive/JJ gangster/NN)
#   ./.)
# (NP The/DT first/JJ act/NN)
# (NP pretty/JJ straightforward/NN)
# (NP the/DT young/JJ girl/NN)
# (NP love/NN)
# (NP life/NN)
# (NP the/DT handsome/NN)
# (NP assertive/JJ gangster/NN)
# (S
#   But/CC
#   how/WRB
#   (NP the/DT meeting/NN)
#   goes/VBZ
#   is/VBZ
#   where/WRB
#   (NP the/DT craziness/NN)
#   starts/VBZ
#   :/:
#   he/PRP
#   intentionally/RB
#   snatches/VBZ
#   her/PRP
#   off/RP
#   (NP the/DT street/NN)
#   and/CC
#   holds/VBZ
#   her/PRP$
#   (NP captive/NN)
#   ./.)
# (NP the/DT meeting/NN)
# (NP the/DT craziness/NN)
# (NP the/DT street/NN)
# (NP captive/NN)
# (S
#   Then/RB
#   tells/VBZ
#   her/PRP$
#   he/PRP
#   will/MD
#   only/RB
#   let/VB
#   her/PRP
#   go/VB
#   if/IN
#   she/PRP
#   manages/VBZ
#   to/TO
#   not/RB
#   fall/VB
#   in/IN
#   (NP love/NN)
#   with/IN
#   him/PRP
#   in/IN
#   one/CD
#   (NP year/NN)
#   ./.)
# (NP love/NN)
# (NP year/NN)
# (S
#   This/DT
#   already/RB
#   feels/VBZ
#   like/IN
#   (NP a/DT plot/NN)
#   picked/VBD
#   straight/RB
#   from/IN
#   (NP a/DT Law/NNP)
#   and/CC
#   (NP Order/NNP)
#   :/:
#   (NP SVU/NNP)
#   (NP episode/NN)
#   ./.)
# (NP a/DT plot/NN)
# (NP a/DT Law/NNP)
# (NP Order/NNP)
# (NP SVU/NNP)
# (NP episode/NN)
# (S
#   (NP The/DT explanation/NN)
#   he/PRP
#   gives/VBZ
#   for/IN
#   why/WRB
#   he/PRP
#   went/VBD
#   after/IN
#   her/PRP
#   in/IN
#   (NP the/DT first/JJ place/NN)
#   just/RB
#   adds/VBZ
#   (NP another/DT thick/JJ layer/NN)
#   of/IN
#   (NP insanity/NN)
#   to/TO
#   (NP the/DT bananas/NNS)
#   cake/VBP
#   ./.)
# (NP The/DT explanation/NN)
# (NP the/DT first/JJ place/NN)
# (NP another/DT thick/JJ layer/NN)
# (NP insanity/NN)
# (NP the/DT bananas/NNS)
# (S
#   (NP The/DT events/NNS)
#   that/WDT
#   follow/VBP
#   are/VBP
#   so/RB
#   astoundingly/RB
#   bizarre/JJ
#   that/IN
#   they/PRP
#   boggle/VBP
#   (NP the/DT mind/NN)
#   ./.)
# (NP The/DT events/NNS)
# (NP the/DT mind/NN)
# (S
#   It/PRP
#   does/VBZ
#   n't/RB
#   take/VB
#   too/RB
#   long/RB
#   for/IN
#   her/PRP$
#   to/TO
#   accept/VB
#   her/PRP$
#   (NP predicament/NN)
#   ,/,
#   and/CC
#   after/IN
#   what/WP
#   appears/VBZ
#   to/TO
#   be/VB
#   no/RB
#   more/JJR
#   than/IN
#   (NP a/DT day/NN)
#   ,/,
#   she/PRP
#   is/VBZ
#   already/RB
#   playing/VBG
#   (NP flirty/JJ games/NNS)
#   and/CC
#   teasing/VBG
#   him/PRP
#   ./.)
# (NP predicament/NN)
# (NP a/DT day/NN)
# (NP flirty/JJ games/NNS)
# (S
#   Once/RB
#   she/PRP
#   gets/VBZ
#   her/PRP$
#   (NP cell/NN)
#   (NP phone/NN)
#   and/CC
#   her/PRP$
#   (NP laptop/JJ back/NN)
#   ,/,
#   she/PRP
#   never/RB
#   (NP bothers/NNS)
#   to/TO
#   ,/,
#   say/VB
#   ,/,
#   call/VB
#   (NP the/DT police/NN)
#   ,/,
#   or/CC
#   tell/VB
#   her/PRP$
#   (NP family/NN)
#   what/WP
#   's/VBZ
#   going/VBG
#   on/IN
#   ./.)
# (NP cell/NN)
# (NP phone/NN)
# (NP laptop/JJ back/NN)
# (NP bothers/NNS)
# (NP the/DT police/NN)
# (NP family/NN)
# (S
#   For/IN
#   (NP half/NN)
#   of/IN
#   (NP the/DT movie/NN)
#   ,/,
#   she/PRP
#   acts/VBZ
#   more/RBR
#   like/IN
#   (NP a/DT girl/NN)
#   just/RB
#   teasing/VBG
#   and/CC
#   trying/VBG
#   make/VB
#   her/PRP$
#   (NP crush/NN)
#   (NP jealous/NN)
#   ,/,
#   than/IN
#   like/IN
#   (NP a/DT woman/NN)
#   who/WP
#   has/VBZ
#   just/RB
#   being/VBG
#   abducted/VBN
#   for/IN
#   (NP sexual/JJ purposes/NNS)
#   by/IN
#   (NP a/DT deranged/JJ murderer/NN)
#   ./.)
# (NP half/NN)
# (NP the/DT movie/NN)
# (NP a/DT girl/NN)
# (NP crush/NN)
# (NP jealous/NN)
# (NP a/DT woman/NN)
# (NP sexual/JJ purposes/NNS)
# (NP a/DT deranged/JJ murderer/NN)
# (S
#   In/IN
#   (NP any/DT other/JJ context/NN)
#   ,/,
#   seeing/VBG
#   her/PRP$
#   giving/VBG
#   in/IN
#   ,/,
#   sleeping/VBG
#   with/IN
#   him/PRP
#   and/CC
#   start/VB
#   (NP a/DT relationship/NN)
#   with/IN
#   her/PRP$
#   (NP kidnapper/NN)
#   would/MD
#   be/VB
#   (NP a/DT horrific/JJ story/NN)
#   of/IN
#   (NP a/DT poor/JJ woman/NN)
#   being/VBG
#   forced/VBN
#   against/IN
#   her/PRP$
#   will/MD
#   and/CC
#   ,/,
#   after/IN
#   getting/VBG
#   completely/RB
#   broken/VBN
#   inside/RB
#   ,/,
#   accepting/VBG
#   her/PRP$
#   (NP fate/NN)
#   ./.)
# (NP any/DT other/JJ context/NN)
# (NP a/DT relationship/NN)
# (NP kidnapper/NN)
# (NP a/DT horrific/JJ story/NN)
# (NP a/DT poor/JJ woman/NN)
# (NP fate/NN)
# (S
#   Seeing/VBG
#   her/PRP$
#   (NP mistake/NN)
#   her/PRP$
#   (NP inevitable/JJ Stockholm/NNP)
#   (NP Syndrome/NNP)
#   for/IN
#   truly/RB
#   falling/VBG
#   in/IN
#   (NP love/NN)
#   is/VBZ
#   not/RB
#   only/RB
#   tragic/JJ
#   ,/,
#   it/PRP
#   almost/RB
#   insults/VBZ
#   (NP the/DT intelligence/NN)
#   of/IN
#   (NP the/DT viewer/NN)
#   ./.)
# (NP mistake/NN)
# (NP inevitable/JJ Stockholm/NNP)
# (NP Syndrome/NNP)
# (NP love/NN)
# (NP the/DT intelligence/NN)
# (NP the/DT viewer/NN)
# (S
#   The/DT
#   ending/VBG
#   does/VBZ
#   n't/RB
#   help/VB
#   either/RB
#   ,/,
#   because/IN
#   it/PRP
#   tries/VBZ
#   to/TO
#   be/VB
#   somber/JJ
#   and/CC
#   serious/JJ
#   ,/,
#   but/CC
#   by/IN
#   (NP the/DT time/NN)
#   (NP the/DT film/NN)
#   ends/VBZ
#   ,/,
#   those/DT
#   two/CD
#   (NP words/NNS)
#   have/VBP
#   already/RB
#   flown/VBN
#   through/IN
#   (NP the/DT window/NN)
#   long/RB
#   ago/RB
#   ./.)
# (NP the/DT time/NN)
# (NP the/DT film/NN)
# (NP words/NNS)
# (NP the/DT window/NN)
# (S
#   (NP This/DT movie/NN)
#   seems/VBZ
#   even/RB
#   more/RBR
#   (NP baffling/NN)
#   and/CC
#   out/IN
#   of/IN
#   (NP place/NN)
#   in/IN
#   our/PRP$
#   (NP current/JJ times/NNS)
#   ,/,
#   (NP the/DT era/NN)
#   of/IN
#   (NP the/DT fight/NN)
#   for/IN
#   (NP gender/NN)
#   (NP equality/NN)
#   ,/,
#   (NP the/DT struggle/NN)
#   for/IN
#   (NP greater/JJR respect/NN)
#   for/IN
#   (NP women/NNS)
#   and/CC
#   (NP the/DT MeToo/NNP)
#   (NP movement.I/NN)
#   know/VBP
#   you/PRP
#   are/VBP
#   thinking/VBG
#   this/DT
#   is/VBZ
#   incomprehensible/JJ
#   and/CC
#   bizarre/JJ
#   ./.)
# (NP This/DT movie/NN)
# (NP baffling/NN)
# (NP place/NN)
# (NP current/JJ times/NNS)
# (NP the/DT era/NN)
# (NP the/DT fight/NN)
# (NP gender/NN)
# (NP equality/NN)
# (NP the/DT struggle/NN)
# (NP greater/JJR respect/NN)
# (NP women/NNS)
# (NP the/DT MeToo/NNP)
# (NP movement.I/NN)
# (S
#   I/PRP
#   sure/VBP
#   thought/VBN
#   that/IN
#   (NP way/NN)
#   myself/PRP
#   for/IN
#   (NP the/DT first/JJ half/NN)
#   ./.)
# (NP way/NN)
# (NP the/DT first/JJ half/NN)
# (S
#   But/CC
#   then/RB
#   you/PRP
#   realize/VBP
#   you/PRP
#   are/VBP
#   simply/RB
#   looking/VBG
#   at/IN
#   it/PRP
#   wrong/JJ
#   ./.)
# (S
#   This/DT
#   is/VBZ
#   still/RB
#   (NP no/DT Citizen/NNP)
#   (NP Kane/NNP)
#   ,/,
#   (NP mind/NN)
#   you/PRP
#   ,/,
#   but/CC
#   it/PRP
#   has/VBZ
#   a/DT
#   very/RB
#   (NP simple/JJ reason/NN)
#   to/TO
#   exist.2/VB
#   ./.)
# (NP no/DT Citizen/NNP)
# (NP Kane/NNP)
# (NP mind/NN)
# (NP simple/JJ reason/NN)
# (S (NP This/DT movie/NN) is/VBZ (NP a/DT complete/JJ fantasy/NN) ./.)
# (NP This/DT movie/NN)
# (NP a/DT complete/JJ fantasy/NN)
# (S
#   (NP The/DT female/JJ lead/NN)
#   is/VBZ
#   in/IN
#   an/DT
#   extremely/RB
#   (NP relatable/JJ situation/NN)
#   :/:
#   she/PRP
#   has/VBZ
#   a/DT
#   vaguely/RB
#   defined/VBN
#   but/CC
#   supposedly/RB
#   (NP successful/JJ job/NN)
#   ,/,
#   but/CC
#   her/PRP$
#   (NP love/NN)
#   (NP life/NN)
#   is/VBZ
#   (NP a/DT mess/NN)
#   ./.)
# (NP The/DT female/JJ lead/NN)
# (NP relatable/JJ situation/NN)
# (NP successful/JJ job/NN)
# (NP love/NN)
# (NP life/NN)
# (NP a/DT mess/NN)
# (S
#   Her/PRP$
#   (NP deadbeat/NN)
#   (NP boyfriend/NN)
#   is/VBZ
#   (NP an/DT amalgamation/NN)
#   of/IN
#   (NP many/JJ things/NNS)
#   that/WDT
#   are/VBP
#   collectively/RB
#   considered/VBN
#   very/RB
#   (NP bad/JJ traits/NNS)
#   for/IN
#   (NP a/DT male/JJ partner/NN)
#   :/:
#   (NP lazy/NN)
#   ,/,
#   makes/VBZ
#   (NP tasteless/JJ jokes/NNS)
#   about/IN
#   her/PRP$
#   in/IN
#   (NP front/NN)
#   of/IN
#   their/PRP$
#   (NP friends/NNS)
#   ,/,
#   does/VBZ
#   n't/RB
#   pay/VB
#   (NP attention/NN)
#   to/TO
#   her/PRP$
#   (NP feelings/NNS)
#   and/CC
#   (NP needs/NNS)
#   and/CC
#   ,/,
#   (/(
#   shocking/VBG
#   )/)
#   ,/,
#   leaves/VBZ
#   her/PRP$
#   (NP behind/NN)
#   on/IN
#   her/PRP$
#   (NP birthday/NN)
#   ,/,
#   to/TO
#   go/VB
#   see/VB
#   (NP a/DT place/NN)
#   they/PRP
#   had/VBD
#   previously/RB
#   agreed/VBN
#   to/TO
#   go/VB
#   to/TO
#   together/RB
#   ./.)
# (NP deadbeat/NN)
# (NP boyfriend/NN)
# (NP an/DT amalgamation/NN)
# (NP many/JJ things/NNS)
# (NP bad/JJ traits/NNS)
# (NP a/DT male/JJ partner/NN)
# (NP lazy/NN)
# (NP tasteless/JJ jokes/NNS)
# (NP front/NN)
# (NP friends/NNS)
# (NP attention/NN)
# (NP feelings/NNS)
# (NP needs/NNS)
# (NP behind/NN)
# (NP birthday/NN)
# (NP a/DT place/NN)
# (S
#   He/PRP
#   also/RB
#   seems/VBZ
#   very/RB
#   indifferent/JJ
#   to/TO
#   her/PRP$
#   (NP sexual/JJ desires/NNS)
#   ,/,
#   and/CC
#   this/DT
#   is/VBZ
#   (NP the/DT crucial/JJ part/NN)
#   I/PRP
#   'll/MD
#   get/VB
#   to/TO
#   shortly/RB
#   ./.)
# (NP sexual/JJ desires/NNS)
# (NP the/DT crucial/JJ part/NN)
# (S
#   So/RB
#   far/RB
#   ,/,
#   very/RB
#   (NP generic/JJ romantic/JJ movie/NN)
#   (NP stuff/NN)
#   ./.)
# (NP generic/JJ romantic/JJ movie/NN)
# (NP stuff/NN)
# (S
#   (NP The/DT next/JJ step/NN)
#   we/PRP
#   (NP the/DT audience/NN)
#   expect/VBP
#   is/VBZ
#   for/IN
#   (NP a/DT knight/NN)
#   in/IN
#   (NP shiny/JJ armor/NN)
#   to/TO
#   appear/VB
#   and/CC
#   save/VB
#   her/PRP
#   from/IN
#   (NP the/DT dead/JJ relationship/NN)
#   ,/,
#   but/CC
#   this/DT
#   is/VBZ
#   where/WRB
#   (NP the/DT normal/JJ movie/NN)
#   (NP stuff/NN)
#   ends/VBZ
#   :/:
#   her/PRP$
#   savior/JJ
#   just/RB
#   outright/MD
#   (NP kidnaps/NNS)
#   and/CC
#   threatens/VBZ
#   her/PRP
#   ./.)
# (NP The/DT next/JJ step/NN)
# (NP the/DT audience/NN)
# (NP a/DT knight/NN)
# (NP shiny/JJ armor/NN)
# (NP the/DT dead/JJ relationship/NN)
# (NP the/DT normal/JJ movie/NN)
# (NP stuff/NN)
# (NP kidnaps/NNS)
# (S
#   He/PRP
#   takes/VBZ
#   her/PRP
#   to/TO
#   his/PRP$
#   (NP house/NN)
#   and/CC
#   does/VBZ
#   n't/RB
#   allow/VB
#   her/PRP
#   to/TO
#   leave/VB
#   ./.)
# (NP house/NN)
# (S
#   (NP This/DT dangerous/JJ criminal/NN)
#   turns/VBZ
#   out/RP
#   to/TO
#   be/VB
#   an/DT
#   extremely/RB
#   (NP dominating/JJ man/NN)
#   ./.)
# (NP This/DT dangerous/JJ criminal/NN)
# (NP dominating/JJ man/NN)
# (S
#   He/PRP
#   grabs/VBD
#   her/PRP
#   violently/RB
#   ,/,
#   thrashes/VBZ
#   her/PRP$
#   (NP around/NN)
#   and/CC
#   menacingly/RB
#   (NP states/NNS)
#   that/IN
#   she/PRP
#   will/MD
#   cave/VB
#   in/IN
#   to/TO
#   him/PRP
#   ./.)
# (NP around/NN)
# (NP states/NNS)
# (S He/PRP also/RB turns/VBZ out/RP to/TO be/VB very/RB rich/JJ ./.)
# (S He/PRP lives/VBZ in/IN (NP a/DT gigantic/JJ castle/NN) ./.)
# (NP a/DT gigantic/JJ castle/NN)
# (S
#   He/PRP
#   takes/VBZ
#   her/PRP
#   to/TO
#   shop/VB
#   for/IN
#   (NP expensive/JJ clothes/NNS)
#   in/IN
#   (NP luxurious/JJ stores/NNS)
#   ,/,
#   gives/VBZ
#   her/PRP$
#   (NP refined/JJ dinners/NNS)
#   and/CC
#   procures/VBZ
#   any/DT
#   dish/JJ
#   she/PRP
#   desires/VBZ
#   ./.)
# (NP expensive/JJ clothes/NNS)
# (NP luxurious/JJ stores/NNS)
# (NP refined/JJ dinners/NNS)
# (S
#   He/PRP
#   is/VBZ
#   also/RB
#   tall/JJ
#   ,/,
#   muscular/JJ
#   ,/,
#   with/IN
#   (NP a/DT gruff/JJ beard/NN)
#   and/CC
#   (NP a/DT generous/JJ amount/NN)
#   of/IN
#   (NP chest/NN)
#   (NP hair/NN)
#   ./.)
# (NP a/DT gruff/JJ beard/NN)
# (NP a/DT generous/JJ amount/NN)
# (NP chest/NN)
# (NP hair/NN)
# (S
#   Even/RB
#   when/WRB
#   she/PRP
#   tries/VBZ
#   to/TO
#   tease/VB
#   him/PRP
#   and/CC
#   gain/VB
#   (NP the/DT upper/JJ hand/NN)
#   ,/,
#   he/PRP
#   turns/VBZ
#   (NP the/DT tables/NNS)
#   and/CC
#   subdues/VBZ
#   her/PRP
#   ./.)
# (NP the/DT upper/JJ hand/NN)
# (NP the/DT tables/NNS)
# (S
#   He/PRP
#   is/VBZ
#   ,/,
#   by/IN
#   and/CC
#   large/JJ
#   ,/,
#   (NP the/DT textbook/NN)
#   (NP definition/NN)
#   of/IN
#   (NP an/DT alpha/JJ male/NN)
#   ./.)
# (NP the/DT textbook/NN)
# (NP definition/NN)
# (NP an/DT alpha/JJ male/NN)
# (S
#   When/WRB
#   she/PRP
#   tries/VBZ
#   to/TO
#   make/VB
#   him/PRP
#   feel/VB
#   jealous/JJ
#   by/IN
#   dancing/VBG
#   with/IN
#   (NP another/DT man/NN)
#   in/IN
#   (NP a/DT nightclub/NN)
#   ,/,
#   our/PRP$
#   (NP hero/NN)
#   (NP responds/NNS)
#   by/IN
#   shooting/VBG
#   (NP the/DT offender/NN)
#   in/IN
#   (NP the/DT hands/NNS)
#   ,/,
#   and/CC
#   frowning/VBG
#   at/IN
#   her/PRP$
#   until/IN
#   she/PRP
#   apologizes/VBZ
#   ./.)
# (NP another/DT man/NN)
# (NP a/DT nightclub/NN)
# (NP hero/NN)
# (NP responds/NNS)
# (NP the/DT offender/NN)
# (NP the/DT hands/NNS)
# (S
#   And/CC
#   when/WRB
#   they/PRP
#   finally/RB
#   make/VBP
#   (NP love/NN)
#   ,/,
#   it/PRP
#   is/VBZ
#   implied/VBN
#   that/IN
#   it/PRP
#   was/VBD
#   (NP everything/NN)
#   she/PRP
#   ever/RB
#   hoped/VBD
#   for/IN
#   -/:
#   he/PRP
#   makes/VBZ
#   her/PRP
#   feel/VB
#   like/IN
#   (NP a/DT Woman/NNP)
#   ,/,
#   (NP dammit/NN)
#   ./.)
# (NP love/NN)
# (NP everything/NN)
# (NP a/DT Woman/NNP)
# (NP dammit/NN)
# (S
#   This/DT
#   is/VBZ
#   (NP the/DT moment/NN)
#   when/WRB
#   (NP something/NN)
#   (NP clicks/NNS)
#   in/IN
#   your/PRP$
#   (NP mind/NN)
#   ./.)
# (NP the/DT moment/NN)
# (NP something/NN)
# (NP clicks/NNS)
# (NP mind/NN)
# (S
#   (NP This/DT movie/NN)
#   takes/VBZ
#   (NP a/DT lot/NN)
#   of/IN
#   (NP influences/NNS)
#   from/IN
#   50/CD
#   (NP Shades/NNS)
#   ,/,
#   but/CC
#   they/PRP
#   did/VBD
#   n't/RB
#   come/VBN
#   from/IN
#   nowhere/RB
#   ./.)
# (NP This/DT movie/NN)
# (NP a/DT lot/NN)
# (NP influences/NNS)
# (NP Shades/NNS)
# (S Let/VB 's/PRP get/VB (NP a/DT little/JJ dirty/NN) here/RB ./.)
# (NP a/DT little/JJ dirty/NN)
# (S
#   How/WRB
#   many/JJ
#   of/IN
#   us/PRP
#   here/RB
#   have/VBP
#   played/VBN
#   ,/,
#   or/CC
#   heard/VB
#   about/IN
#   (NP someone/NN)
#   who/WP
#   plays/VBZ
#   ,/,
#   (NP fetishes/NNS)
#   and/CC
#   (NP fantasies/NNS)
#   with/IN
#   their/PRP$
#   (NP SOs/NNP)
#   ,/,
#   and/CC
#   how/WRB
#   many/JJ
#   of/IN
#   (NP those/DT fantasies/NNS)
#   usually/RB
#   include/VBP
#   popular/JJ
#   ,/,
#   silly/RB
#   (NP scenarios/NNS)
#   like/IN
#   (NP the/DT boyfriend/husband/NN)
#   (NP roleplaying/NN)
#   as/IN
#   (NP a/DT police/NN)
#   (NP officer/NN)
#   ,/,
#   catching/VBG
#   (NP the/DT bandit/NN)
#   played/VBN
#   by/IN
#   (NP the/DT wife/girlfriend/NN)
#   ,/,
#   and/CC
#   taking/VBG
#   her/PRP$
#   into/IN
#   (NP custody/NN)
#   for/IN
#   ``/``
#   (NP interrogation/NN)
#   and/CC
#   (NP full/JJ body/NN)
#   (NP search/NN)
#   ''/''
#   ?/.)
# (NP someone/NN)
# (NP fetishes/NNS)
# (NP fantasies/NNS)
# (NP SOs/NNP)
# (NP those/DT fantasies/NNS)
# (NP scenarios/NNS)
# (NP the/DT boyfriend/husband/NN)
# (NP roleplaying/NN)
# (NP a/DT police/NN)
# (NP officer/NN)
# (NP the/DT bandit/NN)
# (NP the/DT wife/girlfriend/NN)
# (NP custody/NN)
# (NP interrogation/NN)
# (NP full/JJ body/NN)
# (NP search/NN)
# (S Then/RB it/PRP hits/VBZ you/PRP ./.)
# (S
#   (NP This/DT movie/NN)
#   does/VBZ
#   n't/RB
#   make/VB
#   (NP logical/JJ sense/NN)
#   because/IN
#   it/PRP
#   does/VBZ
#   n't/RB
#   have/VB
#   to/TO
#   ./.)
# (NP This/DT movie/NN)
# (NP logical/JJ sense/NN)
# (S
#   It/PRP
#   's/VBZ
#   just/RB
#   two/CD
#   (NP hours/NNS)
#   of/IN
#   (NP a/DT bland/NN)
#   ,/,
#   (NP female/JJ lead/NN)
#   who/WP
#   's/VBZ
#   (NP a/DT stand/NN)
#   in/IN
#   for/IN
#   (NP the/DT woman/NN)
#   watching/VBG
#   (NP the/DT movie/NN)
#   ,/,
#   and/CC
#   living/VBG
#   the/DT
#   fantastic/JJ
#   ,/,
#   (NP outlandish/JJ fantasy/NN)
#   that/IN
#   I/PRP
#   suppose/VBP
#   (NP many/JJ girls/NNS)
#   and/CC
#   (NP women/NNS)
#   out/RP
#   there/RB
#   enjoy/VB
#   thinking/VBG
#   about/IN
#   :/:
#   being/VBG
#   seduced/VBN
#   and/CC
#   dominated/VBN
#   by/IN
#   an/DT
#   otherwordly/RB
#   (NP alpha/JJ male/NN)
#   who/WP
#   then/RB
#   vigorously/RB
#   sates/VBZ
#   their/PRP$
#   (NP sexual/JJ desires/NNS)
#   ./.)
# (NP hours/NNS)
# (NP a/DT bland/NN)
# (NP female/JJ lead/NN)
# (NP a/DT stand/NN)
# (NP the/DT woman/NN)
# (NP the/DT movie/NN)
# (NP outlandish/JJ fantasy/NN)
# (NP many/JJ girls/NNS)
# (NP women/NNS)
# (NP alpha/JJ male/NN)
# (NP sexual/JJ desires/NNS)
# (S
#   (NP This/DT movie/NN)
#   just/RB
#   uses/VBZ
#   a/DT
#   ``/``
#   girl/JJ
#   gets/VBZ
#   kidnapped/VBN
#   ''/''
#   (NP scenario/NN)
#   ,/,
#   50/CD
#   (NP Shades/NNP)
#   simply/RB
#   went/VBD
#   the/DT
#   more/RBR
#   (NP niche/JJ route/NN)
#   with/IN
#   (NP BDSM/NNP)
#   ./.)
# (NP This/DT movie/NN)
# (NP scenario/NN)
# (NP Shades/NNP)
# (NP niche/JJ route/NN)
# (NP BDSM/NNP)
# (S
#   (NP Simple/NN)
#   ,/,
#   (NP nonsensical/JJ plots/NNS)
#   that/WDT
#   serve/VBP
#   purely/RB
#   to/TO
#   let/VB
#   (NP the/DT female/JJ viewers/NNS)
#   vicariously/RB
#   live/VBP
#   (NP a/DT sexual/JJ fantasy.I/NN)
#   'm/VBP
#   going/VBG
#   to/TO
#   say/VB
#   it/PRP
#   out/RP
#   loud/JJ
#   :/:
#   this/DT
#   is/VBZ
#   (NP a/DT porn/JJ movie/NN)
#   ./.)
# (NP Simple/NN)
# (NP nonsensical/JJ plots/NNS)
# (NP the/DT female/JJ viewers/NNS)
# (NP a/DT sexual/JJ fantasy.I/NN)
# (NP a/DT porn/JJ movie/NN)
# (S
#   It/PRP
#   's/VBZ
#   (NP a/DT porno/NN)
#   made/VBN
#   for/IN
#   (NP women/NNS)
#   ./.)
# (NP a/DT porno/NN)
# (NP women/NNS)
# (S
#   And/CC
#   there/EX
#   is/VBZ
#   absolutely/RB
#   (NP nothing/NN)
#   wrong/JJ
#   with/IN
#   this/DT
#   ./.)
# (NP nothing/NN)
# (S
#   This/DT
#   is/VBZ
#   (NP nothing/NN)
#   more/JJR
#   than/IN
#   (NP a/DT pure/NN)
#   ,/,
#   (NP sexual/JJ guilty/JJ pleasure/NN)
#   that/WDT
#   obviously/RB
#   would/MD
#   never/RB
#   work/VB
#   in/IN
#   (NP the/DT real/JJ world/NN)
#   ./.)
# (NP nothing/NN)
# (NP a/DT pure/NN)
# (NP sexual/JJ guilty/JJ pleasure/NN)
# (NP the/DT real/JJ world/NN)
# (S
#   Nothing/VBG
#   different/JJ
#   from/IN
#   a/DT
#   ``/``
#   traditional/JJ
#   ''/''
#   (NP porn/JJ movie/NN)
#   ./.)
# (NP porn/JJ movie/NN)
# (S
#   (NP The/DT only/JJ real/JJ difference/NN)
#   is/VBZ
#   the/DT
#   public/JJ
#   it/PRP
#   is/VBZ
#   aimed/VBN
#   at/IN
#   ./.)
# (NP The/DT only/JJ real/JJ difference/NN)
# (S
#   (NP A/DT normal/JJ porn/JJ movie/NN)
#   for/IN
#   (NP men/NNS)
#   is/VBZ
#   going/VBG
#   to/TO
#   cater/VB
#   to/TO
#   (NP men/NNS)
#   's/POS
#   (NP fantasies/NNS)
#   :/:
#   (NP ludicrous/JJ setups/NNS)
#   ,/,
#   (NP gorgeous/JJ women/NNS)
#   gladly/RB
#   doing/VBG
#   (NP everything/NN)
#   (NP the/DT man/NN)
#   demands/VBZ
#   ,/,
#   (NP explicit/JJ images/NNS)
#   of/IN
#   (NP intercourse/NN)
#   ./.)
# (NP A/DT normal/JJ porn/JJ movie/NN)
# (NP men/NNS)
# (NP men/NNS)
# (NP fantasies/NNS)
# (NP ludicrous/JJ setups/NNS)
# (NP gorgeous/JJ women/NNS)
# (NP everything/NN)
# (NP the/DT man/NN)
# (NP explicit/JJ images/NNS)
# (NP intercourse/NN)
# (S
#   (NP This/DT porn/JJ movie/NN)
#   (/(
#   and/CC
#   50/CD
#   (NP Shades/NNS)
#   as/RB
#   well/RB
#   )/)
#   (NP caters/NNS)
#   to/TO
#   (NP fantasies/NNS)
#   that/WDT
#   are/VBP
#   more/JJR
#   common/JJ
#   for/IN
#   (NP many/JJ women/NNS)
#   :/:
#   a/DT
#   strong/JJ
#   ,/,
#   dominating/VBG
#   (NP male/JJ figure/NN)
#   that/WDT
#   takes/VBZ
#   them/PRP
#   on/IN
#   (NP expensive/JJ trips/NNS)
#   to/TO
#   (NP majestic/JJ locations/NNS)
#   and/CC
#   is/VBZ
#   completely/RB
#   focused/VBN
#   on/IN
#   pleasuring/VBG
#   (NP the/DT woman/NN)
#   ,/,
#   not/RB
#   himself/PRP
#   ./.)
# (NP This/DT porn/JJ movie/NN)
# (NP Shades/NNS)
# (NP caters/NNS)
# (NP fantasies/NNS)
# (NP many/JJ women/NNS)
# (NP male/JJ figure/NN)
# (NP expensive/JJ trips/NNS)
# (NP majestic/JJ locations/NNS)
# (NP the/DT woman/NN)
# (S
#   (NP The/DT only/JJ thing/NN)
#   (NP this/DT movie/NN)
#   really/RB
#   does/VBZ
#   wrong/JJ
#   at/IN
#   (NP this/DT point/NN)
#   is/VBZ
#   being/VBG
#   marketed/VBN
#   as/IN
#   a/DT
#   normal/JJ
#   ,/,
#   (NP traditional/JJ movie/NN)
#   when/WRB
#   it/PRP
#   so/RB
#   clearly/RB
#   is/VBZ
#   not/RB
#   ./.)
# (NP The/DT only/JJ thing/NN)
# (NP this/DT movie/NN)
# (NP this/DT point/NN)
# (NP traditional/JJ movie/NN)
# (S
#   If/IN
#   you/PRP
#   are/VBP
#   (NP a/DT woman/NN)
#   ,/,
#   you/PRP
#   are/VBP
#   probably/RB
#   going/VBG
#   to/TO
#   enjoy/VB
#   living/VBG
#   (NP this/DT fantasy/NN)
#   ,/,
#   and/CC
#   there/EX
#   is/VBZ
#   (NP no/DT shame/NN)
#   in/IN
#   that/DT
#   ./.)
# (NP a/DT woman/NN)
# (NP this/DT fantasy/NN)
# (NP no/DT shame/NN)
# (S
#   It/PRP
#   just/RB
#   makes/VBZ
#   me/PRP
#   realize/VB
#   how/WRB
#   grossly/RB
#   biased/VBD
#   (NP the/DT movie/NN)
#   (NP industry/NN)
#   is/VBZ
#   when/WRB
#   it/PRP
#   comes/VBZ
#   to/TO
#   porn/VB
#   :/:
#   we/PRP
#   are/VBP
#   okay/JJ
#   with/IN
#   all/PDT
#   (NP the/DT millions/NNS)
#   of/IN
#   (NP silly/JJ porno/NN)
#   (NP flicks/NNS)
#   and/CC
#   (NP videos/NNS)
#   aimed/VBN
#   at/IN
#   (NP men/NNS)
#   ,/,
#   but/CC
#   when/WRB
#   we/PRP
#   see/VBP
#   (NP a/DT silly/JJ sexual/JJ fetish/JJ movie/NN)
#   aimed/VBN
#   at/IN
#   (NP women/NNS)
#   ,/,
#   the/DT
#   moviegoing/VBG
#   public/JJ
#   collectively/RB
#   pops/VBP
#   their/PRP$
#   (NP monocles/NNS)
#   in/IN
#   (NP outrage.I/NN)
#   watched/VBD
#   (NP this/DT movie/NN)
#   with/IN
#   my/PRP$
#   (NP wife/NN)
#   and/CC
#   while/IN
#   we/PRP
#   were/VBD
#   trying/VBG
#   to/TO
#   take/VB
#   it/PRP
#   seriously/RB
#   ,/,
#   we/PRP
#   both/DT
#   complained/VBD
#   how/WRB
#   bizarre/JJ
#   (NP the/DT plot/NN)
#   is/VBZ
#   ./.)
# (NP the/DT movie/NN)
# (NP industry/NN)
# (NP the/DT millions/NNS)
# (NP silly/JJ porno/NN)
# (NP flicks/NNS)
# (NP videos/NNS)
# (NP men/NNS)
# (NP a/DT silly/JJ sexual/JJ fetish/JJ movie/NN)
# (NP women/NNS)
# (NP monocles/NNS)
# (NP outrage.I/NN)
# (NP this/DT movie/NN)
# (NP wife/NN)
# (NP the/DT plot/NN)
# (S
#   But/CC
#   once/RB
#   we/PRP
#   understand/VBP
#   what/WP
#   is/VBZ
#   actually/RB
#   at/IN
#   (NP play/NN)
#   here/RB
#   ,/,
#   we/PRP
#   see/VBP
#   it/PRP
#   in/IN
#   (NP a/DT whole/JJ different/JJ light/NN)
#   ./.)
# (NP play/NN)
# (NP a/DT whole/JJ different/JJ light/NN)
# (S
#   This/DT
#   is/VBZ
#   (NP a/DT porn/JJ movie/NN)
#   ,/,
#   and/CC
#   do/VBP
#   n't/RB
#   let/VB
#   (NP the/DT lack/NN)
#   of/IN
#   (NP explicit/JJ imagery/NN)
#   (NP fool/NN)
#   you/PRP
#   (/(
#   there/EX
#   is/VBZ
#   (NP lots/NNS)
#   of/IN
#   (NP nudity/NN)
#   however/RB
#   ,/,
#   so/IN
#   beware/JJ
#   )/)
#   ./.)
# (NP a/DT porn/JJ movie/NN)
# (NP the/DT lack/NN)
# (NP explicit/JJ imagery/NN)
# (NP fool/NN)
# (NP lots/NNS)
# (NP nudity/NN)
# (S
#   If/IN
#   you/PRP
#   are/VBP
#   still/RB
#   not/RB
#   convinced/VBN
#   and/CC
#   will/MD
#   still/RB
#   watch/VB
#   it/PRP
#   thinking/VBG
#   it/PRP
#   is/VBZ
#   a/DT
#   ``/``
#   traditional/JJ
#   ''/''
#   (NP movie/NN)
#   ,/,
#   do/VBP
#   n't/RB
#   bother/VB
#   ,/,
#   and/CC
#   save/VB
#   (NP the/DT disappointment/NN)
#   ./.)
# (NP movie/NN)
# (NP the/DT disappointment/NN)
# (S
#   If/IN
#   ,/,
#   however/RB
#   ,/,
#   you/PRP
#   understand/VBP
#   and/CC
#   accept/VBP
#   it/PRP
#   for/IN
#   what/WP
#   it/PRP
#   is/VBZ
#   ,/,
#   then/RB
#   go/VB
#   ahead/RB
#   at/IN
#   (NP enjoy/NN)
#   it/PRP
#   ./.)
# (NP enjoy/NN)
# (S (NP The/DT plot/NN) was/VBD (NP trash/NN) ./.)
# (NP The/DT plot/NN)
# (NP trash/NN)
# (S
#   Even/RB
#   (NP fifty/JJ shades/NNS)
#   (NP series/NN)
#   had/VBD
#   (NP better/JJR plots/NNS)
#   than/IN
#   this/DT
#   ./.)
# (NP fifty/JJ shades/NNS)
# (NP series/NN)
# (NP better/JJR plots/NNS)
# (S
#   (NP Things/NNS)
#   happen/VBP
#   out/IN
#   of/IN
#   nowhere/RB
#   ,/,
#   I/PRP
#   was/VBD
#   confused/VBN
#   (NP the/DT whole/JJ time/NN)
#   watching/VBG
#   (NP this/DT movie/NN)
#   ./.)
# (NP Things/NNS)
# (NP the/DT whole/JJ time/NN)
# (NP this/DT movie/NN)
# (S
#   Could/MD
#   n't/RB
#   even/RB
#   get/VB
#   myself/PRP
#   to/TO
#   finish/VB
#   (NP watching/NN)
#   till/IN
#   (NP the/DT end/NN))
# (NP watching/NN)
# (NP the/DT end/NN)
# (S
#   (NP Wow/NNP)
#   ,/,
#   how/WRB
#   (NP corny/NN)
#   can/MD
#   (NP a/DT movie/NN)
#   (NP get/NN)
#   and/CC
#   what/WDT
#   were/VBD
#   they/PRP
#   thinking/VBG
#   ,/,
#   it/PRP
#   's/VBZ
#   so/RB
#   corny/JJ
#   it/PRP
#   can/MD
#   be/VB
#   rated/VBN
#   as/IN
#   (NP a/DT comedy/NN)
#   (NP movie/NN)
#   ./.)
# (NP Wow/NNP)
# (NP corny/NN)
# (NP a/DT movie/NN)
# (NP get/NN)
# (NP a/DT comedy/NN)
# (NP movie/NN)
# (S
#   They/PRP
#   collected/VBD
#   (NP every/DT cliche/NN)
#   from/IN
#   (NP the/DT book/NN)
#   of/IN
#   (NP cringe/NN)
#   and/CC
#   (NP romance/NN)
#   and/CC
#   shoved/VBD
#   them/PRP
#   in/IN
#   (NP a/DT movie/NN)
#   ./.)
# (NP every/DT cliche/NN)
# (NP the/DT book/NN)
# (NP cringe/NN)
# (NP romance/NN)
# (NP a/DT movie/NN)
# (S
#   I/PRP
#   ca/MD
#   n't/RB
#   even/RB
#   humor/VB
#   (NP the/DT movie/NN)
#   by/IN
#   listing/VBG
#   (NP the/DT things/NNS)
#   that/WDT
#   are/VBP
#   bad/JJ
#   with/IN
#   it/PRP
#   ,/,
#   does/VBZ
#   n't/RB
#   even/RB
#   deserve/VB
#   (NP the/DT time/NN)
#   or/CC
#   (NP effort/NN)
#   ,/,
#   the/DT
#   two/CD
#   (NP hours/NNS)
#   I/PRP
#   wasted/VBD
#   watching/VBG
#   it/PRP
#   were/VBD
#   more/JJR
#   than/IN
#   enough/RB
#   ./.)
# (NP the/DT movie/NN)
# (NP the/DT things/NNS)
# (NP the/DT time/NN)
# (NP effort/NN)
# (NP hours/NNS)
# (S
#   Probably/RB
#   one/CD
#   of/IN
#   (NP the/DT worst/JJS movies/NNS)
#   of/IN
#   (NP the/DT century/NN)
#   so/RB
#   far/RB)
# (NP the/DT worst/JJS movies/NNS)
# (NP the/DT century/NN)
# (S
#   Seriously/RB
#   I/PRP
#   am/VBP
#   not/RB
#   politically/RB
#   correct/JJ
#   woke/VBD
#   or/CC
#   outraged/VBD
#   person.But/IN
#   (NP the/DT idea/NN)
#   that/IN
#   (NP a/DT scumbag/NN)
#   (NP mafia/NN)
#   (NP guy/NN)
#   ,/,
#   is/VBZ
#   going/VBG
#   to/TO
#   sexually/RB
#   assault/VB
#   his/PRP$
#   (NP way/NN)
#   into/IN
#   (NP a/DT woman/NN)
#   's/POS
#   (NP heart/NN)
#   is/VBZ
#   just/RB
#   absurd/JJ
#   ./.)
# (NP the/DT idea/NN)
# (NP a/DT scumbag/NN)
# (NP mafia/NN)
# (NP guy/NN)
# (NP way/NN)
# (NP a/DT woman/NN)
# (NP heart/NN)
# (S
#   (NP The/DT sopranos/NN)
#   was/VBD
#   good/JJ
# ...
#   (NP input/NN)
#   is/VBZ
#   amazing/JJ
#   ,/,
#   (NP Pugh/NNP)
#   is/VBZ
#   just/RB
#   as/RB
#   good/JJ
#   &/CC
#   (NP the/DT rest/NN)
#   (NP provide/NN)
#   (NP brilliant/JJ support/NN)
#   but/CC
#   it/PRP
#   's/VBZ
#   their/PRP$
#   (NP chemistry/NN)
#   with/IN
#   one/CD
#   another/DT
#   that/WDT
#   clicks/VBZ
#   (NP best.Overall/NN)
#   ,/,
#   (NP Little/JJ Women/NNP)
#   (NP presents/NNS)
#   (NP Greta/NNP)
#   (NP Gerwig/NNP)
#   in/IN
#   (NP stellar/JJ form/NN)
#   ,/,
#   and/CC
#   is/VBZ
#   (NP another/DT quality/NN)
#   (NP addition/NN)
#   to/TO
#   her/PRP$
#   (NP filmography/NN)
#   ./.)
# (NP Ronan/NNP)
# (NP input/NN)
# (NP Pugh/NNP)
# (NP the/DT rest/NN)
# (NP provide/NN)
# (NP brilliant/JJ support/NN)
# (NP chemistry/NN)
# (NP best.Overall/NN)
# (NP Little/JJ Women/NNP)
# (NP presents/NNS)
# (NP Greta/NNP)
# (NP Gerwig/NNP)
# (NP stellar/JJ form/NN)
# (NP another/DT quality/NN)
# (NP addition/NN)
# (NP filmography/NN)
# (S
#   Exquisitely/RB
#   highlighting/VBG
#   (NP the/DT women/NNS)
#   's/POS
#   (NP plight/NN)
#   ,/,
#   (NP prejudice/NN)
#   &/CC
#   (NP powerlessness/NN)
#   in/IN
#   (NP those/DT days/NNS)
#   and/CC
#   to/TO
#   (NP an/DT extent/NN)
#   even/RB
#   (NP today/NN)
#   ,/,
#   (NP Little/NNP)
#   (NP Women/NNP)
#   is/VBZ
#   (NP a/DT joyful/JJ celebration/NN)
#   of/IN
#   (NP sisterhood/NN)
#   that/WDT
#   's/VBZ
#   highly/RB
#   faithful/JJ
#   to/TO
#   its/PRP$
#   (NP source/NN)
#   (NP material/NN)
#   and/CC
#   is/VBZ
#   winsome/JJ
#   &/CC
#   whimsical/JJ
#   in/IN
#   (NP wonderful/JJ ways/NNS)
#   ./.)
# (NP the/DT women/NNS)
# (NP plight/NN)
# (NP prejudice/NN)
# (NP powerlessness/NN)
# (NP those/DT days/NNS)
# (NP an/DT extent/NN)
# (NP today/NN)
# (NP Little/NNP)
# (NP Women/NNP)
# (NP a/DT joyful/JJ celebration/NN)
# (NP sisterhood/NN)
# (NP source/NN)
# (NP material/NN)
# (NP wonderful/JJ ways/NNS)
# (S
#   One/CD
#   of/IN
#   (NP the/DT best/JJS all-round/JJ films/NNS)
#   of/IN
#   2019/CD
#   ./.)
# (NP the/DT best/JJS all-round/JJ films/NNS)
# (S
#   (NP Greta/NNP)
#   (NP Gerwig/NNP)
#   's/POS
#   (NP post-'Lady/JJ Bird/NNP)
#   '/POS
#   (NP female/NN)
#   centred/VBD
#   (NP 'Little/JJ Women/NNP)
#   '/POS
#   ,/,
#   based/VBN
#   on/IN
#   the/DT
#   acclaimed/VBN
#   (NP novel/NN)
#   by/IN
#   (NP Louisa/NNP)
#   (NP May/NNP)
#   (NP Alcott/NNP)
#   ,/,
#   takes/VBZ
#   us/PRP
#   back/RB
#   to/TO
#   (NP the/DT late/JJ 19th/JJ century/NN)
#   in/IN
#   which/WDT
#   we/PRP
#   follow/VBP
#   (NP the/DT lives/NNS)
#   of/IN
#   (NP the/DT March-family/NNP)
#   ./.)
# (NP Greta/NNP)
# (NP Gerwig/NNP)
# (NP post-'Lady/JJ Bird/NNP)
# (NP female/NN)
# (NP 'Little/JJ Women/NNP)
# (NP novel/NN)
# (NP Louisa/NNP)
# (NP May/NNP)
# (NP Alcott/NNP)
# (NP the/DT late/JJ 19th/JJ century/NN)
# (NP the/DT lives/NNS)
# (NP the/DT March-family/NNP)
# (S
#   (NP Numerous/JJ adaptations/NNS)
#   have/VBP
#   been/VBN
#   made/VBN
#   over/IN
#   (NP the/DT past/JJ few/JJ decades/NNS)
#   ,/,
#   but/CC
#   (NP Gerwig/NNP)
#   elevates/VBZ
#   (NP the/DT material/NN)
#   ,/,
#   translating/VBG
#   it/PRP
#   in/IN
#   (NP a/DT way/NN)
#   to/TO
#   appeal/VB
#   to/TO
#   (NP modern/JJ audiences/NNS)
#   ,/,
#   without/IN
#   ever/RB
#   losing/VBG
#   (NP the/DT essence/NN)
#   of/IN
#   (NP the/DT well/NN)
#   known/VBN
#   (NP story.When/NN)
#   we/PRP
#   first/RB
#   meet/VBD
#   the/DT
#   talented/VBN
#   (NP Jo/NNP)
#   (/(
#   (NP Saoirse/NNP)
#   (NP Ronan/NNP)
#   )/)
#   ,/,
#   she/PRP
#   's/VBZ
#   living/VBG
#   in/IN
#   (NP New/NNP)
#   (NP York/NNP)
#   ,/,
#   teaching/VBG
#   (NP girls/NNS)
#   (NP literature/NN)
#   and/CC
#   trying/VBG
#   to/TO
#   sell/VB
#   her/PRP$
#   (NP own/JJ stories/NNS)
#   to/TO
#   (NP the/DT local/JJ newspaper/NN)
#   ./.)
# (NP Numerous/JJ adaptations/NNS)
# (NP the/DT past/JJ few/JJ decades/NNS)
# (NP Gerwig/NNP)
# (NP the/DT material/NN)
# (NP a/DT way/NN)
# (NP modern/JJ audiences/NNS)
# (NP the/DT essence/NN)
# (NP the/DT well/NN)
# (NP story.When/NN)
# (NP Jo/NNP)
# (NP Saoirse/NNP)
# (NP Ronan/NNP)
# (NP New/NNP)
# (NP York/NNP)
# (NP girls/NNS)
# (NP literature/NN)
# (NP own/JJ stories/NNS)
# (NP the/DT local/JJ newspaper/NN)
# (S
#   While/IN
#   (NP Jo/NNP)
#   lives/VBZ
#   her/PRP$
#   (NP best/JJS life/NN)
#   ,/,
#   her/PRP$
#   (NP hopeless/JJ romantic/JJ sister/NN)
#   (NP Amy/NNP)
#   (/(
#   (NP Florence/NNP)
#   (NP Pugh/NNP)
#   )/)
#   lives/VBZ
#   with/IN
#   her/PRP$
#   (NP old/JJ fashioned/JJ aunt/NN)
#   (/(
#   (NP Meryl/NNP)
#   (NP Streep/NNP)
#   )/)
#   in/IN
#   (NP Paris/NNP)
#   ,/,
#   attending/VBG
#   (NP painting/NN)
#   (NP classes/NNS)
#   while/IN
#   hoping/VBG
#   for/IN
#   (NP a/DT true/JJ love/NN)
#   to/TO
#   come/VB
#   (NP rescue/NN)
#   her/PRP
#   ./.)
# (NP Jo/NNP)
# (NP best/JJS life/NN)
# (NP hopeless/JJ romantic/JJ sister/NN)
# (NP Amy/NNP)
# (NP Florence/NNP)
# (NP Pugh/NNP)
# (NP old/JJ fashioned/JJ aunt/NN)
# (NP Meryl/NNP)
# (NP Streep/NNP)
# (NP Paris/NNP)
# (NP painting/NN)
# (NP classes/NNS)
# (NP a/DT true/JJ love/NN)
# (NP rescue/NN)
# (S
#   (NP Other/JJ sister/NN)
#   (NP Meg/NNP)
#   (/(
#   (NP Emma/NNP)
#   (NP Watson/NNP)
#   )/)
#   is/VBZ
#   happily/RB
#   married/VBN
#   with/IN
#   (NP kids/NNS)
#   and/CC
#   the/DT
#   musically/RB
#   gifted/VBN
#   (NP Beth/NNP)
#   (/(
#   (NP Eliza/NNP)
#   (NP Scanlen/NNP)
#   )/)
#   has/VBZ
#   been/VBN
#   bedridden/VBN
#   with/IN
#   (NP a/DT severe/JJ illness/NN)
#   ./.)
# (NP Other/JJ sister/NN)
# (NP Meg/NNP)
# (NP Emma/NNP)
# (NP Watson/NNP)
# (NP kids/NNS)
# (NP Beth/NNP)
# (NP Eliza/NNP)
# (NP Scanlen/NNP)
# (NP a/DT severe/JJ illness/NN)
# (S
#   When/WRB
#   (NP Jo/NNP)
#   gets/VBZ
#   (NP news/NN)
#   about/IN
#   (NP Beth/NNP)
#   's/POS
#   (NP state/NN)
#   quickly/RB
#   (NP deteriorating/NN)
#   ,/,
#   she/PRP
#   leaves/VBZ
#   (NP everything/NN)
#   (NP behind/NN)
#   and/CC
#   (NP jumps/NNS)
#   on/IN
#   (NP the/DT first/JJ train/NN)
#   (NP home/NN)
#   ./.)
# (NP Jo/NNP)
# (NP news/NN)
# (NP Beth/NNP)
# (NP state/NN)
# (NP deteriorating/NN)
# (NP everything/NN)
# (NP behind/NN)
# (NP jumps/NNS)
# (NP the/DT first/JJ train/NN)
# (NP home/NN)
# (S
#   While/IN
#   (NP Jo/NNP)
#   (NP naps/NNS)
#   ,/,
#   we/PRP
#   flash/VBP
#   back/RB
#   to/TO
#   (NP easier/JJR times/NNS)
#   seven/CD
#   (NP years/NNS)
#   earlier/RB
#   ,/,
#   when/WRB
#   (NP all/DT sisters/NNS)
#   still/RB
#   lived/VBD
#   merrily/RB
#   under/IN
#   one/CD
#   (NP roof.The/NN)
#   (NP first/JJ thing/NN)
#   you/PRP
#   'll/MD
#   notice/VB
#   is/VBZ
#   (NP the/DT scale/NN)
#   on/IN
#   which/WDT
#   all/DT
#   of/IN
#   this/DT
#   has/VBZ
#   been/VBN
#   made/VBN
#   ./.)
# (NP Jo/NNP)
# (NP naps/NNS)
# (NP easier/JJR times/NNS)
# (NP years/NNS)
# (NP all/DT sisters/NNS)
# (NP roof.The/NN)
# (NP first/JJ thing/NN)
# (NP the/DT scale/NN)
# (S
#   (NP Extraordinary/JJ production/NN)
#   (NP design/NN)
#   inside/IN
#   (NP the/DT old/JJ mansions/NNS)
#   surrounded/VBN
#   by/IN
#   the/DT
#   breathtaking/VBG
#   (NP scenery/NN)
#   of/IN
#   (NP Massachusetts/NNP)
#   ,/,
#   where/WRB
#   (NP Little/JJ Women/NNP)
#   was/VBD
#   filmed/VBN
#   ./.)
# (NP Extraordinary/JJ production/NN)
# (NP design/NN)
# (NP the/DT old/JJ mansions/NNS)
# (NP scenery/NN)
# (NP Massachusetts/NNP)
# (NP Little/JJ Women/NNP)
# (S
#   Let/VB
#   (NP Academy/NNP)
#   (NP Award/NNP)
#   (NP winning/NN)
#   (/(
#   for/IN
#   his/PRP$
#   (NP scores/NNS)
#   of/IN
#   (NP 'The/NNP)
#   (NP Shape/NNP)
#   of/IN
#   (NP Water/NNP)
#   '/POS
#   and/CC
#   'The/CD
#   (NP Grand/NNP)
#   (NP Budapest/NNP)
#   (NP Hotel/NNP)
#   '/POS
#   )/)
#   (NP composer/NN)
#   (NP Alexandre/NNP)
#   (NP Desplat/NNP)
#   set/VBD
#   (NP the/DT tone/NN)
#   for/IN
#   (NP each/DT scene/NN)
#   with/IN
#   his/PRP$
#   (NP classically/NN)
#   infused/VBD
#   orchestra/JJ
#   ,/,
#   and/CC
#   all/DT
#   you/PRP
#   need/VBP
#   is/VBZ
#   talent/JJ
#   on/IN
#   (NP screen/NN)
#   and/CC
#   on/IN
#   paper.Luckily/RB
#   (NP Gerwig/NNP)
#   knows/VBZ
#   how/WRB
#   to/TO
#   write/VB
#   (NP a/DT terrific/JJ screenplay/NN)
#   and/CC
#   (NP the/DT cast/NN)
#   has/VBZ
#   the/DT
#   most/RBS
#   (NP incredible/JJ chemistry/NN)
#   ./.)
# (NP Academy/NNP)
# (NP Award/NNP)
# (NP winning/NN)
# (NP scores/NNS)
# (NP 'The/NNP)
# (NP Shape/NNP)
# (NP Water/NNP)
# (NP Grand/NNP)
# (NP Budapest/NNP)
# (NP Hotel/NNP)
# (NP composer/NN)
# (NP Alexandre/NNP)
# (NP Desplat/NNP)
# (NP the/DT tone/NN)
# (NP each/DT scene/NN)
# (NP classically/NN)
# (NP screen/NN)
# (NP Gerwig/NNP)
# (NP a/DT terrific/JJ screenplay/NN)
# (NP the/DT cast/NN)
# (NP incredible/JJ chemistry/NN)
# (S
#   (NP The/DT dialogue/NN)
#   is/VBZ
#   riddled/VBN
#   with/IN
#   (NP timely/JJ jokes/NNS)
#   and/CC
#   hopelessly/RB
#   (NP romantic/JJ discussions/NNS)
#   ,/,
#   (NP perfect/NN)
#   for/IN
#   (NP that/DT time/NN)
#   (NP period/NN)
#   ./.)
# (NP The/DT dialogue/NN)
# (NP timely/JJ jokes/NNS)
# (NP romantic/JJ discussions/NNS)
# (NP perfect/NN)
# (NP that/DT time/NN)
# (NP period/NN)
# (S
#   It/PRP
#   's/VBZ
#   (NP all/DT part/NN)
#   of/IN
#   (NP a/DT bigger/JJR picture/NN)
#   in/IN
#   which/WDT
#   (NP each/DT character/NN)
#   has/VBZ
#   their/PRP$
#   (NP own/JJ story/NN)
#   to/TO
#   tell/VB
#   ./.)
# (NP all/DT part/NN)
# (NP a/DT bigger/JJR picture/NN)
# (NP each/DT character/NN)
# (NP own/JJ story/NN)
# (S
#   (NP Saoirse/NNP)
#   (NP Ronan/NNP)
#   's/POS
#   (/(
#   (NP Lady/NNP)
#   (NP Bird/NNP)
#   )/)
#   (NP radiant/NN)
#   (NP presence/NN)
#   is/VBZ
#   again/RB
#   noteworthy/JJ
#   ,/,
#   more/RBR
#   so/RB
#   ,/,
#   she/PRP
#   is/VBZ
#   quickly/RB
#   becoming/VBG
#   (NP the/DT best/JJS actress/NN)
#   in/IN
#   (NP the/DT business/NN)
#   ./.)
# (NP Saoirse/NNP)
# (NP Ronan/NNP)
# (NP Lady/NNP)
# (NP Bird/NNP)
# (NP radiant/NN)
# (NP presence/NN)
# (NP the/DT best/JJS actress/NN)
# (NP the/DT business/NN)
# (S
#   While/IN
#   rising/VBG
#   (NP star/NN)
#   (NP Florence/NNP)
#   (NP Pugh/NNP)
#   (/(
#   (NP Midsommar/NNP)
#   )/)
#   as/IN
#   the/DT
#   truly/RB
#   hilarious/JJ
#   and/CC
#   hopelessly/RB
#   obsessed/VBN
#   with/IN
#   (NP love/NN)
#   ,/,
#   (NP wealth/NN)
#   and/CC
#   looks/VBZ
#   (NP Amy/NNP)
#   ,/,
#   gives/VBZ
#   (NP another/DT career/NN)
#   defining/VBG
#   (NP performance/NN)
#   ,/,
#   to/TO
#   leave/VB
#   (NP a/DT mark/NN)
#   on/IN
#   (NP today/NN)
#   's/POS
#   (NP moviegoers/NNS)
#   '/POS
#   (NP memory/NN)
#   ./.)
# (NP star/NN)
# (NP Florence/NNP)
# (NP Pugh/NNP)
# (NP Midsommar/NNP)
# (NP love/NN)
# (NP wealth/NN)
# (NP Amy/NNP)
# (NP another/DT career/NN)
# (NP performance/NN)
# (NP a/DT mark/NN)
# (NP today/NN)
# (NP moviegoers/NNS)
# (NP memory/NN)
# (S
#   It/PRP
#   's/VBZ
#   when/WRB
#   all/DT
#   four/CD
#   (NP sisters/NNS)
#   and/CC
#   their/PRP$
#   (NP mother/NN)
#   (/(
#   played/VBN
#   by/IN
#   (NP a/DT comforting/NN)
#   (NP Laura/NNP)
#   (NP Dern/NNP)
#   )/)
#   first/RB
#   appear/VBP
#   on/IN
#   (NP screen/NN)
#   ,/,
#   you/PRP
#   'll/MD
#   fall/VB
#   in/IN
#   (NP love/NN)
#   with/IN
#   (NP this/DT family/NN)
#   ./.)
# (NP sisters/NNS)
# (NP mother/NN)
# (NP a/DT comforting/NN)
# (NP Laura/NNP)
# (NP Dern/NNP)
# (NP screen/NN)
# (NP love/NN)
# (NP this/DT family/NN)
# (S
#   There/EX
#   's/VBZ
#   (NP a/DT cosiness/NN)
#   and/CC
#   homely/RB
#   feeling/VBG
#   to/TO
#   their/PRP$
#   (NP interactions/NNS)
#   ,/,
#   that/WDT
#   will/MD
#   warm/VB
#   you/PRP
#   up/RP
#   from/IN
#   (NP the/DT inside/NN)
#   ./.)
# (NP a/DT cosiness/NN)
# (NP interactions/NNS)
# (NP the/DT inside/NN)
# (S
#   Something/VBG
#   this/DT
#   innocent/JJ
#   and/CC
#   safe/JJ
#   has/VBZ
#   n't/RB
#   been/VBN
#   brought/VBN
#   to/TO
#   (NP the/DT big/JJ screen/NN)
#   in/IN
#   a/DT
#   very/RB
#   (NP long/JJ time/NN)
#   and/CC
#   (NP Gerwig/NNP)
#   knows/VBZ
#   just/RB
#   how/WRB
#   to/TO
#   control/VB
#   your/PRP$
#   (NP emotions.After/NN)
#   (NP a/DT lot/NN)
#   of/IN
#   going/VBG
#   back/RB
#   and/CC
#   (NP forth/NN)
#   in/IN
#   (NP time/NN)
#   -/:
#   which/WDT
#   is/VBZ
#   quite/RB
#   confusing/JJ
#   to/TO
#   begin/VB
#   with/IN
#   ,/,
#   but/CC
#   you/PRP
#   get/VBP
#   more/JJR
#   used/VBN
#   to/TO
#   it/PRP
#   further/RB
#   down/RP
#   (NP the/DT line/NN)
#   when/WRB
#   (NP both/DT timelines/NNS)
#   move/VBP
#   forward/RB
#   to/TO
#   meet/VB
#   in/IN
#   the/DT
#   middle/JJ
#   -/:
#   (NP the/DT final/JJ third/NN)
#   of/IN
#   (NP the/DT film/NN)
#   builds/VBZ
#   up/RP
#   to/TO
#   (NP a/DT gut/NN)
#   wrenching/VBG
#   (NP conclusion/NN)
#   ./.)
# (NP the/DT big/JJ screen/NN)
# (NP long/JJ time/NN)
# (NP Gerwig/NNP)
# (NP emotions.After/NN)
# (NP a/DT lot/NN)
# (NP forth/NN)
# (NP time/NN)
# (NP the/DT line/NN)
# (NP both/DT timelines/NNS)
# (NP the/DT final/JJ third/NN)
# (NP the/DT film/NN)
# (NP a/DT gut/NN)
# (NP conclusion/NN)
# (S
#   For/IN
#   (NP some/DT reason/NN)
#   ,/,
#   (NP the/DT actual/JJ heartbreaking/NN)
#   (NP event/NN)
#   is/VBZ
#   n't/RB
#   so/RB
#   much/JJ
#   of/IN
#   (NP a/DT surprise/NN)
#   ,/,
#   it/PRP
#   's/VBZ
#   (NP the/DT aftermath/NN)
#   that/WDT
#   truly/VBZ
#   (NP shatters/NNS)
#   your/PRP$
#   (NP heart/NN)
#   into/IN
#   (NP tiny/JJ pieces/NNS)
#   and/CC
#   leaves/VBZ
#   you/PRP
#   gasping/VBG
#   for/IN
#   (NP air/NN)
#   while/IN
#   (NP tears/NNS)
#   roll/VBP
#   down/RP
#   your/PRP$
#   (NP cheek/NN)
#   ./.)
# (NP some/DT reason/NN)
# (NP the/DT actual/JJ heartbreaking/NN)
# (NP event/NN)
# (NP a/DT surprise/NN)
# (NP the/DT aftermath/NN)
# (NP shatters/NNS)
# (NP heart/NN)
# (NP tiny/JJ pieces/NNS)
# (NP air/NN)
# (NP tears/NNS)
# (NP cheek/NN)
# (S
#   (NP Little/JJ Women/NNP)
#   is/VBZ
#   just/RB
#   as/RB
#   heartwarming/VBG
#   as/IN
#   it/PRP
#   is/VBZ
#   excruciatingly/RB
#   sad/JJ
#   ./.)
# (NP Little/JJ Women/NNP)
# (S
#   (NP Greta/NNP)
#   (NP Gerwig/NNP)
#   has/VBZ
#   made/VBN
#   a/DT
#   timeless/JJ
#   classic/JJ
#   that/WDT
#   exudes/VBZ
#   (NP love/NN)
#   ./.)
# (NP Greta/NNP)
# (NP Gerwig/NNP)
# (NP love/NN)
# (S
#   Watching/VBG
#   (NP this/DT film/NN)
#   will/MD
#   for/IN
#   sure/JJ
#   become/VB
#   (NP a/DT new/JJ Christmas/NNP)
#   (NP tradition/NN)
#   in/IN
#   (NP many/JJ households/NNS)
#   ./.)
# (NP this/DT film/NN)
# (NP a/DT new/JJ Christmas/NNP)
# (NP tradition/NN)
# (NP many/JJ households/NNS)
# (S
#   What/WP
#   a/DT
#   wonderful/JJ
#   gift.Originally/RB
#   published/VBN
#   on/IN
#   (NP intoscreens/NNS))
# (NP intoscreens/NNS)
# (S
#   ``/``
#   (NP Little/JJ Women/NNP)
#   ''/''
#   is/VBZ
#   empowering/VBG
#   ,/,
#   refreshing/VBG
#   and/CC
#   an/DT
#   absolutely/RB
#   (NP lovely/JJ film/NN)
#   backed/VBN
#   by/IN
#   (NP an/DT incredible/JJ cast/NN)
#   ./.)
# (NP Little/JJ Women/NNP)
# (NP lovely/JJ film/NN)
# (NP an/DT incredible/JJ cast/NN)
# (S ./.)
# (S
#   In/IN
#   (NP this/DT drama/NN)
#   ,/,
#   (NP the/DT March/NNP)
#   (NP sisters/NNS)
#   are/VBP
#   four/CD
#   (NP young/JJ women/NNS)
#   each/DT
#   determined/VBD
#   to/TO
#   live/VB
#   (NP life/NN)
#   on/IN
#   their/PRP$
#   (NP own/JJ terms/NNS)
#   ./.)
# (NP this/DT drama/NN)
# (NP the/DT March/NNP)
# (NP sisters/NNS)
# (NP young/JJ women/NNS)
# (NP life/NN)
# (NP own/JJ terms/NNS)
# (S
#   Based/VBN
#   on/IN
#   (NP the/DT classic/JJ novel/NN)
#   of/IN
#   (NP the/DT same/JJ name/NN)
#   ./.)
# (NP the/DT classic/JJ novel/NN)
# (NP the/DT same/JJ name/NN)
# (S ./.)
# (S
#   I/PRP
#   had/VBD
#   (NP neutral/JJ feelings/NNS)
#   about/IN
#   ``/``
#   (NP Little/JJ Women/NNP)
#   ''/''
#   as/IN
#   I/PRP
#   walked/VBD
#   in/IN
#   to/TO
#   take/VB
#   my/PRP$
#   (NP seat/NN)
#   ,/,
#   but/CC
#   in/IN
#   (NP the/DT end/NN)
#   I/PRP
#   thoroughly/RB
#   enjoyed/VBD
#   (NP this/DT film/NN)
#   ./.)
# (NP neutral/JJ feelings/NNS)
# (NP Little/JJ Women/NNP)
# (NP seat/NN)
# (NP the/DT end/NN)
# (NP this/DT film/NN)
# (S
#   (NP A/DT sweet/NN)
#   ,/,
#   sensitive/JJ
#   and/CC
#   (NP powerful/JJ film/NN)
#   that/WDT
#   will/MD
#   remain/VB
#   timeless/JJ
#   like/IN
#   its/PRP$
#   (NP source/NN)
#   (NP material/NN)
#   ./.)
# (NP A/DT sweet/NN)
# (NP powerful/JJ film/NN)
# (NP source/NN)
# (NP material/NN)
# (S
#   (NP The/DT cast/NN)
#   of/IN
#   (NP leads/NNS)
#   is/VBZ
#   terrific/JJ
#   but/CC
#   (NP Florence/NNP)
#   (NP Pugh/NNP)
#   steals/VBZ
#   (NP the/DT show/NN)
#   ./.)
# (NP The/DT cast/NN)
# (NP leads/NNS)
# (NP Florence/NNP)
# (NP Pugh/NNP)
# (NP the/DT show/NN)
# (S
#   (NP Pugh/NNP)
#   will/MD
#   become/VB
#   one/CD
#   of/IN
#   (NP the/DT great/JJ leading/JJ ladies/NNS)
#   in/IN
#   (NP the/DT biz/NN)
#   (/(
#   see/VB
#   also/RB
#   ``/``
#   Fighting/VBG
#   With/IN
#   (NP My/NNP)
#   (NP Family/NNP)
#   ''/''
#   ,/,
#   ``/``
#   (NP Midsommar/NNP)
#   ''/''
#   )/)
#   ./.)
# (NP Pugh/NNP)
# (NP the/DT great/JJ leading/JJ ladies/NNS)
# (NP the/DT biz/NN)
# (NP My/NNP)
# (NP Family/NNP)
# (NP Midsommar/NNP)
# (S
#   ``/``
#   (NP Little/JJ Women/NNP)
#   ''/''
#   is/VBZ
#   garnished/VBN
#   with/IN
#   (NP beauty/NN)
#   and/CC
#   (NP a/DT joy/NN)
#   to/TO
#   watch/VB
#   ./.)
# (NP Little/JJ Women/NNP)
# (NP beauty/NN)
# (NP a/DT joy/NN)
# (S
#   You/PRP
#   will/MD
#   fall/VB
#   in/IN
#   (NP love/NN)
#   with/IN
#   (NP this/DT film/NN)
#   ./.)
# (NP love/NN)
# (NP this/DT film/NN)
# (S
#   (NP Tender/NN)
#   ,/,
#   (NP beautiful/JJ rhythm/NN)
#   ,/,
#   (NP well-kept/JJ characters/NNS)
#   and/CC
#   (NP an/DT atmosphere/NN)
#   that/WDT
#   holds/VBZ
#   up/IN
#   to/TO
#   (NP the/DT end/NN)
#   ./.)
# (NP Tender/NN)
# (NP beautiful/JJ rhythm/NN)
# (NP well-kept/JJ characters/NNS)
# (NP an/DT atmosphere/NN)
# (NP the/DT end/NN)
# (S
#   we/PRP
#   all/DT
#   know/VBP
#   (NP the/DT story/NN)
#   ,/,
#   making/VBG
#   (NP a/DT good/JJ movie/NN)
#   was/VBD
#   not/RB
#   easy/JJ
#   at/IN
#   all/DT
#   ./.)
# (NP the/DT story/NN)
# (NP a/DT good/JJ movie/NN)
# (S 7/10/CD)

# %%
print(sentences_arr)
# Out:
# [Tree('S', [('I', 'PRP'), ('honestly', 'RB'), ('ca', 'MD'), ("n't", 'RB'), ('believe', 'VB'), ('this', 'DT'), ('is', 'VBZ'), Tree('NP', [('an', 'DT'), ('actual', 'JJ'), ('movie', 'NN')]), ('and', 'CC'), Tree('NP', [('number', 'NN')]), ('1', 'CD'), ('on', 'IN'), Tree('NP', [('Netflix', 'NNP')]), ('in', 'IN'), ('my', 'PRP$'), Tree('NP', [('country', 'NN')]), ('.', '.')]), Tree('S', [('This', 'DT'), ('was', 'VBD'), ('probably', 'RB'), Tree('NP', [('the', 'DT'), ('worst', 'JJS'), ('movie', 'NN')]), ('I', 'PRP'), ("'ve", 'VBP'), ('ever', 'RB'), ('seen', 'VBN'), ('.', '.')]), Tree('S', [Tree('NP', [('The', 'DT'), ('dialogues', 'NNS')]), ('between', 'IN'), Tree('NP', [('the', 'DT'), ('main', 'JJ'), ('characters', 'NNS')]), ('are', 'VBP'), ('unbelievably', 'RB'), ('cringy', 'JJ'), ('and', 'CC'), Tree('NP', [('the', 'DT'), ('plot', 'NN')]), ('literally', 'RB'), ('does', 'VBZ'), ("n't", 'RB'), ('make', 'VB'), Tree('NP', [('any', 'DT'), ('sense', 'NN')]), ('.', '.')]), Tree('S', [('Do', 'VBP'), ("n't", 'RB'), ('watch', 'VB'), Tree('NP', [('this', 'DT'), ('movie', 'NN')]), ('unless', 'IN'), ('you', 'PRP'), ('wan', 'VBP'), Tree('NP', [('na', 'JJ'), ('waste', 'NN')]), ('2', 'CD'), Tree('NP', [('hours', 'NNS')]), ('of', 'IN'), ('your', 'PRP$'), Tree('NP', [('life', 'NN')]), ('just', 'RB'), ('to', 'TO'), ('give', 'VB'), Tree('NP', [('this', 'DT'), ('movie', 'NN')]), ('a', 'DT'), ('(', '('), ('probably', 'RB'), (')', ')'), ('1', 'CD'), Tree('NP', [('star', 'NN')]), Tree('NP', [('rating', 'NN')]), ('too', 'RB'), ('.', '.')]), Tree('S', [Tree('NP', [('Girl', 'NNP')]), ("'s", 'POS'), Tree('NP', [('boyfriend', 'NN')]), ('wears', 'VBZ'), ('cargo', 'VBP'), Tree('NP', [('short', 'JJ'), ('pants', 'NNS')]), ('on', 'IN'), ('her', 'PRP$'), Tree('NP', [('birthday', 'NN')]), ('.', '.')]), Tree('S', [('If', 'IN'), ('that', 'DT'), ('is', 'VBZ'), ('not', 'RB'), Tree('NP', [('a', 'DT'), ('red', 'JJ'), ('flag', 'NN')]), (',', ','), ('I', 'PRP'), ('do', 'VBP'), ('not', 'RB'), ('know', 'VB'), ('what', 'WP'), ('it', 'PRP'), ('is', 'VBZ'), ('.', '.')]), Tree('S', [Tree('NP', [('A', 'DT'), ('kidnapped', 'JJ'), ('woman', 'NN')]), ('is', 'VBZ'), ('smiling', 'VBG'), ('less', 'JJR'), ('than', 'IN'), ('24', 'CD'), Tree('NP', [('hours', 'NNS')]), ('after', 'IN'), ('being', 'VBG'), ('fed', 'VBN'), ('and', 'CC'), ('taking', 'VBG'), Tree('NP', [('shopping', 'NN')]), ('at', 'IN'), Tree('NP', [('a', 'DT'), ('high', 'JJ'), ('end', 'NN')]), Tree('NP', [('botique', 'NN')]), ('by', 'IN'), ('her', 'PRP$'), Tree('NP', [('captor', 'NN')]), ('.', '.')]), Tree('S', [('3', 'CD'), Tree('NP', [('days', 'NNS')]), ('into', 'IN'), ('her', 'PRP$'), Tree('NP', [('captivity', 'NN')]), Tree('NP', [('spent', 'NN')]), ('jetsetting', 'VBG'), ('to', 'TO'), Tree('NP', [('VIP', 'NNP')]), Tree('NP', [('clubs', 'NNS')]), ('and', 'CC'), ('on', 'IN'), Tree('NP', [('private', 'JJ'), ('yachts', 'NNS')]), ('she', 'PRP'), ('blows', 'VBZ'), ('him', 'PRP'), ('and', 'CC'), ('falls', 'VBZ'), ('in', 'IN'), Tree('NP', [('love', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('A', 'DT'), ('true', 'JJ'), ('romance', 'NN')]), Tree('NP', [('tale', 'NN')]), ('for', 'IN'), Tree('NP', [('the', 'DT'), ('ages', 'NNS')]), ('.', '.')]), Tree('S', [Tree('NP', [('The', 'DT'), ('cringe', 'NN')]), Tree('NP', [('levels', 'NNS')]), ('runeth', 'VBP'), ('over', 'IN'), ('.', '.')]), Tree('S', [Tree('NP', [('The', 'DT'), ('English', 'NNP')]), ('is', 'VBZ'), ('almost', 'RB'), ('as', 'RB'), ('bad', 'JJ'), ('as', 'IN'), Tree('NP', [('the', 'DT'), ('plot', 'NN')]), ('.', '.')]), Tree('S', [('If', 'IN'), ('you', 'PRP'), ('want', 'VBP'), ('to', 'TO'), ('watch', 'VB'), Tree('NP', [('this', 'DT'), ('movie', 'NN')]), ('do', 'VBP'), ('so', 'RB'), ('as', 'IN'), Tree('NP', [('a', 'DT'), ('drinking', 'NN')]), Tree('NP', [('game', 'NN')]), ('.', '.')]), Tree('S', [Tree('NP', [('Did', 'NNP')]), ('you', 'PRP'), ('cringe', 'VB'), ('?', '.')]), Tree('S', [('Then', 'RB'), ('take', 'VB'), Tree('NP', [('a', 'DT'), ('shot', 'NN')]), ('my', 'PRP$'), Tree('NP' ...

# %%
print(sentences_np_arr)
# Out:
# [Tree('NP', [('an', 'DT'), ('actual', 'JJ'), ('movie', 'NN')]), Tree('NP', [('number', 'NN')]), Tree('NP', [('Netflix', 'NNP')]), Tree('NP', [('country', 'NN')]), Tree('NP', [('the', 'DT'), ('worst', 'JJS'), ('movie', 'NN')]), Tree('NP', [('The', 'DT'), ('dialogues', 'NNS')]), Tree('NP', [('the', 'DT'), ('main', 'JJ'), ('characters', 'NNS')]), Tree('NP', [('the', 'DT'), ('plot', 'NN')]), Tree('NP', [('any', 'DT'), ('sense', 'NN')]), Tree('NP', [('this', 'DT'), ('movie', 'NN')]), Tree('NP', [('na', 'JJ'), ('waste', 'NN')]), Tree('NP', [('hours', 'NNS')]), Tree('NP', [('life', 'NN')]), Tree('NP', [('this', 'DT'), ('movie', 'NN')]), Tree('NP', [('star', 'NN')]), Tree('NP', [('rating', 'NN')]), Tree('NP', [('Girl', 'NNP')]), Tree('NP', [('boyfriend', 'NN')]), Tree('NP', [('short', 'JJ'), ('pants', 'NNS')]), Tree('NP', [('birthday', 'NN')]), Tree('NP', [('a', 'DT'), ('red', 'JJ'), ('flag', 'NN')]), Tree('NP', [('A', 'DT'), ('kidnapped', 'JJ'), ('woman', 'NN')]), Tree('NP', [('hours', 'NNS')]), Tree('NP', [('shopping', 'NN')]), Tree('NP', [('a', 'DT'), ('high', 'JJ'), ('end', 'NN')]), Tree('NP', [('botique', 'NN')]), Tree('NP', [('captor', 'NN')]), Tree('NP', [('days', 'NNS')]), Tree('NP', [('captivity', 'NN')]), Tree('NP', [('spent', 'NN')]), Tree('NP', [('VIP', 'NNP')]), Tree('NP', [('clubs', 'NNS')]), Tree('NP', [('private', 'JJ'), ('yachts', 'NNS')]), Tree('NP', [('love', 'NN')]), Tree('NP', [('A', 'DT'), ('true', 'JJ'), ('romance', 'NN')]), Tree('NP', [('tale', 'NN')]), Tree('NP', [('the', 'DT'), ('ages', 'NNS')]), Tree('NP', [('The', 'DT'), ('cringe', 'NN')]), Tree('NP', [('levels', 'NNS')]), Tree('NP', [('The', 'DT'), ('English', 'NNP')]), Tree('NP', [('the', 'DT'), ('plot', 'NN')]), Tree('NP', [('this', 'DT'), ('movie', 'NN')]), Tree('NP', [('a', 'DT'), ('drinking', 'NN')]), Tree('NP', [('game', 'NN')]), Tree('NP', [('Did', 'NNP')]), Tree('NP', [('a', 'DT'), ('shot', 'NN')]), Tree('NP', [('dude', 'NN')]), Tree('NP', [('the', 'DT'), ('end', 'NN')]), Tree('NP', [('this', 'DT'), ('movie', 'NN')]), Tree('NP', [('a', 'DT'), ('good', 'JJ'), ('idea', 'NN')]), Tree('NP', [('a', 'DT'), ('complete', 'JJ'), ('train', 'NN')]), Tree('NP', [('wreck', 'NN')]), Tree('NP', [('multiple', 'JJ'), ('reasons.One', 'NN')]), Tree('NP', [('the', 'DT'), ('biggest', 'JJS'), ('issues', 'NNS')]), Tree('NP', [('the', 'DT'), ('plot', 'NN')]), Tree('NP', [('a', 'DT'), ('man', 'NN')]), Tree('NP', [('a', 'DT'), ('woman', 'NN')]), Tree('NP', [('captive', 'NN')]), Tree('NP', [('a', 'DT'), ('movie', 'NN')]), Tree('NP', [('this', 'DT'), ('idea', 'NN')]), Tree('NP', [('The', 'DT'), ('male', 'JJ'), ('character', 'NN')]), Tree('NP', [('a', 'DT'), ('creep', 'NN')]), Tree('NP', [('the', 'DT'), ('female', 'JJ'), ('character', 'NN')]), Tree('NP', [('multiple', 'JJ'), ('times', 'NNS')]), Tree('NP', [('a', 'DT'), ('bad', 'JJ'), ('thing', 'NN')]), Tree('NP', [('a', 'DT'), ('man', 'NN')]), Tree('NP', [('power', 'NN')]), Tree('NP', [('variations', 'NNS')]), Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('scene', 'NN')]), Tree('NP', [('different', 'JJ'), ('times', 'NNS')]), Tree('NP', [('This', 'DT'), ('movie', 'NN')]), Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('scene', 'NN')]), Tree('NP', [('random', 'JJ'), ('montages', 'NNS')]), Tree('NP', [('a', 'DT'), ('song', 'NN')]), Tree('NP', [('it.The', 'JJ'), ('actions', 'NNS')]), Tree('NP', [('the', 'DT'), ('characters', 'NNS')]), Tree('NP', [('a', 'DT'), ('foreign', 'JJ'), ('country', 'NN')]), Tree('NP', [('the', 'DT'), ('next', 'JJ'), ('day', 'NN')]), Tree('NP', [('a', 'DT'), ('shopping', 'NN')]), Tree('NP', [('montage', 'NN')]), Tree('NP', [('woo', 'JJ'), ('lets', 'NNS')]), Tree('NP', [('some', 'DT'), ('new', 'JJ'), ('clothes', 'NNS')]), Tree('NP', [('acts', 'NNS')]), Tree('NP', [('fine', 'NN')]), Tree('NP', [('the', 'DT'), ('audience', 'NN')]), Tree('NP', [('side', 'NN')]), Tree('NP', [('current', 'JJ'), ('boyfriend', 'NN')]), Tree('NP', [('a', 'DT'), ('horrible', 'JJ'), ('person', 'NN')]), Tree('NP', [('the', 'DT'), ('audience ...

# %% [markdown]
# ### Conclusion
#
# In this assignment, I started by extracting the user reviews from the IMDB website. I chose "Romance" as the genre for this assignment. I did not have any specific reason to choose this genre but I tested the program with other Genres like Action, Adventure, Comedy, and Thriller as well.
#
# Once all the reviews were extracted, we proceed to identify Noun Phrases by chunking the reviews. A total of 101 reviews were extracted (Top 5 Romance movies) and used as part of our analysis.
#
# After glancing through the initial results, it was observed that proper nouns were not being tagged as Noun Phrases. This behaviour was changed using a simple tweak to the grammar pattern. Instead of looking for nouns (NN), the pattern was altered to look for <NN.\*>. This would include Proper Noun (NNP), plural form of noun (NNS) and proper noun (NNPS) as well in addition to regular nouns(NN).
#
# The pattern was also tweaked to include <JJ.\*> to include comparitive and superlative adjectives. This helped us tag "the worst movie" as a noun phrase.

# %% [markdown]
# ### References
#
# - https://medium.com/analytics-vidhya/movie-recommendation-from-imdb-reviews-without-actually-read-the-reviews-fe8865a70bd5
